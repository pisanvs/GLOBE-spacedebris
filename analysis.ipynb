# %% [markdown]
# # Data analysis
#
# We would like to find statistically significant changes in the data after debris reentry. To do this we will first do the following analysis:
#
# 1. Statistical Differences (before & after reentry)
#     - Mean
#     - Median
#     - Standard Deviation
# 2. Anomaly Detection
# 3. Range of change
# 4. Cumulative Unsigned Rate of Change
#
# Finally, we will train an AI model on the data or some selected metrics and we will see how well it performs in predicting reentry events.

# %%
import pandas as pd

# Load the CSV file
file_path = "outputs/output.csv"
df = pd.read_csv(file_path)

# Display headers and first few rows
df_head = df.head()

# Display last few rows to get an overall sense of the data
df_tail = df.tail()

df_head, df_tail
# Out:
# (                  date      object  airtempsCurrentTemp  \
#  0  2020-03-10T02:30:00  NORAD 6792                 31.7
#  1  2020-03-10T05:00:00  NORAD 6792                 29.2
#  2  2020-03-10T05:30:00  NORAD 6792                 28.4
#  3  2020-03-10T08:30:00  NORAD 6792                 25.4
#  4  2020-03-10T09:00:00  NORAD 6792                 23.4
#
#     dissolvedoxygensDissolvedOxygenViaKitMgl  \
#  0                                       NaN
#  1                                       NaN
#  2                                       NaN
#  3                                       NaN
#  4                                       NaN
#
#     dissolvedoxygensDissolvedOxygenViaProbeMgl  \
#  0                                         NaN
#  1                                         NaN
#  2                                         NaN
#  3                                         NaN
#  4                                         NaN
#
#     dissolvedoxygensSalinityViaDokitPpt    distance  humiditiesDewpoint  \
#  0                                  NaN  998.651955                25.5
#  1                                  NaN  998.651955                25.1
#  2                                  NaN  998.651955                24.7
#  3                                  NaN  998.651955                23.1
#  4                                  NaN  998.651955                22.4
#
#     humiditiesRelativeHumidityPercent
#  0                               69.0
#  1                               78.0
#  2                               80.0
#  3                               87.0
#  4                               94.0  ,
#                         date       object  airtempsCurrentTemp  \
#  395254  2024-09-15T00:21:00  NORAD 60337                 14.0
#  395255  2024-09-14T00:21:00  NORAD 60337                 12.1
#  395256  2024-09-13T00:21:00  NORAD 60337                 13.0
#  395257  2024-09-12T00:21:00  NORAD 60337                 14.3
#  395258  2024-09-11T00:21:00  NORAD 60337                 15.3
#
#          dissolvedoxygensDissolvedOxygenViaKitMgl  \
#  395254                                       NaN
#  395255                                       NaN
#  395256                                       NaN
#  395257                                       NaN
#  395258                                       NaN
#
#          dissolvedoxygensDissolvedOxygenViaProbeMgl  \
#  395254                                         NaN
#  395255                                         NaN
#  395256                                         NaN
#  395257                                         NaN
#  395258                                         NaN
#
#          dissolvedoxygensSalinityViaDokitPpt   distance  humiditiesDewpoint  \
#  395254                                  NaN  422.00784                 NaN
#  395255                                  NaN  422.00784                 NaN
#  395256                                  NaN  422.00784                 NaN
#  395257                                  NaN  422.00784                 NaN
#  395258                                  NaN  422.00784                 NaN
#
#          humiditiesRelativeHumidityPercent
#  395254                                NaN
#  395255                                NaN
#  395256                                NaN
#  395257                                NaN
#  395258                                NaN  )

# %%
# Extract the object numbers from the re-entry log
reentry_objects = set()  # Using a set for quick lookup

with open("outputs/near-reentry-log.txt", "r") as file:
    for line in file:
        parts = line.split()
        if len(parts) > 1 and parts[1].isdigit():
            reentry_objects.add(parts[1])  # Extract the object number

# Extract object numbers from the dataset
df["object_id"] = df["object"].str.extract(r'(\d+)')  # Extract numeric part of "object"
df["object_id"] = df["object_id"].astype(str)

# Find matching objects in the dataset
matching_objects = df[df["object_id"].isin(reentry_objects)]["object_id"].unique()

# Count how many re-entry objects have matching data
num_matches = len(matching_objects)
num_total = len(reentry_objects)

num_matches, num_total, matching_objects
# Out:
# (108,
#  241,
#  array(['6792', '9911', '25274', '25469', '26476', '26640', '26692',
#         '27613', '28130', '28418', '28641', '28921', '29247', '29386',
#         '29482', '29512', '29664', '32751', '32765', '34603', '36749',
#         '38037', '38047', '38048', '38872', '38994', '39069', '39083',
#         '39259', '39482', '39559', '39566', '39572', '39649', '40313',
#         '40422', '40729', '40913', '40963', '41107', '41574', '41575',
#         '41576', '41640', '41777', '41839', '41865', '42704', '42903',
#         '42972', '43101', '43624', '43673', '43684', '44251', '44385',
#         '44820', '44924', '44939', '45076', '45091', '45103', '45203',
#         '45392', '45612', '45704', '45736', '46365', '46368', '46536',
#         '46673', '46769', '47168', '47396', '47569', '47570', '47605',
#         '47741', '47801', '47999', '48409', '48579', '48665', '48809',
#         '49223', '49339', '49386', '49524', '49923', '50164', '51967',
#         '52279', '52512', '52691', '53270', '53759', '53808', '55606',
#         '56198', '56829', '56831', '57631', '57989', '58904', '59589',
#         '59592', '59665', '60337'], dtype=object))

# %% [markdown]
# Now that we have the data for reentry time matched to our extracted GLOBE measurements, we can proceed with further analysis.

# %%
from datetime import datetime, timedelta

# Convert date columns to datetime
df["date"] = pd.to_datetime(df["date"])

reentry_times = {}

with open("outputs/near-reentry-log.txt", "r") as file:
    for line in file:
        parts = line.strip().rstrip(".").split()  # Remove trailing period and split
        if len(parts) > 1 and parts[1].isdigit():
            object_id = parts[1]
            timestamp_str = f"{parts[-2]} {parts[-1]}"  # Extract date and time
            try:
                reentry_times[object_id] = datetime.strptime(timestamp_str, "%Y-%m-%d %H:%M:%S")
            except ValueError as e:
                print(f"Error parsing timestamp for object {object_id}: {timestamp_str} -> {e}")

# Check if parsing succeeded
len(reentry_times)
# Out:
# 241

# %%
# Define time windows before and after reentry (24 and 48 hours)
time_windows = [72]

# Create dictionaries to store time series data
time_series_data = {win: {"before": [], "after": [], "distance": []} for win in time_windows}

# Extract data within the time windows
for obj_id in matching_objects:
    if obj_id in reentry_times:
        reentry_time = reentry_times[obj_id]

        for win in time_windows:
            time_before = reentry_time - timedelta(hours=win)
            time_after = reentry_time + timedelta(hours=win)

            # Select data within the time window
            before_reentry = df[(df["object_id"] == obj_id) & (df["date"] >= time_before) & (df["date"] < reentry_time)]
            after_reentry = df[(df["object_id"] == obj_id) & (df["date"] > reentry_time) & (df["date"] <= time_after)]

            time_series_data[win]["before"].append(before_reentry)
            time_series_data[win]["after"].append(after_reentry)
            time_series_data[win]["distance"].append(df[["distance", "object_id"]][df["object_id"] == obj_id])


# Concatenate results into DataFrames
for win in time_windows:
    time_series_data[win]["before"] = pd.concat(time_series_data[win]["before"])
    time_series_data[win]["after"] = pd.concat(time_series_data[win]["after"])
    time_series_data[win]["distance"] = pd.concat(time_series_data[win]["distance"])

# Display a summary of extracted data
{win: {"before_count": len(time_series_data[win]["before"]), "after_count": len(time_series_data[win]["after"]), "distance_count": len(time_series_data[win]["distance"])} for win in time_windows}
# Out:
# {72: {'before_count': 41480, 'after_count': 41061, 'distance_count': 395259}}

# %%
import random

# Randomly select 5 objects from the matching ones
random_objects = random.sample(list(matching_objects), 5)

random_objects
# Out:
# ['29247', '29512', '55606', '39083', '48409']

# %%
import numpy as np

# Function to compute baseline statistics for numeric columns
def compute_stats(df):
    # Select only numeric columns
    df_numeric = df.select_dtypes(include=[np.number])
    df_numeric.dropna(inplace=True, axis=1, how="all")
    
    stats = {
        "mean": df_numeric.mean(),
        "median": df_numeric.median(),
        "std_dev": df_numeric.std(),
        "IQR": df_numeric.quantile(0.75) - df_numeric.quantile(0.25),
        "range": df_numeric.max() - df_numeric.min()
    }
    return stats

# Prepare a dictionary to store the results by object
baseline_stats_by_object = {}

for win in time_windows:
    for obj_id in matching_objects:
        # Get the data for the current object
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()
        
        if obj_id not in baseline_stats_by_object:
            baseline_stats_by_object[obj_id] = {}
        
        baseline_stats_by_object[obj_id][win] = {
            "before": compute_stats(before_data),
            "after": compute_stats(after_data),
            "distance": distance
        }

baseline_stats_by_object
# Out:
# {'6792': {72: {'before': {'mean': airtempsCurrentTemp                   30.063121
#     distance                             998.315049
#     humiditiesDewpoint                    21.869286
#     humiditiesRelativeHumidityPercent     66.178571
#     dtype: float64,
#     'median': airtempsCurrentTemp                   27.900000
#     distance                             998.651955
#     humiditiesDewpoint                    23.400000
#     humiditiesRelativeHumidityPercent     75.500000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   4.584655
#     distance                              4.000536
#     humiditiesDewpoint                    3.004598
#     humiditiesRelativeHumidityPercent    23.419929
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   8.700
#     distance                              0.000
#     humiditiesDewpoint                    3.475
#     humiditiesRelativeHumidityPercent    44.250
#     dtype: float64,
#     'range': airtempsCurrentTemp                  13.500000
#     distance                             47.503732
#     humiditiesDewpoint                   11.000000
#     humiditiesRelativeHumidityPercent    70.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   26.746099
#     distance                             998.651955
#     humiditiesDewpoint                    22.902837
#     humiditiesRelativeHumidityPercent     80.652482
#     dtype: float64,
#     'median': airtempsCurrentTemp                   25.600000
#     distance                             998.651955
#     humiditiesDewpoint                    22.500000
#     humiditiesRelativeHumidityPercent     84.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                  3.934454e+00
#     distance                             1.140921e-13
#     humiditiesDewpoint                   1.353722e+00
#     humiditiesRelativeHumidityPercent    1.372796e+01
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   5.8
#     distance                              0.0
#     humiditiesDewpoint                    2.4
#     humiditiesRelativeHumidityPercent    17.0
#     dtype: float64,
#     'range': airtempsCurrentTemp                  15.0
#     distance                              0.0
#     humiditiesDewpoint                    5.0
#     humiditiesRelativeHumidityPercent    57.0
#     dtype: float64},
#    'distance': np.float64(998.3148785401547)}},
#  '9911': {72: {'before': {'mean': airtempsCurrentTemp                          24.457190
#     dissolvedoxygensDissolvedOxygenViaKitMgl      3.000000
#     distance                                    894.035173
#     humiditiesDewpoint                           18.555217
#     humiditiesRelativeHumidityPercent            71.154980
#     dtype: float64,
#     'median': airtempsCurrentTemp                          24.600000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      3.000000
#     distance                                    884.937227
#     humiditiesDewpoint                           19.000000
#     humiditiesRelativeHumidityPercent            75.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                          2.539465
#     dissolvedoxygensDissolvedOxygenViaKitMgl          NaN
#     distance                                    33.184867
#     humiditiesDewpoint                           2.516945
#     humiditiesRelativeHumidityPercent           12.869306
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          4.025
#     dissolvedoxygensDissolvedOxygenViaKitMgl     0.000
#     distance                                     0.000
#     humiditiesDewpoint                           1.600
#     humiditiesRelativeHumidityPercent           19.000
#     dtype: float64,
#     'range': airtempsCurrentTemp                          14.000000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      0.000000
#     distance                                    256.758927
#     humiditiesDewpoint                           22.700000
#     humiditiesRelativeHumidityPercent            69.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                          24.178630
#     dissolvedoxygensDissolvedOxygenViaKitMgl      8.458333
#     distance                                    895.079751
#     humiditiesDewpoint                           17.507704
#     humiditiesRelativeHumidityPercent            67.293161
#     dtype: float64,
#     'median': airtempsCurrentTemp                          24.050000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      8.950000
#     distance                                    884.937227
#     humiditiesDewpoint                           16.600000
#     humiditiesRelativeHumidityPercent            67.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                          2.120127
#     dissolvedoxygensDissolvedOxygenViaKitMgl     1.537666
#     distance                                    37.497002
#     humiditiesDewpoint                           2.596953
#     humiditiesRelativeHumidityPercent           12.533490
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          3.1000
#     dissolvedoxygensDissolvedOxygenViaKitMgl     2.3875
#     distance                                     0.0000
#     humiditiesDewpoint                           4.6000
#     humiditiesRelativeHumidityPercent           14.7250
#     dtype: float64,
#     'range': airtempsCurrentTemp                          11.600000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      3.500000
#     distance                                    393.567983
#     humiditiesDewpoint                           24.100000
#     humiditiesRelativeHumidityPercent            85.000000
#     dtype: float64},
#    'distance': np.float64(920.3301355824387)}},
#  '25274': {72: {'before': {'mean': Series([], dtype: float64),
#     'median': Series([], dtype: float64),
#     'std_dev': Series([], dtype: float64),
#     'IQR': Series([], dtype: float64),
#     'range': Series([], dtype: float64)},
#    'after': {'mean': Series([], dtype: float64),
#     'median': Series([], dtype: float64),
#     'std_dev': Series([], dtype: float64),
#     'IQR': Series([], dtype: float64),
#     'range': Series([], dtype: float64)},
#    'distance': np.float64(532.0815903147353)}},
#  '25469': {72: {'before': {'mean': airtempsCurrentTemp                   24.922143
#     distance                             993.801202
#     humiditiesDewpoint                    21.418571
#     humiditiesRelativeHumidityPercent     81.185714
#     dtype: float64,
#     'median': airtempsCurrentTemp                   24.100000
#     distance                             993.801202
#     humiditiesDewpoint                    21.500000
#     humiditiesRelativeHumidityPercent     85.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                  2.569720e+00
#     distance                             1.140951e-13
#     humiditiesDewpoint                   7.676542e-01
#     humiditiesRelativeHumidityPercent    9.051877e+00
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   4.550
#     distance                              0.000
#     humiditiesDewpoint                    1.325
#     humiditiesRelativeHumidityPercent    16.000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   8.5
#     distance                              0.0
#     humiditiesDewpoint                    3.2
#     humiditiesRelativeHumidityPercent    28.0
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   23.463964
#     distance                             993.801202
#     humiditiesDewpoint                    21.200901
#     humiditiesRelativeHumidityPercent     87.171171
#     dtype: float64,
#     'median': airtempsCurrentTemp                   22.900000
#     distance                             993.801202
#     humiditiesDewpoint                    21.200000
#     humiditiesRelativeHumidityPercent     88.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                  2.016603
#     distance                             0.000000
#     humiditiesDewpoint                   0.920227
#     humiditiesRelativeHumidityPercent    6.331557
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                  3.1
#     distance                             0.0
#     humiditiesDewpoint                   1.4
#     humiditiesRelativeHumidityPercent    9.5
#     dtype: float64,
#     'range': airtempsCurrentTemp                   7.5
#     distance                              0.0
#     humiditiesDewpoint                    3.7
#     humiditiesRelativeHumidityPercent    25.0
#     dtype: float64},
#    'distance': np.float64(993.8012023101774)}},
#  '26476': {72: {'before': {'mean': airtempsCurrentTemp                   26.000000
#     distance                             966.466575
#     humiditiesDewpoint                    19.928472
#     humiditiesRelativeHumidityPercent     71.583333
#     dtype: float64,
#     'median': airtempsCurrentTemp                   24.400000
#     distance                             966.466575
#     humiditiesDewpoint                    19.800000
#     humiditiesRelativeHumidityPercent     78.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   4.908762
#     distance                              0.000000
#     humiditiesDewpoint                    2.293794
#     humiditiesRelativeHumidityPercent    17.658176
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   9.45
#     distance                              0.00
#     humiditiesDewpoint                    3.80
#     humiditiesRelativeHumidityPercent    27.25
#     dtype: float64,
#     'range': airtempsCurrentTemp                  15.4
#     distance                              0.0
#     humiditiesDewpoint                    9.7
#     humiditiesRelativeHumidityPercent    64.0
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   22.983088
#     distance                             966.466575
#     humiditiesDewpoint                    11.270588
#     humiditiesRelativeHumidityPercent     52.823529
#     dtype: float64,
#     'median': airtempsCurrentTemp                   21.650000
#     distance                             966.466575
#     humiditiesDewpoint                    11.850000
#     humiditiesRelativeHumidityPercent     45.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   5.549502
#     distance                              0.000000
#     humiditiesDewpoint                    4.554186
#     humiditiesRelativeHumidityPercent    24.298417
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   9.800
#     distance                              0.000
#     humiditiesDewpoint                    7.825
#     humiditiesRelativeHumidityPercent    49.000
#     dtype: float64,
#     'range': airtempsCurrentTemp                  20.2
#     distance                              0.0
#     humiditiesDewpoint                   19.1
#     humiditiesRelativeHumidityPercent    75.0
#     dtype: float64},
#    'distance': np.float64(966.6090433319285)}},
#  '26640': {72: {'before': {'mean': airtempsCurrentTemp                   29.600000
#     distance                             449.570038
#     humiditiesDewpoint                    14.466667
#     humiditiesRelativeHumidityPercent     40.000000
#     dtype: float64,
#     'median': airtempsCurrentTemp                   32.000000
#     distance                             478.336686
#     humiditiesDewpoint                    19.100000
#     humiditiesRelativeHumidityPercent     51.500000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   4.860041
#     distance                             39.390355
#     humiditiesDewpoint                    8.025169
#     humiditiesRelativeHumidityPercent    19.918584
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   6.800000
#     distance                             71.916619
#     humiditiesDewpoint                    6.950000
#     humiditiesRelativeHumidityPercent    17.250000
#     dtype: float64,
#     'range': airtempsCurrentTemp                  11.200000
#     distance                             71.916619
#     humiditiesDewpoint                   13.900000
#     humiditiesRelativeHumidityPercent    34.500000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   28.940000
#     distance                             449.570038
#     humiditiesDewpoint                    15.766667
#     humiditiesRelativeHumidityPercent     35.466667
#     dtype: float64,
#     'median': airtempsCurrentTemp                   29.000000
#     distance                             478.336686
#     humiditiesDewpoint                    16.200000
#     humiditiesRelativeHumidityPercent     35.800000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   2.075572
#     distance                             39.390355
#     humiditiesDewpoint                    0.750555
#     humiditiesRelativeHumidityPercent     0.577350
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   4.100000
#     distance                             71.916619
#     humiditiesDewpoint                    0.650000
#     humiditiesRelativeHumidityPercent     0.500000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   4.200000
#     distance                             71.916619
#     humiditiesDewpoint                    1.300000
#     humiditiesRelativeHumidityPercent     1.000000
#     dtype: float64},
#    'distance': np.float64(459.89652696332854)}},
#  '26692': {72: {'before': {'mean': airtempsCurrentTemp                   26.728571
#     distance                             860.320417
#     humiditiesDewpoint                    21.300000
#     humiditiesRelativeHumidityPercent     65.450000
#     dtype: float64,
#     'median': airtempsCurrentTemp                   28.000000
#     distance                             837.812473
#     humiditiesDewpoint                    21.300000
#     humiditiesRelativeHumidityPercent     65.450000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   2.474345
#     distance                             33.880513
#     humiditiesDewpoint                    8.626703
#     humiditiesRelativeHumidityPercent    28.920667
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   3.100000
#     distance                             58.158659
#     humiditiesDewpoint                    6.100000
#     humiditiesRelativeHumidityPercent    20.450000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   7.100000
#     distance                             75.079027
#     humiditiesDewpoint                   12.200000
#     humiditiesRelativeHumidityPercent    40.900000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp     30.050000
#     distance               881.431467
#     dtype: float64,
#     'median': airtempsCurrentTemp     30.100000
#     distance               895.971132
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp     0.500000
#     distance               29.079329
#     dtype: float64,
#     'IQR': airtempsCurrentTemp     0.450000
#     distance               14.539665
#     dtype: float64,
#     'range': airtempsCurrentTemp     1.200000
#     distance               58.158659
#     dtype: float64},
#    'distance': np.float64(883.5999578504238)}},
#  '27613': {72: {'before': {'mean': airtempsCurrentTemp     20.133333
#     distance               386.999486
#     dtype: float64,
#     'median': airtempsCurrentTemp     20.200000
#     distance               386.999486
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    0.503322
#     distance               0.000000
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    0.5
#     distance               0.0
#     dtype: float64,
#     'range': airtempsCurrentTemp    1.0
#     distance               0.0
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp     18.666667
#     distance               386.999486
#     dtype: float64,
#     'median': airtempsCurrentTemp     19.800000
#     distance               386.999486
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    2.872862
#     distance               0.000000
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    2.7
#     distance               0.0
#     dtype: float64,
#     'range': airtempsCurrentTemp    5.4
#     distance               0.0
#     dtype: float64},
#    'distance': np.float64(386.9994860250063)}},
#  '28130': {72: {'before': {'mean': airtempsCurrentTemp                   30.108333
#     distance                             779.254485
#     humiditiesDewpoint                    24.072464
#     humiditiesRelativeHumidityPercent     75.330290
#     dtype: float64,
#     'median': airtempsCurrentTemp                   30.550000
#     distance                             804.786768
#     humiditiesDewpoint                    24.400000
#     humiditiesRelativeHumidityPercent     76.750000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    3.776564
#     distance                             149.407650
#     humiditiesDewpoint                     3.537139
#     humiditiesRelativeHumidityPercent     12.077006
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    4.350000
#     distance                             196.011784
#     humiditiesDewpoint                     3.025000
#     humiditiesRelativeHumidityPercent     15.700000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   20.000000
#     distance                             478.001077
#     humiditiesDewpoint                    16.550000
#     humiditiesRelativeHumidityPercent     50.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   30.743333
#     distance                             777.741056
#     humiditiesDewpoint                    24.419231
#     humiditiesRelativeHumidityPercent     74.698077
#     dtype: float64,
#     'median': airtempsCurrentTemp                   31.125000
#     distance                             795.827215
#     humiditiesDewpoint                    24.250000
#     humiditiesRelativeHumidityPercent     72.300000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    2.287211
#     distance                             142.649095
#     humiditiesDewpoint                     2.088460
#     humiditiesRelativeHumidityPercent     12.760774
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    2.900000
#     distance                             174.115383
#     humiditiesDewpoint                     2.887500
#     humiditiesRelativeHumidityPercent     17.256250
#     dtype: float64,
#     'range': airtempsCurrentTemp                    8.500000
#     distance                             466.470169
#     humiditiesDewpoint                     8.900000
#     humiditiesRelativeHumidityPercent     53.400000
#     dtype: float64},
#    'distance': np.float64(756.9085853308869)}},
#  '28418': {72: {'before': {'mean': airtempsCurrentTemp                   31.185185
#     distance                             400.735068
#     humiditiesDewpoint                    17.180000
#     humiditiesRelativeHumidityPercent     58.800000
#     dtype: float64,
#     'median': airtempsCurrentTemp                   32.000000
#     distance                             177.738991
#     humiditiesDewpoint                    17.200000
#     humiditiesRelativeHumidityPercent     54.400000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    2.759933
#     distance                             333.466890
#     humiditiesDewpoint                     1.779607
#     humiditiesRelativeHumidityPercent     16.697305
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    2.750000
#     distance                             689.782227
#     humiditiesDewpoint                     1.300000
#     humiditiesRelativeHumidityPercent     15.200000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   13.300000
#     distance                             781.557767
#     humiditiesDewpoint                     4.800000
#     humiditiesRelativeHumidityPercent     43.600000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   31.696154
#     distance                             346.569012
#     humiditiesDewpoint                    16.133333
#     humiditiesRelativeHumidityPercent     44.333333
#     dtype: float64,
#     'median': airtempsCurrentTemp                   31.875000
#     distance                             173.944808
#     humiditiesDewpoint                    16.800000
#     humiditiesRelativeHumidityPercent     42.600000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    1.464030
#     distance                             306.071369
#     humiditiesDewpoint                     1.422439
#     humiditiesRelativeHumidityPercent      4.838733
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    1.712500
#     distance                             156.141572
#     humiditiesDewpoint                     1.300000
#     humiditiesRelativeHumidityPercent      4.600000
#     dtype: float64,
#     'range': airtempsCurrentTemp                    7.000000
#     distance                             784.223912
#     humiditiesDewpoint                     2.600000
#     humiditiesRelativeHumidityPercent      9.200000
#     dtype: float64},
#    'distance': np.float64(380.39974443315833)}},
#  '28641': {72: {'before': {'mean': airtempsCurrentTemp     38.666667
#     distance               672.987537
#     dtype: float64,
#     'median': airtempsCurrentTemp     38.000000
#     distance               675.318546
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    2.081666
#     distance               4.037426
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    2.000000
#     distance               3.496513
#     dtype: float64,
#     'range': airtempsCurrentTemp    4.000000
#     distance               6.993026
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp     39.250000
#     distance               672.884128
#     dtype: float64,
#     'median': airtempsCurrentTemp     39.500000
#     distance               675.318546
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    0.957427
#     distance               4.868835
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    1.250000
#     distance               2.434417
#     dtype: float64,
#     'range': airtempsCurrentTemp    2.000000
#     distance               9.737669
#     dtype: float64},
#    'distance': np.float64(669.5040839130005)}},
#  '28921': {72: {'before': {'mean': airtempsCurrentTemp                   29.935409
#     distance                             525.866213
#     humiditiesDewpoint                    12.609091
#     humiditiesRelativeHumidityPercent     41.836364
#     dtype: float64,
#     'median': airtempsCurrentTemp                   30.000000
#     distance                             528.471935
#     humiditiesDewpoint                    11.500000
#     humiditiesRelativeHumidityPercent     30.200000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    2.777946
#     distance                             177.831168
#     humiditiesDewpoint                     7.564847
#     humiditiesRelativeHumidityPercent     23.620215
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    1.916667
#     distance                             258.299633
#     humiditiesDewpoint                    12.300000
#     humiditiesRelativeHumidityPercent     38.400000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   14.000000
#     distance                             688.767521
#     humiditiesDewpoint                    21.000000
#     humiditiesRelativeHumidityPercent     60.500000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   30.061398
#     distance                             537.749107
#     humiditiesDewpoint                    12.800000
#     humiditiesRelativeHumidityPercent     42.886364
#     dtype: float64,
#     'median': airtempsCurrentTemp                   30.281250
#     distance                             541.741391
#     humiditiesDewpoint                    13.200000
#     humiditiesRelativeHumidityPercent     39.600000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    2.405053
#     distance                             160.122607
#     humiditiesDewpoint                     7.497866
#     humiditiesRelativeHumidityPercent     21.245471
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    2.833333
#     distance                             185.652058
#     humiditiesDewpoint                    12.050000
#     humiditiesRelativeHumidityPercent     31.725000
#     dtype: float64,
#     'range': airtempsCurrentTemp                    9.000000
#     distance                             672.882919
#     humiditiesDewpoint                    20.500000
#     humiditiesRelativeHumidityPercent     56.000000
#     dtype: float64},
#    'distance': np.float64(540.7440344011051)}},
#  '29247': {72: {'before': {'mean': airtempsCurrentTemp     15.227273
#     distance               388.686764
#     dtype: float64,
#     'median': airtempsCurrentTemp     15.000000
#     distance               416.669392
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp      1.965752
#     distance               133.519645
#     dtype: float64,
#     'IQR': airtempsCurrentTemp      1.450000
#     distance               211.320291
#     dtype: float64,
#     'range': airtempsCurrentTemp      7.800000
#     distance               328.786232
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp     13.6500
#     distance               410.5843
#     dtype: float64,
#     'median': airtempsCurrentTemp     13.900000
#     distance               424.515911
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp      1.504327
#     distance               173.126940
#     dtype: float64,
#     'IQR': airtempsCurrentTemp      1.625000
#     distance               318.337524
#     dtype: float64,
#     'range': airtempsCurrentTemp      4.000000
#     distance               328.786232
#     dtype: float64},
#    'distance': np.float64(413.4173284101769)}},
#  '29386': {72: {'before': {'mean': airtempsCurrentTemp                    41.811111
#     distance                             1130.534268
#     humiditiesDewpoint                     32.666667
#     humiditiesRelativeHumidityPercent      64.000000
#     dtype: float64,
#     'median': airtempsCurrentTemp                    40.800000
#     distance                             1138.723838
#     humiditiesDewpoint                     32.900000
#     humiditiesRelativeHumidityPercent      62.500000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   3.993806
#     distance                             19.088042
#     humiditiesDewpoint                    3.922584
#     humiditiesRelativeHumidityPercent    16.309506
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   7.050000
#     distance                             24.031587
#     humiditiesDewpoint                    5.700000
#     humiditiesRelativeHumidityPercent    26.250000
#     dtype: float64,
#     'range': airtempsCurrentTemp                  10.850000
#     distance                             51.136017
#     humiditiesDewpoint                   10.000000
#     humiditiesRelativeHumidityPercent    39.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                    38.383333
#     distance                             1131.086856
#     humiditiesDewpoint                     33.350000
#     humiditiesRelativeHumidityPercent      70.666667
#     dtype: float64,
#     'median': airtempsCurrentTemp                    38.000000
#     distance                             1127.687415
#     humiditiesDewpoint                     33.850000
#     humiditiesRelativeHumidityPercent      70.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   4.087787
#     distance                             14.764108
#     humiditiesDewpoint                    2.979765
#     humiditiesRelativeHumidityPercent    17.795130
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   4.400000
#     distance                             15.776138
#     humiditiesDewpoint                    4.825000
#     humiditiesRelativeHumidityPercent    30.500000
#     dtype: float64,
#     'range': airtempsCurrentTemp                  13.200000
#     distance                             51.136017
#     humiditiesDewpoint                    6.800000
#     humiditiesRelativeHumidityPercent    40.000000
#     dtype: float64},
#    'distance': np.float64(1132.2895250906092)}},
#  '29482': {72: {'before': {'mean': airtempsCurrentTemp                          17.249001
#     dissolvedoxygensDissolvedOxygenViaKitMgl      8.144444
#     distance                                    920.723071
#     humiditiesDewpoint                           10.564681
#     humiditiesRelativeHumidityPercent            69.721552
#     dtype: float64,
#     'median': airtempsCurrentTemp                           17.166667
#     dissolvedoxygensDissolvedOxygenViaKitMgl       8.000000
#     distance                                    1014.564879
#     humiditiesDewpoint                            10.627778
#     humiditiesRelativeHumidityPercent             71.866667
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                           4.474298
#     dissolvedoxygensDissolvedOxygenViaKitMgl      3.610786
#     distance                                    212.758509
#     humiditiesDewpoint                            2.500049
#     humiditiesRelativeHumidityPercent            17.952596
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          7.567111
#     dissolvedoxygensDissolvedOxygenViaKitMgl     2.700000
#     distance                                    34.072311
#     humiditiesDewpoint                           3.661111
#     humiditiesRelativeHumidityPercent           29.213889
#     dtype: float64,
#     'range': airtempsCurrentTemp                          18.000000
#     dissolvedoxygensDissolvedOxygenViaKitMgl     11.800000
#     distance                                    985.144922
#     humiditiesDewpoint                           15.900000
#     humiditiesRelativeHumidityPercent            78.555556
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                          15.029613
#     dissolvedoxygensDissolvedOxygenViaKitMgl      9.140909
#     distance                                    928.232996
#     humiditiesDewpoint                           12.532839
#     humiditiesRelativeHumidityPercent            90.032645
#     dtype: float64,
#     'median': airtempsCurrentTemp                           14.400000
#     dissolvedoxygensDissolvedOxygenViaKitMgl       9.150000
#     distance                                    1014.564879
#     humiditiesDewpoint                            13.277778
#     humiditiesRelativeHumidityPercent             98.222222
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                           3.991843
#     dissolvedoxygensDissolvedOxygenViaKitMgl      3.106833
#     distance                                    189.516910
#     humiditiesDewpoint                            2.471960
#     humiditiesRelativeHumidityPercent            14.568260
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          5.233124
#     dissolvedoxygensDissolvedOxygenViaKitMgl     1.800000
#     distance                                    54.510723
#     humiditiesDewpoint                           3.257143
#     humiditiesRelativeHumidityPercent           11.844444
#     dtype: float64,
#     'range': airtempsCurrentTemp                          20.600000
#     dissolvedoxygensDissolvedOxygenViaKitMgl     12.000000
#     distance                                    985.144922
#     humiditiesDewpoint                           22.600000
#     humiditiesRelativeHumidityPercent            71.166667
#     dtype: float64},
#    'distance': np.float64(929.43116961109)}},
#  '29512': {72: {'before': {'mean': airtempsCurrentTemp      34.000000
#     distance               1049.827372
#     dtype: float64,
#     'median': airtempsCurrentTemp      34.000000
#     distance               1049.827372
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp   NaN
#     distance              NaN
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    0.0
#     distance               0.0
#     dtype: float64,
#     'range': airtempsCurrentTemp    0.0
#     distance               0.0
#     dtype: float64},
#    'after': {'mean': Series([], dtype: float64),
#     'median': Series([], dtype: float64),
#     'std_dev': Series([], dtype: float64),
#     'IQR': Series([], dtype: float64),
#     'range': Series([], dtype: float64)},
#    'distance': np.float64(1049.8273715901362)}},
#  '29664': {72: {'before': {'mean': airtempsCurrentTemp     -18.333333
#     distance               1005.276678
#     dtype: float64,
#     'median': airtempsCurrentTemp     -17.000000
#     distance               1005.276678
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    8.082904
#     distance               0.000000
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    8.0
#     distance               0.0
#     dtype: float64,
#     'range': airtempsCurrentTemp    16.0
#     distance                0.0
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp     -12.333333
#     distance               1005.276678
#     dtype: float64,
#     'median': airtempsCurrentTemp      -9.000000
#     distance               1005.276678
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    7.571878
#     distance               0.000000
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    7.0
#     distance               0.0
#     dtype: float64,
#     'range': airtempsCurrentTemp    14.0
#     distance                0.0
#     dtype: float64},
#    'distance': np.float64(1005.276677744487)}},
#  '32751': {72: {'before': {'mean': airtempsCurrentTemp                            24.111150
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      7.000000
#     distance                                      971.516993
#     humiditiesDewpoint                             11.648709
#     humiditiesRelativeHumidityPercent              47.861150
#     dtype: float64,
#     'median': airtempsCurrentTemp                             22.400000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl       7.000000
#     distance                                      1136.515799
#     humiditiesDewpoint                              10.500000
#     humiditiesRelativeHumidityPercent               48.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                             5.930077
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      1.414214
#     distance                                      260.097505
#     humiditiesDewpoint                              6.712848
#     humiditiesRelativeHumidityPercent              13.945114
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                             7.900000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      1.000000
#     distance                                      365.665563
#     humiditiesDewpoint                              5.150000
#     humiditiesRelativeHumidityPercent              15.850000
#     dtype: float64,
#     'range': airtempsCurrentTemp                            27.800000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      2.000000
#     distance                                      920.663757
#     humiditiesDewpoint                             33.850000
#     humiditiesRelativeHumidityPercent              73.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                          21.148452
#     dissolvedoxygensDissolvedOxygenViaKitMgl      6.400000
#     dissolvedoxygensSalinityViaDokitPpt          42.900000
#     distance                                    996.379854
#     humiditiesDewpoint                           12.414915
#     humiditiesRelativeHumidityPercent            59.042628
#     dtype: float64,
#     'median': airtempsCurrentTemp                           20.360000
#     dissolvedoxygensDissolvedOxygenViaKitMgl       6.200000
#     dissolvedoxygensSalinityViaDokitPpt           42.900000
#     distance                                    1136.515799
#     humiditiesDewpoint                            11.650000
#     humiditiesRelativeHumidityPercent             60.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                           6.009927
#     dissolvedoxygensDissolvedOxygenViaKitMgl      1.509967
#     dissolvedoxygensSalinityViaDokitPpt                NaN
#     distance                                    267.316791
#     humiditiesDewpoint                            5.664310
#     humiditiesRelativeHumidityPercent            14.564103
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                           6.000000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      1.500000
#     dissolvedoxygensSalinityViaDokitPpt           0.000000
#     distance                                    396.559819
#     humiditiesDewpoint                            3.800000
#     humiditiesRelativeHumidityPercent            16.750000
#     dtype: float64,
#     'range': airtempsCurrentTemp                           31.600000
#     dissolvedoxygensDissolvedOxygenViaKitMgl       3.000000
#     dissolvedoxygensSalinityViaDokitPpt            0.000000
#     distance                                    1112.977204
#     humiditiesDewpoint                            35.200000
#     humiditiesRelativeHumidityPercent             77.000000
#     dtype: float64},
#    'distance': np.float64(979.8716124964284)}},
#  '32765': {72: {'before': {'mean': airtempsCurrentTemp                   31.219545
#     distance                             772.628688
#     humiditiesDewpoint                    18.246899
#     humiditiesRelativeHumidityPercent     46.175194
#     dtype: float64,
#     'median': airtempsCurrentTemp                   32.000000
#     distance                             750.407422
#     humiditiesDewpoint                    19.350000
#     humiditiesRelativeHumidityPercent     43.500000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    5.715867
#     distance                             195.436654
#     humiditiesDewpoint                     7.890214
#     humiditiesRelativeHumidityPercent     14.778182
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    7.500000
#     distance                             375.965343
#     humiditiesDewpoint                    10.683333
#     humiditiesRelativeHumidityPercent     14.500000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   26.650000
#     distance                             734.249641
#     humiditiesDewpoint                    33.100000
#     humiditiesRelativeHumidityPercent     79.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   31.318056
#     distance                             782.390440
#     humiditiesDewpoint                    18.504054
#     humiditiesRelativeHumidityPercent     47.959459
#     dtype: float64,
#     'median': airtempsCurrentTemp                   31.25000
#     distance                             758.42116
#     humiditiesDewpoint                    18.65000
#     humiditiesRelativeHumidityPercent     45.00000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    5.420453
#     distance                             197.032099
#     humiditiesDewpoint                     8.671314
#     humiditiesRelativeHumidityPercent     16.418871
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    6.300000
#     distance                             354.002984
#     humiditiesDewpoint                    10.700000
#     humiditiesRelativeHumidityPercent     20.000000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   28.900000
#     distance                             734.249641
#     humiditiesDewpoint                    36.700000
#     humiditiesRelativeHumidityPercent     74.666667
#     dtype: float64},
#    'distance': np.float64(788.7165401779511)}},
#  '34603': {72: {'before': {'mean': airtempsCurrentTemp                            17.463171
#     dissolvedoxygensDissolvedOxygenViaKitMgl        8.166667
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      8.000000
#     distance                                      912.932087
#     humiditiesDewpoint                              1.209457
#     humiditiesRelativeHumidityPercent              37.252779
#     dtype: float64,
#     'median': airtempsCurrentTemp                            17.90000
#     dissolvedoxygensDissolvedOxygenViaKitMgl        8.00000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      8.00000
#     distance                                      931.83675
#     humiditiesDewpoint                              0.70000
#     humiditiesRelativeHumidityPercent              36.00000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                            4.718117
#     dissolvedoxygensDissolvedOxygenViaKitMgl       2.303801
#     dissolvedoxygensDissolvedOxygenViaProbeMgl          NaN
#     distance                                      76.999844
#     humiditiesDewpoint                             4.010052
#     humiditiesRelativeHumidityPercent             15.986524
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                            8.4
#     dissolvedoxygensDissolvedOxygenViaKitMgl       2.2
#     dissolvedoxygensDissolvedOxygenViaProbeMgl     0.0
#     distance                                       0.0
#     humiditiesDewpoint                             5.8
#     humiditiesRelativeHumidityPercent             23.0
#     dtype: float64,
#     'range': airtempsCurrentTemp                            20.100000
#     dissolvedoxygensDissolvedOxygenViaKitMgl        7.900000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      0.000000
#     distance                                      670.623688
#     humiditiesDewpoint                             38.100000
#     humiditiesRelativeHumidityPercent              89.300000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                          14.654503
#     dissolvedoxygensDissolvedOxygenViaKitMgl      6.557143
#     distance                                    917.495563
#     humiditiesDewpoint                            0.266095
#     humiditiesRelativeHumidityPercent            41.328581
#     dtype: float64,
#     'median': airtempsCurrentTemp                          14.97500
#     dissolvedoxygensDissolvedOxygenViaKitMgl      7.00000
#     distance                                    931.83675
#     humiditiesDewpoint                            0.20000
#     humiditiesRelativeHumidityPercent            43.00000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                          5.405329
#     dissolvedoxygensDissolvedOxygenViaKitMgl     4.860678
#     distance                                    61.002435
#     humiditiesDewpoint                           3.494199
#     humiditiesRelativeHumidityPercent           16.270833
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          9.375
#     dissolvedoxygensDissolvedOxygenViaKitMgl     7.050
#     distance                                     0.000
#     humiditiesDewpoint                           3.900
#     humiditiesRelativeHumidityPercent           26.500
#     dtype: float64,
#     'range': airtempsCurrentTemp                          20.700000
#     dissolvedoxygensDissolvedOxygenViaKitMgl     13.000000
#     distance                                    582.661886
#     humiditiesDewpoint                           23.100000
#     humiditiesRelativeHumidityPercent            81.000000
#     dtype: float64},
#    'distance': np.float64(913.5099395747033)}},
#  '36749': {72: {'before': {'mean': airtempsCurrentTemp                          24.280133
#     dissolvedoxygensDissolvedOxygenViaKitMgl      8.250000
#     distance                                    404.843763
#     humiditiesDewpoint                           16.206996
#     humiditiesRelativeHumidityPercent            64.191667
#     dtype: float64,
#     'median': airtempsCurrentTemp                          24.50000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      9.00000
#     distance                                    169.69181
#     humiditiesDewpoint                           16.20000
#     humiditiesRelativeHumidityPercent            63.00000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                           5.316085
#     dissolvedoxygensDissolvedOxygenViaKitMgl      2.221325
#     distance                                    299.673849
#     humiditiesDewpoint                            2.348639
#     humiditiesRelativeHumidityPercent            20.748215
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          10.045833
#     dissolvedoxygensDissolvedOxygenViaKitMgl      0.750000
#     distance                                    528.635013
#     humiditiesDewpoint                            2.508333
#     humiditiesRelativeHumidityPercent            40.358333
#     dtype: float64,
#     'range': airtempsCurrentTemp                          21.864706
#     dissolvedoxygensDissolvedOxygenViaKitMgl      7.000000
#     distance                                    976.265629
#     humiditiesDewpoint                           38.300000
#     humiditiesRelativeHumidityPercent            89.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                          22.651158
#     dissolvedoxygensDissolvedOxygenViaKitMgl      8.055556
#     distance                                    408.473757
#     humiditiesDewpoint                           17.027021
#     humiditiesRelativeHumidityPercent            72.781184
#     dtype: float64,
#     'median': airtempsCurrentTemp                          22.20000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      8.60000
#     distance                                    169.69181
#     humiditiesDewpoint                           17.50000
#     humiditiesRelativeHumidityPercent            75.00000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                           4.446105
#     dissolvedoxygensDissolvedOxygenViaKitMgl      2.954704
#     distance                                    302.817085
#     humiditiesDewpoint                            2.496092
#     humiditiesRelativeHumidityPercent            17.303586
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                           7.500000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      3.200000
#     distance                                    537.518024
#     humiditiesDewpoint                            2.662500
#     humiditiesRelativeHumidityPercent            31.455227
#     dtype: float64,
#     'range': airtempsCurrentTemp                          21.800000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      9.100000
#     distance                                    976.265629
#     humiditiesDewpoint                           32.200000
#     humiditiesRelativeHumidityPercent            88.900000
#     dtype: float64},
#    'distance': np.float64(404.00759453698385)}},
#  '38037': {72: {'before': {'mean': airtempsCurrentTemp                          -0.376540
#     dissolvedoxygensDissolvedOxygenViaKitMgl      9.340000
#     distance                                    812.601069
#     humiditiesDewpoint                           -3.558393
#     humiditiesRelativeHumidityPercent            79.867753
#     dtype: float64,
#     'median': airtempsCurrentTemp                           0.900000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      9.000000
#     distance                                    841.792694
#     humiditiesDewpoint                           -3.600000
#     humiditiesRelativeHumidityPercent            81.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                          4.072054
#     dissolvedoxygensDissolvedOxygenViaKitMgl     0.614817
#     distance                                    83.207251
#     humiditiesDewpoint                           3.306224
#     humiditiesRelativeHumidityPercent           10.514673
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          3.10
#     dissolvedoxygensDissolvedOxygenViaKitMgl     1.00
#     distance                                     0.00
#     humiditiesDewpoint                           2.55
#     humiditiesRelativeHumidityPercent           18.00
#     dtype: float64,
#     'range': airtempsCurrentTemp                          20.900000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      1.300000
#     distance                                    462.452120
#     humiditiesDewpoint                           18.166667
#     humiditiesRelativeHumidityPercent            43.333333
# ...
#     'IQR': airtempsCurrentTemp                          4.975000
#     dissolvedoxygensDissolvedOxygenViaKitMgl     1.650000
#     dissolvedoxygensSalinityViaDokitPpt          0.000000
#     distance                                    86.137053
#     humiditiesDewpoint                           3.550000
#     humiditiesRelativeHumidityPercent           28.500000
#     dtype: float64,
#     'range': airtempsCurrentTemp                          16.588889
#     dissolvedoxygensDissolvedOxygenViaKitMgl      4.750000
#     dissolvedoxygensSalinityViaDokitPpt           0.000000
#     distance                                    578.332666
#     humiditiesDewpoint                           14.100000
#     humiditiesRelativeHumidityPercent            62.444444
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                            28.484682
#     dissolvedoxygensDissolvedOxygenViaKitMgl        8.300000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      8.200000
#     dissolvedoxygensSalinityViaDokitPpt            34.666667
#     distance                                      281.192159
#     humiditiesDewpoint                             20.073447
#     humiditiesRelativeHumidityPercent              61.175267
#     dtype: float64,
#     'median': airtempsCurrentTemp                            29.700000
#     dissolvedoxygensDissolvedOxygenViaKitMgl        8.900000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      8.200000
#     dissolvedoxygensSalinityViaDokitPpt            34.666667
#     distance                                      244.385401
#     humiditiesDewpoint                             20.314286
#     humiditiesRelativeHumidityPercent              60.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                             3.365750
#     dissolvedoxygensDissolvedOxygenViaKitMgl        1.546322
#     dissolvedoxygensDissolvedOxygenViaProbeMgl           NaN
#     dissolvedoxygensSalinityViaDokitPpt                  NaN
#     distance                                      113.696204
#     humiditiesDewpoint                              1.783649
#     humiditiesRelativeHumidityPercent              11.970541
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                            4.200000
#     dissolvedoxygensDissolvedOxygenViaKitMgl       1.450000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl     0.000000
#     dissolvedoxygensSalinityViaDokitPpt            0.000000
#     distance                                      86.137053
#     humiditiesDewpoint                             2.950000
#     humiditiesRelativeHumidityPercent             15.000000
#     dtype: float64,
#     'range': airtempsCurrentTemp                            13.894444
#     dissolvedoxygensDissolvedOxygenViaKitMgl        4.600000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      0.000000
#     dissolvedoxygensSalinityViaDokitPpt             0.000000
#     distance                                      613.489495
#     humiditiesDewpoint                              9.000000
#     humiditiesRelativeHumidityPercent              54.333333
#     dtype: float64},
#    'distance': np.float64(286.5901343056066)}},
#  '57989': {72: {'before': {'mean': airtempsCurrentTemp                          22.000000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      6.625000
#     distance                                    610.061601
#     humiditiesDewpoint                           21.300000
#     humiditiesRelativeHumidityPercent            96.000000
#     dtype: float64,
#     'median': airtempsCurrentTemp                          22.00000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      6.75000
#     distance                                    550.68958
#     humiditiesDewpoint                           21.30000
#     humiditiesRelativeHumidityPercent            96.00000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                                NaN
#     dissolvedoxygensDissolvedOxygenViaKitMgl      0.478714
#     distance                                    134.103749
#     humiditiesDewpoint                                 NaN
#     humiditiesRelativeHumidityPercent                  NaN
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                         0.000000
#     dissolvedoxygensDissolvedOxygenViaKitMgl    0.625000
#     distance                                    2.236024
#     humiditiesDewpoint                          0.000000
#     humiditiesRelativeHumidityPercent           0.000000
#     dtype: float64,
#     'range': airtempsCurrentTemp                           0.000000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      1.000000
#     distance                                    301.327373
#     humiditiesDewpoint                            0.000000
#     humiditiesRelativeHumidityPercent             0.000000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   30.433333
#     distance                             741.212938
#     humiditiesDewpoint                    25.166667
#     humiditiesRelativeHumidityPercent     74.766667
#     dtype: float64,
#     'median': airtempsCurrentTemp                   32.000000
#     distance                             849.944656
#     humiditiesDewpoint                    25.300000
#     humiditiesRelativeHumidityPercent     70.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                    3.894012
#     distance                             188.328859
#     humiditiesDewpoint                     0.907377
#     humiditiesRelativeHumidityPercent     19.296718
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                    3.650000
#     distance                             163.097577
#     humiditiesDewpoint                     0.900000
#     humiditiesRelativeHumidityPercent     18.850000
#     dtype: float64,
#     'range': airtempsCurrentTemp                    7.300000
#     distance                             326.195153
#     humiditiesDewpoint                     1.800000
#     humiditiesRelativeHumidityPercent     37.700000
#     dtype: float64},
#    'distance': np.float64(748.0586729122813)}},
#  '58904': {72: {'before': {'mean': airtempsCurrentTemp                   15.016958
#     distance                             596.440257
#     humiditiesDewpoint                    11.870120
#     humiditiesRelativeHumidityPercent     81.859018
#     dtype: float64,
#     'median': airtempsCurrentTemp                   14.033333
#     distance                             595.642097
#     humiditiesDewpoint                    11.600000
#     humiditiesRelativeHumidityPercent     83.166667
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                  2.632377
#     distance                             5.735550
#     humiditiesDewpoint                   1.765172
#     humiditiesRelativeHumidityPercent    6.578799
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                  3.741667e+00
#     distance                             1.136868e-13
#     humiditiesDewpoint                   2.241667e+00
#     humiditiesRelativeHumidityPercent    8.666667e+00
#     dtype: float64,
#     'range': airtempsCurrentTemp                  14.066667
#     distance                             72.948439
#     humiditiesDewpoint                    6.566667
#     humiditiesRelativeHumidityPercent    44.666667
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   16.528396
#     distance                             598.196568
#     humiditiesDewpoint                     9.909869
#     humiditiesRelativeHumidityPercent     65.975540
#     dtype: float64,
#     'median': airtempsCurrentTemp                   15.933333
#     distance                             595.642097
#     humiditiesDewpoint                     9.633333
#     humiditiesRelativeHumidityPercent     68.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   2.893809
#     distance                             20.641283
#     humiditiesDewpoint                    1.616809
#     humiditiesRelativeHumidityPercent    11.345406
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                   4.750000
#     distance                              0.000000
#     humiditiesDewpoint                    2.566667
#     humiditiesRelativeHumidityPercent    13.000000
#     dtype: float64,
#     'range': airtempsCurrentTemp                   12.533333
#     distance                             246.362250
#     humiditiesDewpoint                    12.600000
#     humiditiesRelativeHumidityPercent     61.666667
#     dtype: float64},
#    'distance': np.float64(638.4413549968441)}},
#  '59589': {72: {'before': {'mean': Series([], dtype: float64),
#     'median': Series([], dtype: float64),
#     'std_dev': Series([], dtype: float64),
#     'IQR': Series([], dtype: float64),
#     'range': Series([], dtype: float64)},
#    'after': {'mean': Series([], dtype: float64),
#     'median': Series([], dtype: float64),
#     'std_dev': Series([], dtype: float64),
#     'IQR': Series([], dtype: float64),
#     'range': Series([], dtype: float64)},
#    'distance': np.float64(793.5970018928529)}},
#  '59592': {72: {'before': {'mean': airtempsCurrentTemp                          20.271036
#     dissolvedoxygensDissolvedOxygenViaKitMgl      7.775000
#     distance                                    545.518372
#     humiditiesDewpoint                           12.090126
#     humiditiesRelativeHumidityPercent            60.029513
#     dtype: float64,
#     'median': airtempsCurrentTemp                          21.400000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      8.550000
#     distance                                    506.032701
#     humiditiesDewpoint                           12.100000
#     humiditiesRelativeHumidityPercent            57.877500
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                          3.164561
#     dissolvedoxygensDissolvedOxygenViaKitMgl     2.646224
#     distance                                    76.295438
#     humiditiesDewpoint                           1.643533
#     humiditiesRelativeHumidityPercent           10.911103
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                          3.300000
#     dissolvedoxygensDissolvedOxygenViaKitMgl     2.325000
#     distance                                     0.000000
#     humiditiesDewpoint                           2.725000
#     humiditiesRelativeHumidityPercent           10.781111
#     dtype: float64,
#     'range': airtempsCurrentTemp                          14.200000
#     dissolvedoxygensDissolvedOxygenViaKitMgl      6.000000
#     distance                                    860.461667
#     humiditiesDewpoint                           12.800000
#     humiditiesRelativeHumidityPercent            70.800000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                            21.766847
#     dissolvedoxygensDissolvedOxygenViaKitMgl        8.245455
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      9.000000
#     distance                                      544.310659
#     humiditiesDewpoint                             12.879866
#     humiditiesRelativeHumidityPercent              57.991816
#     dtype: float64,
#     'median': airtempsCurrentTemp                            22.900000
#     dissolvedoxygensDissolvedOxygenViaKitMgl        7.000000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      9.000000
#     distance                                      506.032701
#     humiditiesDewpoint                             12.500000
#     humiditiesRelativeHumidityPercent              57.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                            3.300437
#     dissolvedoxygensDissolvedOxygenViaKitMgl       2.611652
#     dissolvedoxygensDissolvedOxygenViaProbeMgl          NaN
#     distance                                      77.869961
#     humiditiesDewpoint                             1.777341
#     humiditiesRelativeHumidityPercent             12.198847
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                            3.00
#     dissolvedoxygensDissolvedOxygenViaKitMgl       4.25
#     dissolvedoxygensDissolvedOxygenViaProbeMgl     0.00
#     distance                                       0.00
#     humiditiesDewpoint                             2.39
#     humiditiesRelativeHumidityPercent             10.00
#     dtype: float64,
#     'range': airtempsCurrentTemp                            13.877778
#     dissolvedoxygensDissolvedOxygenViaKitMgl        6.500000
#     dissolvedoxygensDissolvedOxygenViaProbeMgl      0.000000
#     distance                                      914.015837
#     humiditiesDewpoint                             17.650000
#     humiditiesRelativeHumidityPercent              69.000000
#     dtype: float64},
#    'distance': np.float64(546.3163716490276)}},
#  '59665': {72: {'before': {'mean': airtempsCurrentTemp                   30.705371
#     distance                             535.335230
#     humiditiesDewpoint                    26.356745
#     humiditiesRelativeHumidityPercent     77.731884
#     dtype: float64,
#     'median': airtempsCurrentTemp                   30.350000
#     distance                             528.417031
#     humiditiesDewpoint                    26.400000
#     humiditiesRelativeHumidityPercent     78.500000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   1.692682
#     distance                             33.797046
#     humiditiesDewpoint                    1.157992
#     humiditiesRelativeHumidityPercent     8.437201
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                  2.600
#     distance                             0.000
#     humiditiesDewpoint                   0.925
#     humiditiesRelativeHumidityPercent    9.750
#     dtype: float64,
#     'range': airtempsCurrentTemp                    6.700000
#     distance                             242.833686
#     humiditiesDewpoint                    10.950000
#     humiditiesRelativeHumidityPercent     50.500000
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp                   28.303938
#     distance                             531.305880
#     humiditiesDewpoint                    26.307331
#     humiditiesRelativeHumidityPercent     89.060710
#     dtype: float64,
#     'median': airtempsCurrentTemp                   27.925000
#     distance                             528.417031
#     humiditiesDewpoint                    26.450000
#     humiditiesRelativeHumidityPercent     91.000000
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp                   1.785180
#     distance                             21.248383
#     humiditiesDewpoint                    0.845537
#     humiditiesRelativeHumidityPercent     7.041757
#     dtype: float64,
#     'IQR': airtempsCurrentTemp                  2.25
#     distance                             0.00
#     humiditiesDewpoint                   0.75
#     humiditiesRelativeHumidityPercent    7.00
#     dtype: float64,
#     'range': airtempsCurrentTemp                    6.950000
#     distance                             242.833686
#     humiditiesDewpoint                     9.650000
#     humiditiesRelativeHumidityPercent     55.000000
#     dtype: float64},
#    'distance': np.float64(563.6647406375927)}},
#  '60337': {72: {'before': {'mean': airtempsCurrentTemp     14.333333
#     distance               422.007840
#     dtype: float64,
#     'median': airtempsCurrentTemp     14.90000
#     distance               422.00784
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    2.498666
#     distance               0.000000
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    2.45
#     distance               0.00
#     dtype: float64,
#     'range': airtempsCurrentTemp    4.9
#     distance               0.0
#     dtype: float64},
#    'after': {'mean': airtempsCurrentTemp     14.833333
#     distance               422.007840
#     dtype: float64,
#     'median': airtempsCurrentTemp     15.60000
#     distance               422.00784
#     dtype: float64,
#     'std_dev': airtempsCurrentTemp    1.778576
#     distance               0.000000
#     dtype: float64,
#     'IQR': airtempsCurrentTemp    1.65
#     distance               0.00
#     dtype: float64,
#     'range': airtempsCurrentTemp    3.3
#     distance               0.0
#     dtype: float64},
#    'distance': np.float64(422.00784025949895)}}}

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate  # used to output markdown tables

def calculate_stats_series(series, trim_percentile=5):
    """Calculate statistics for a pandas Series after removing outliers based on a given percentile and return a dictionary."""
    
    # Sort the series to find the cut-off points for trimming
    series_sorted = series.sort_values()
    
    # Calculate the trim cut-off points based on the given percentile
    lower_trim = series_sorted.quantile(trim_percentile / 100)
    upper_trim = series_sorted.quantile(1 - trim_percentile / 100)
    
    # Remove outliers based on the trim values (both lower and upper)
    trimmed_series = series_sorted[
        (series_sorted >= lower_trim) & (series_sorted <= upper_trim)
    ]
    
    # Calculate statistics on the trimmed data
    stats = {
        "mean": trimmed_series.mean(),
        "median": trimmed_series.median(),
        "std_dev": trimmed_series.std(),
        "IQR": trimmed_series.quantile(0.75) - trimmed_series.quantile(0.25),
        "range": trimmed_series.max() - trimmed_series.min(),
    }
    
    return stats


# Dictionary to store the comparison tables
comparison_tables = {}

# Iterate over time windows and objects
for win in time_windows:
    for obj_id in matching_objects:
        # Filter before and after data for this object
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data  = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()
        
        # Proceed only if there is data in both periods
        if not before_data.empty and not after_data.empty:
            # Determine which numeric measurements are available
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns
            for column in numeric_cols:
                # Get the measurement series for before and after (dropping NaN)
                before_series = before_data[column].dropna()
                after_series  = after_data[column].dropna()
                
                if not before_series.empty and not after_series.empty:
                    # Compute statistics for each measurement
                    before_stats = calculate_stats_series(before_series)
                    after_stats  = calculate_stats_series(after_series)
                    
                    # Build a DataFrame for this measurement's comparison
                    comp_df = pd.DataFrame({
                        "Before": pd.Series(before_stats),
                        "After": pd.Series(after_stats)
                    })
                    comp_df.index.name = "Measurement"

                    # Add a Δ column
                    comp_df["Δ"] = comp_df["After"] - comp_df["Before"]
                    
                    # Build a table name that includes the object and measurement name
                    table_name = f"Object {obj_id} - {column} - Window {win} hours - Measured {distance}km Away"
                    comparison_tables[table_name] = comp_df

# %%
# Output each table in Markdown format
for table_name, df in comparison_tables.items():
    print(f"### Comparison Table: {table_name}")
    print(df.to_markdown(tablefmt="github", floatfmt=".2f"))
    print("\n")
# Out:
# ### Comparison Table: Object 6792 - airtempsCurrentTemp - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    29.91 |   26.37 | -3.54 |
# | median        |    27.90 |   25.50 | -2.40 |
# | std_dev       |     4.29 |    3.32 | -0.97 |
# | IQR           |     8.15 |    5.15 | -3.00 |
# | range         |    12.40 |   12.60 |  0.20 |
#
#
# ### Comparison Table: Object 6792 - distance - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   998.65 |  998.65 |  0.00 |
# | median        |   998.65 |  998.65 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 6792 - humiditiesDewpoint - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    22.04 |   22.82 |  0.78 |
# | median        |    23.40 |   22.50 | -0.90 |
# | std_dev       |     2.66 |    1.19 | -1.47 |
# | IQR           |     3.30 |    2.10 | -1.20 |
# | range         |     8.60 |    3.90 | -4.70 |
#
#
# ### Comparison Table: Object 6792 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    67.23 |   82.50 |  15.27 |
# | median        |    76.00 |   85.50 |   9.50 |
# | std_dev       |    22.10 |   11.34 | -10.77 |
# | IQR           |    41.00 |   16.00 | -25.00 |
# | range         |    64.00 |   46.00 | -18.00 |
#
#
# ### Comparison Table: Object 9911 - airtempsCurrentTemp - Window 72 hours - Measured 920.3301355824387km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.43 |   24.08 | -0.35 |
# | median        |    24.60 |   24.00 | -0.60 |
# | std_dev       |     2.18 |    1.70 | -0.49 |
# | IQR           |     3.55 |    3.00 | -0.55 |
# | range         |     7.50 |    6.60 | -0.90 |
#
#
# ### Comparison Table: Object 9911 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 920.3301355824387km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |     3.00 |    8.56 |   5.56 |
# | median        |     3.00 |    8.95 |   5.95 |
# | std_dev       |   nan    |    1.36 | nan    |
# | IQR           |     0.00 |    0.86 |   0.86 |
# | range         |     0.00 |    3.15 |   3.15 |
#
#
# ### Comparison Table: Object 9911 - distance - Window 72 hours - Measured 920.3301355824387km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   889.42 |  890.63 | 1.21 |
# | median        |   884.94 |  884.94 | 0.00 |
# | std_dev       |    15.20 |   18.67 | 3.47 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |   104.09 |  104.25 | 0.17 |
#
#
# ### Comparison Table: Object 9911 - humiditiesDewpoint - Window 72 hours - Measured 920.3301355824387km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    18.89 |   17.47 | -1.41 |
# | median        |    19.00 |   16.60 | -2.40 |
# | std_dev       |     1.06 |    2.15 |  1.09 |
# | IQR           |     1.50 |    4.50 |  3.00 |
# | range         |     4.40 |    6.40 |  2.00 |
#
#
# ### Comparison Table: Object 9911 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 920.3301355824387km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    72.67 |   67.98 | -4.69 |
# | median        |    75.00 |   67.00 | -8.00 |
# | std_dev       |    10.05 |   10.99 |  0.94 |
# | IQR           |    18.00 |   12.00 | -6.00 |
# | range         |    34.00 |   39.00 |  5.00 |
#
#
# ### Comparison Table: Object 25469 - airtempsCurrentTemp - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.81 |   23.40 | -1.41 |
# | median        |    24.05 |   22.90 | -1.15 |
# | std_dev       |     2.39 |    1.75 | -0.64 |
# | IQR           |     4.33 |    2.60 | -1.73 |
# | range         |     7.40 |    6.10 | -1.30 |
#
#
# ### Comparison Table: Object 25469 - distance - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   993.80 |  993.80 |  0.00 |
# | median        |   993.80 |  993.80 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 25469 - humiditiesDewpoint - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    21.44 |   21.18 | -0.26 |
# | median        |    21.50 |   21.20 | -0.30 |
# | std_dev       |     0.68 |    0.79 |  0.11 |
# | IQR           |     1.30 |    1.30 |  0.00 |
# | range         |     2.30 |    3.10 |  0.80 |
#
#
# ### Comparison Table: Object 25469 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    81.98 |   87.89 |  5.91 |
# | median        |    85.50 |   89.00 |  3.50 |
# | std_dev       |     8.40 |    5.50 | -2.90 |
# | IQR           |    14.25 |    9.00 | -5.25 |
# | range         |    25.00 |   18.00 | -7.00 |
#
#
# ### Comparison Table: Object 26476 - airtempsCurrentTemp - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    25.91 |   23.08 | -2.83 |
# | median        |    24.40 |   21.70 | -2.70 |
# | std_dev       |     4.49 |    5.00 |  0.51 |
# | IQR           |     8.55 |    8.75 |  0.20 |
# | range         |    14.10 |   17.10 |  3.00 |
#
#
# ### Comparison Table: Object 26476 - distance - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   966.47 |  966.47 | 0.00 |
# | median        |   966.47 |  966.47 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 26476 - humiditiesDewpoint - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    19.97 |   11.21 | -8.76 |
# | median        |    19.80 |   11.85 | -7.95 |
# | std_dev       |     1.91 |    3.88 |  1.97 |
# | IQR           |     3.30 |    6.83 |  3.52 |
# | range         |     6.60 |   13.50 |  6.90 |
#
#
# ### Comparison Table: Object 26476 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    73.27 |   52.65 | -20.61 |
# | median        |    78.00 |   46.00 | -32.00 |
# | std_dev       |    15.13 |   22.84 |   7.71 |
# | IQR           |    26.00 |   47.50 |  21.50 |
# | range         |    52.00 |   65.00 |  13.00 |
#
#
# ### Comparison Table: Object 26640 - airtempsCurrentTemp - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.40 |   29.48 | -0.93 |
# | median        |    32.00 |   30.00 | -2.00 |
# | std_dev       |     3.67 |    1.96 | -1.71 |
# | IQR           |     3.40 |    2.52 | -0.88 |
# | range         |     6.80 |    4.10 | -2.70 |
#
#
# ### Comparison Table: Object 26640 - distance - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   449.57 |  449.57 | 0.00 |
# | median        |   478.34 |  478.34 | 0.00 |
# | std_dev       |    39.39 |   39.39 | 0.00 |
# | IQR           |    71.92 |   71.92 | 0.00 |
# | range         |    71.92 |   71.92 | 0.00 |
#
#
# ### Comparison Table: Object 26640 - humiditiesDewpoint - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    19.10 |   16.20 | -2.90 |
# | median        |    19.10 |   16.20 | -2.90 |
# | std_dev       |     0.00 |    0.00 |  0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 26640 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    51.50 |   35.80 | -15.70 |
# | median        |    51.50 |   35.80 | -15.70 |
# | std_dev       |     0.00 |    0.00 |   0.00 |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 26692 - airtempsCurrentTemp - Window 72 hours - Measured 883.5999578504238km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    26.84 |   30.10 |  3.26 |
# | median        |    28.00 |   30.10 |  2.10 |
# | std_dev       |     1.68 |    0.14 | -1.54 |
# | IQR           |     3.00 |    0.10 | -2.90 |
# | range         |     3.20 |    0.20 | -3.00 |
#
#
# ### Comparison Table: Object 26692 - distance - Window 72 hours - Measured 883.5999578504238km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   866.89 |  895.97 |  29.08 |
# | median        |   866.89 |  895.97 |  29.08 |
# | std_dev       |    31.85 |    0.00 | -31.85 |
# | IQR           |    58.16 |    0.00 | -58.16 |
# | range         |    58.16 |    0.00 | -58.16 |
#
#
# ### Comparison Table: Object 27613 - airtempsCurrentTemp - Window 72 hours - Measured 386.9994860250063km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    20.20 |   19.80 |  -0.40 |
# | median        |    20.20 |   19.80 |  -0.40 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 27613 - distance - Window 72 hours - Measured 386.9994860250063km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   387.00 |  387.00 | 0.00 |
# | median        |   387.00 |  387.00 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 28130 - airtempsCurrentTemp - Window 72 hours - Measured 756.9085853308869km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.28 |   30.82 |  0.54 |
# | median        |    30.40 |   31.12 |  0.73 |
# | std_dev       |     2.38 |    1.85 | -0.53 |
# | IQR           |     3.83 |    1.88 | -1.96 |
# | range         |     7.00 |    6.50 | -0.50 |
#
#
# ### Comparison Table: Object 28130 - distance - Window 72 hours - Measured 756.9085853308869km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   774.03 |  773.32 | -0.71 |
# | median        |   794.76 |  795.83 |  1.07 |
# | std_dev       |   149.23 |  142.61 | -6.62 |
# | IQR           |   195.96 |  191.35 | -4.60 |
# | range         |   458.73 |  458.73 |  0.00 |
#
#
# ### Comparison Table: Object 28130 - humiditiesDewpoint - Window 72 hours - Measured 756.9085853308869km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.41 |   24.51 |  0.10 |
# | median        |    24.40 |   24.25 | -0.15 |
# | std_dev       |     1.91 |    1.47 | -0.43 |
# | IQR           |     1.67 |    1.91 |  0.24 |
# | range         |     7.70 |    4.93 | -2.77 |
#
#
# ### Comparison Table: Object 28130 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 756.9085853308869km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    75.49 |   74.87 | -0.62 |
# | median        |    76.75 |   72.30 | -4.45 |
# | std_dev       |     8.49 |    9.89 |  1.41 |
# | IQR           |    13.88 |   14.07 |  0.20 |
# | range         |    26.20 |   32.42 |  6.22 |
#
#
# ### Comparison Table: Object 28418 - airtempsCurrentTemp - Window 72 hours - Measured 380.39974443315833km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    31.39 |   31.73 |  0.34 |
# | median        |    32.00 |   31.88 | -0.12 |
# | std_dev       |     1.71 |    0.88 | -0.83 |
# | IQR           |     2.08 |    1.45 | -0.63 |
# | range         |     7.00 |    3.00 | -4.00 |
#
#
# ### Comparison Table: Object 28418 - distance - Window 72 hours - Measured 380.39974443315833km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   358.31 |  363.84 |  5.53 |
# | median        |   177.74 |  175.84 | -1.90 |
# | std_dev       |   308.48 |  312.69 |  4.22 |
# | IQR           |   209.37 |  290.04 | 80.67 |
# | range         |   774.02 |  774.23 |  0.21 |
#
#
# ### Comparison Table: Object 28418 - humiditiesDewpoint - Window 72 hours - Measured 380.39974443315833km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    17.37 |   16.80 |  -0.57 |
# | median        |    17.20 |   16.80 |  -0.40 |
# | std_dev       |     0.67 |  nan    | nan    |
# | IQR           |     0.65 |    0.00 |  -0.65 |
# | range         |     1.30 |    0.00 |  -1.30 |
#
#
# ### Comparison Table: Object 28418 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 380.39974443315833km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    56.40 |   42.60 | -13.80 |
# | median        |    54.40 |   42.60 | -11.80 |
# | std_dev       |     7.79 |  nan    | nan    |
# | IQR           |     7.60 |    0.00 |  -7.60 |
# | range         |    15.20 |    0.00 | -15.20 |
#
#
# ### Comparison Table: Object 28641 - airtempsCurrentTemp - Window 72 hours - Measured 669.5040839130005km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    38.00 |   39.67 |   1.67 |
# | median        |    38.00 |   40.00 |   2.00 |
# | std_dev       |   nan    |    0.58 | nan    |
# | IQR           |     0.00 |    0.50 |   0.50 |
# | range         |     0.00 |    1.00 |   1.00 |
#
#
# ### Comparison Table: Object 28641 - distance - Window 72 hours - Measured 669.5040839130005km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   675.32 |  675.32 | 0.00 |
# | median        |   675.32 |  675.32 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 28921 - airtempsCurrentTemp - Window 72 hours - Measured 540.7440344011051km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    30.10 |   30.39 | 0.29 |
# | median        |    30.00 |   30.29 | 0.29 |
# | std_dev       |     1.99 |    2.09 | 0.09 |
# | IQR           |     1.45 |    2.82 | 1.37 |
# | range         |     7.70 |    8.00 | 0.30 |
#
#
# ### Comparison Table: Object 28921 - distance - Window 72 hours - Measured 540.7440344011051km Away
# | Measurement   |   Before |   After |       Δ |
# |---------------|----------|---------|---------|
# | mean          |   537.37 |  537.25 |   -0.12 |
# | median        |   549.51 |  548.58 |   -0.93 |
# | std_dev       |   174.97 |  136.50 |  -38.47 |
# | IQR           |   166.05 |  170.74 |    4.69 |
# | range         |   671.01 |  497.64 | -173.37 |
#
#
# ### Comparison Table: Object 28921 - humiditiesDewpoint - Window 72 hours - Measured 540.7440344011051km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    12.43 |   12.61 | 0.18 |
# | median        |    11.50 |   13.20 | 1.70 |
# | std_dev       |     6.62 |    6.62 | 0.00 |
# | IQR           |     8.70 |    9.50 | 0.80 |
# | range         |    16.60 |   19.20 | 2.60 |
#
#
# ### Comparison Table: Object 28921 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 540.7440344011051km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    40.46 |   41.24 |  0.78 |
# | median        |    30.20 |   39.60 |  9.40 |
# | std_dev       |    21.37 |   18.75 | -2.63 |
# | IQR           |    24.00 |   24.90 |  0.90 |
# | range         |    53.50 |   53.30 | -0.20 |
#
#
# ### Comparison Table: Object 29247 - airtempsCurrentTemp - Window 72 hours - Measured 413.4173284101769km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    15.03 |   13.18 | -1.85 |
# | median        |    15.00 |   13.80 | -1.20 |
# | std_dev       |     0.89 |    1.08 |  0.19 |
# | IQR           |     0.90 |    2.00 |  1.10 |
# | range         |     2.60 |    2.10 | -0.50 |
#
#
# ### Comparison Table: Object 29247 - distance - Window 72 hours - Measured 413.4173284101769km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   388.69 |  410.58 |  21.90 |
# | median        |   416.67 |  424.52 |   7.85 |
# | std_dev       |   133.52 |  173.13 |  39.61 |
# | IQR           |   211.32 |  318.34 | 107.02 |
# | range         |   328.79 |  328.79 |   0.00 |
#
#
# ### Comparison Table: Object 29386 - airtempsCurrentTemp - Window 72 hours - Measured 1132.2895250906092km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    41.45 |   37.95 | -3.50 |
# | median        |    40.80 |   38.00 | -2.80 |
# | std_dev       |     3.28 |    2.60 | -0.68 |
# | IQR           |     4.27 |    2.62 | -1.65 |
# | range         |     8.10 |    7.80 | -0.30 |
#
#
# ### Comparison Table: Object 29386 - distance - Window 72 hours - Measured 1132.2895250906092km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |  1130.53 | 1133.96 |   3.43 |
# | median        |  1138.72 | 1127.69 | -11.04 |
# | std_dev       |    19.09 |   11.43 |  -7.65 |
# | IQR           |    24.03 |   17.82 |  -6.21 |
# | range         |    51.14 |   27.46 | -23.67 |
#
#
# ### Comparison Table: Object 29386 - humiditiesDewpoint - Window 72 hours - Measured 1132.2895250906092km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    32.55 |   33.58 |  1.03 |
# | median        |    32.90 |   33.85 |  0.95 |
# | std_dev       |     2.99 |    2.62 | -0.36 |
# | IQR           |     3.90 |    4.07 |  0.18 |
# | range         |     6.60 |    5.20 | -1.40 |
#
#
# ### Comparison Table: Object 29386 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 1132.2895250906092km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    63.75 |   71.00 | 7.25 |
# | median        |    62.50 |   70.00 | 7.50 |
# | std_dev       |    13.77 |   16.15 | 2.38 |
# | IQR           |    18.75 |   23.50 | 4.75 |
# | range         |    30.00 |   34.00 | 4.00 |
#
#
# ### Comparison Table: Object 29482 - airtempsCurrentTemp - Window 72 hours - Measured 929.43116961109km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    17.26 |   14.98 | -2.27 |
# | median        |    17.17 |   14.43 | -2.73 |
# | std_dev       |     3.98 |    3.35 | -0.63 |
# | IQR           |     7.34 |    4.68 | -2.66 |
# | range         |    13.63 |   13.29 | -0.34 |
#
#
# ### Comparison Table: Object 29482 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 929.43116961109km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.16 |    9.17 |  1.02 |
# | median        |     8.00 |    9.15 |  1.15 |
# | std_dev       |     2.40 |    1.75 | -0.65 |
# | IQR           |     2.35 |    1.70 | -0.65 |
# | range         |     7.60 |    6.50 | -1.10 |
#
#
# ### Comparison Table: Object 29482 - distance - Window 72 hours - Measured 929.43116961109km Away
# | Measurement   |   Before |   After |       Δ |
# |---------------|----------|---------|---------|
# | mean          |   957.95 |  961.22 |    3.26 |
# | median        |  1014.56 | 1014.56 |    0.00 |
# | std_dev       |   138.81 |  114.81 |  -24.00 |
# | IQR           |    20.56 |   31.84 |   11.28 |
# | range         |   725.46 |  605.83 | -119.62 |
#
#
# ### Comparison Table: Object 29482 - humiditiesDewpoint - Window 72 hours - Measured 929.43116961109km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    10.63 |   12.63 |  1.99 |
# | median        |    10.63 |   13.28 |  2.65 |
# | std_dev       |     1.99 |    1.95 | -0.04 |
# | IQR           |     3.29 |    2.80 | -0.49 |
# | range         |     6.88 |    7.12 |  0.24 |
#
#
# ### Comparison Table: Object 29482 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 929.43116961109km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    70.21 |   92.09 |  21.88 |
# | median        |    71.87 |   98.23 |  26.37 |
# | std_dev       |    15.67 |   10.34 |  -5.32 |
# | IQR           |    26.14 |   10.72 | -15.42 |
# | range         |    55.01 |   39.04 | -15.97 |
#
#
# ### Comparison Table: Object 29664 - airtempsCurrentTemp - Window 72 hours - Measured 1005.276677744487km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   -17.00 |   -9.00 |   8.00 |
# | median        |   -17.00 |   -9.00 |   8.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 29664 - distance - Window 72 hours - Measured 1005.276677744487km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |  1005.28 | 1005.28 | 0.00 |
# | median        |  1005.28 | 1005.28 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 32751 - airtempsCurrentTemp - Window 72 hours - Measured 979.8716124964284km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.20 |   20.72 | -3.48 |
# | median        |    23.00 |   20.36 | -2.64 |
# | std_dev       |     5.14 |    4.27 | -0.87 |
# | IQR           |     7.20 |    5.39 | -1.81 |
# | range         |    18.50 |   18.20 | -0.30 |
#
#
# ### Comparison Table: Object 32751 - distance - Window 72 hours - Measured 979.8716124964284km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   995.48 | 1031.43 |  35.96 |
# | median        |  1136.52 | 1136.52 |   0.00 |
# | std_dev       |   214.97 |  210.43 |  -4.54 |
# | IQR           |   340.69 |  302.18 | -38.51 |
# | range         |   748.29 |  694.38 | -53.91 |
#
#
# ### Comparison Table: Object 32751 - humiditiesDewpoint - Window 72 hours - Measured 979.8716124964284km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    11.57 |   12.29 |  0.72 |
# | median        |    10.50 |   11.65 |  1.15 |
# | std_dev       |     4.75 |    3.92 | -0.83 |
# | IQR           |     4.50 |    3.18 | -1.32 |
# | range         |    20.40 |   19.40 | -1.00 |
#
#
# ### Comparison Table: Object 32751 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 979.8716124964284km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    47.81 |   58.82 | 11.01 |
# | median        |    48.00 |   60.00 | 12.00 |
# | std_dev       |    10.53 |   11.01 |  0.48 |
# | IQR           |    13.46 |   15.38 |  1.91 |
# | range         |    44.60 |   47.25 |  2.65 |
#
#
# ### Comparison Table: Object 32765 - airtempsCurrentTemp - Window 72 hours - Measured 788.7165401779511km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    31.18 |   31.64 |  0.46 |
# | median        |    32.00 |   31.30 | -0.70 |
# | std_dev       |     4.25 |    4.09 | -0.16 |
# | IQR           |     7.20 |    6.00 | -1.20 |
# | range         |    14.70 |   16.00 |  1.30 |
#
#
# ### Comparison Table: Object 32765 - distance - Window 72 hours - Measured 788.7165401779511km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   768.58 |  761.56 |  -7.02 |
# | median        |   750.41 |  744.37 |  -6.03 |
# | std_dev       |   171.92 |  168.30 |  -3.62 |
# | IQR           |   375.97 |  342.69 | -33.27 |
# | range         |   472.67 |  472.67 |   0.00 |
#
#
# ### Comparison Table: Object 32765 - humiditiesDewpoint - Window 72 hours - Measured 788.7165401779511km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    18.64 |   18.51 | -0.13 |
# | median        |    19.35 |   18.65 | -0.70 |
# | std_dev       |     6.10 |    7.20 |  1.11 |
# | IQR           |     8.90 |    9.50 |  0.60 |
# | range         |    22.60 |   25.37 |  2.77 |
#
#
# ### Comparison Table: Object 32765 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 788.7165401779511km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    45.37 |   47.31 | 1.93 |
# | median        |    43.50 |   45.00 | 1.50 |
# | std_dev       |    10.60 |   13.10 | 2.50 |
# | IQR           |    13.00 |   18.00 | 5.00 |
# | range         |    39.33 |   48.17 | 8.83 |
#
#
# ### Comparison Table: Object 34603 - airtempsCurrentTemp - Window 72 hours - Measured 913.5099395747033km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    17.52 |   14.60 | -2.91 |
# | median        |    17.90 |   14.90 | -3.00 |
# | std_dev       |     4.15 |    4.85 |  0.69 |
# | IQR           |     7.70 |    8.77 |  1.07 |
# | range         |    13.40 |   16.20 |  2.80 |
#
#
# ### Comparison Table: Object 34603 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 913.5099395747033km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.20 |    5.32 | -2.88 |
# | median        |     8.00 |    5.45 | -2.55 |
# | std_dev       |     1.37 |    3.93 |  2.56 |
# | IQR           |     1.60 |    7.08 |  5.48 |
# | range         |     4.00 |    8.60 |  4.60 |
#
#
# ### Comparison Table: Object 34603 - distance - Window 72 hours - Measured 913.5099395747033km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   919.54 |  924.29 |   4.75 |
# | median        |   931.84 |  931.84 |   0.00 |
# | std_dev       |    36.47 |   25.73 | -10.73 |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |   188.68 |  159.79 | -28.89 |
#
#
# ### Comparison Table: Object 34603 - humiditiesDewpoint - Window 72 hours - Measured 913.5099395747033km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     1.17 |    0.13 | -1.04 |
# | median        |     0.65 |    0.20 | -0.45 |
# | std_dev       |     2.93 |    2.56 | -0.37 |
# | IQR           |     5.28 |    3.60 | -1.68 |
# | range         |    10.30 |   10.80 |  0.50 |
#
#
# ### Comparison Table: Object 34603 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 913.5099395747033km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    36.53 |   41.05 | 4.52 |
# | median        |    36.00 |   43.00 | 7.00 |
# | std_dev       |    13.42 |   14.12 | 0.70 |
# | IQR           |    20.75 |   24.00 | 3.25 |
# | range         |    47.00 |   49.00 | 2.00 |
#
#
# ### Comparison Table: Object 36749 - airtempsCurrentTemp - Window 72 hours - Measured 404.00759453698385km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.35 |   22.64 | -1.71 |
# | median        |    24.50 |   22.20 | -2.30 |
# | std_dev       |     4.86 |    3.85 | -1.00 |
# | IQR           |     9.28 |    6.90 | -2.37 |
# | range         |    15.30 |   13.41 | -1.89 |
#
#
# ### Comparison Table: Object 36749 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 404.00759453698385km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.83 |    8.20 | -0.63 |
# | median        |     9.00 |    8.60 | -0.40 |
# | std_dev       |     0.61 |    2.15 |  1.54 |
# | IQR           |     0.30 |    2.05 |  1.75 |
# | range         |     1.80 |    6.50 |  4.70 |
#
#
# ### Comparison Table: Object 36749 - distance - Window 72 hours - Measured 404.00759453698385km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   407.55 |  410.42 | 2.87 |
# | median        |   169.69 |  169.69 | 0.00 |
# | std_dev       |   299.74 |  303.05 | 3.31 |
# | IQR           |   530.94 |  537.52 | 6.58 |
# | range         |   871.98 |  871.98 | 0.00 |
#
#
# ### Comparison Table: Object 36749 - humiditiesDewpoint - Window 72 hours - Measured 404.00759453698385km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    16.27 |   17.23 |  0.96 |
# | median        |    16.20 |   17.50 |  1.30 |
# | std_dev       |     1.54 |    1.76 |  0.22 |
# | IQR           |     2.30 |    2.29 | -0.01 |
# | range         |     6.46 |    7.70 |  1.24 |
#
#
# ### Comparison Table: Object 36749 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 404.00759453698385km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    64.68 |   73.28 |   8.59 |
# | median        |    64.00 |   74.81 |  10.81 |
# | std_dev       |    19.74 |   15.39 |  -4.35 |
# | IQR           |    38.80 |   28.00 | -10.80 |
# | range         |    57.00 |   50.83 |  -6.17 |
#
#
# ### Comparison Table: Object 38037 - airtempsCurrentTemp - Window 72 hours - Measured 805.6877566317269km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    -0.13 |    2.23 |  2.36 |
# | median        |     0.90 |    2.40 |  1.50 |
# | std_dev       |     3.24 |    1.61 | -1.63 |
# | IQR           |     2.10 |    1.94 | -0.16 |
# | range         |    14.21 |    6.60 | -7.61 |
#
#
# ### Comparison Table: Object 38037 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 805.6877566317269km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |     9.50 |   10.20 |   0.70 |
# | median        |     9.50 |   10.20 |   0.70 |
# | std_dev       |     0.58 |  nan    | nan    |
# | IQR           |     1.00 |    0.00 |  -1.00 |
# | range         |     1.00 |    0.00 |  -1.00 |
#
#
# ### Comparison Table: Object 38037 - distance - Window 72 hours - Measured 805.6877566317269km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   828.35 |  821.08 | -7.27 |
# | median        |   841.79 |  841.79 |  0.00 |
# | std_dev       |    46.62 |   61.64 | 15.02 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |   317.77 |  329.70 | 11.93 |
#
#
# ### Comparison Table: Object 38037 - humiditiesDewpoint - Window 72 hours - Measured 805.6877566317269km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    -3.44 |   -1.69 |  1.75 |
# | median        |    -3.60 |   -2.40 |  1.20 |
# | std_dev       |     2.46 |    1.69 | -0.77 |
# | IQR           |     2.20 |    3.20 |  1.00 |
# | range         |    12.11 |    6.07 | -6.03 |
#
#
# ### Comparison Table: Object 38037 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 805.6877566317269km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    80.15 |   77.57 | -2.58 |
# | median        |    81.00 |   79.00 | -2.00 |
# | std_dev       |     9.33 |   10.02 |  0.69 |
# | IQR           |    17.00 |   19.00 |  2.00 |
# | range         |    33.50 |   33.38 | -0.12 |
#
#
# ### Comparison Table: Object 38047 - airtempsCurrentTemp - Window 72 hours - Measured 986.5696864017867km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    17.87 |   14.75 | -3.12 |
# | median        |    17.85 |   14.40 | -3.45 |
# | std_dev       |     1.65 |    2.58 |  0.93 |
# | IQR           |     3.00 |    4.35 |  1.35 |
# | range         |     5.90 |    9.10 |  3.20 |
#
#
# ### Comparison Table: Object 38047 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 986.5696864017867km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     9.70 |    4.32 | -5.38 |
# | median        |     9.70 |    3.85 | -5.85 |
# | std_dev       |     0.14 |    1.53 |  1.39 |
# | IQR           |     0.10 |    2.67 |  2.58 |
# | range         |     0.20 |    3.20 |  3.00 |
#
#
# ### Comparison Table: Object 38047 - distance - Window 72 hours - Measured 986.5696864017867km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   982.76 |  983.55 | 0.79 |
# | median        |   982.07 |  982.07 | 0.00 |
# | std_dev       |     5.52 |    8.44 | 2.92 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |    54.01 |   58.55 | 4.54 |
#
#
# ### Comparison Table: Object 38047 - humiditiesDewpoint - Window 72 hours - Measured 986.5696864017867km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    15.04 |    3.88 | -11.16 |
# | median        |    15.90 |    3.80 | -12.10 |
# | std_dev       |     1.95 |    2.77 |   0.82 |
# | IQR           |     2.90 |    3.10 |   0.20 |
# | range         |     7.70 |   11.30 |   3.60 |
#
#
# ### Comparison Table: Object 38047 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 986.5696864017867km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    83.51 |   48.92 | -34.59 |
# | median        |    84.00 |   48.00 | -36.00 |
# | std_dev       |     7.30 |    9.45 |   2.15 |
# | IQR           |    11.00 |   15.00 |   4.00 |
# | range         |    28.50 |   34.00 |   5.50 |
#
#
# ### Comparison Table: Object 38872 - airtempsCurrentTemp - Window 72 hours - Measured 574.6741267143639km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.73 |    6.28 | -2.45 |
# | median        |     8.70 |    6.56 | -2.14 |
# | std_dev       |     1.42 |    2.60 |  1.18 |
# | IQR           |     2.03 |    4.03 |  2.01 |
# | range         |     5.97 |    9.67 |  3.69 |
#
#
# ### Comparison Table: Object 38872 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 574.6741267143639km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.97 |    7.77 | -1.20 |
# | median        |    10.00 |    7.00 | -3.00 |
# | std_dev       |     1.75 |    1.28 | -0.46 |
# | IQR           |     3.00 |    1.75 | -1.25 |
# | range         |     5.00 |    3.30 | -1.70 |
#
#
# ### Comparison Table: Object 38872 - distance - Window 72 hours - Measured 574.6741267143639km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   551.86 |  555.26 |  3.40 |
# | median        |   534.07 |  534.07 |  0.00 |
# | std_dev       |    24.98 |   30.85 |  5.87 |
# | IQR           |    47.12 |   52.38 |  5.27 |
# | range         |    66.05 |   78.41 | 12.36 |
#
#
# ### Comparison Table: Object 38872 - humiditiesDewpoint - Window 72 hours - Measured 574.6741267143639km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     7.30 |    5.21 | -2.09 |
# | median        |     7.50 |    5.51 | -1.99 |
# | std_dev       |     1.22 |    2.27 |  1.05 |
# | IQR           |     1.69 |    3.08 |  1.39 |
# | range         |     4.62 |    8.63 |  4.02 |
#
#
# ### Comparison Table: Object 38872 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 574.6741267143639km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    91.54 |   92.77 |  1.23 |
# | median        |    91.67 |   92.96 |  1.29 |
# | std_dev       |     3.82 |    2.62 | -1.19 |
# | IQR           |     6.67 |    3.33 | -3.33 |
# | range         |    13.67 |   12.67 | -1.00 |
#
#
# ### Comparison Table: Object 38994 - airtempsCurrentTemp - Window 72 hours - Measured 723.0357312939036km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    31.70 |   31.00 |  -0.70 |
# | median        |    31.70 |   31.00 |  -0.70 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 38994 - distance - Window 72 hours - Measured 723.0357312939036km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   739.11 |  739.11 | 0.00 |
# | median        |   739.11 |  739.11 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 38994 - humiditiesDewpoint - Window 72 hours - Measured 723.0357312939036km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    26.10 |   26.10 |   0.00 |
# | median        |    26.10 |   26.10 |   0.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 38994 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 723.0357312939036km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    75.00 |   73.00 |  -2.00 |
# | median        |    75.00 |   73.00 |  -2.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 39069 - airtempsCurrentTemp - Window 72 hours - Measured 733.1385927312612km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    20.71 |   17.98 | -2.73 |
# | median        |    21.10 |   18.00 | -3.10 |
# | std_dev       |     2.76 |    3.00 |  0.24 |
# | IQR           |     3.73 |    2.97 | -0.75 |
# | range         |    12.10 |   12.20 |  0.10 |
#
#
# ### Comparison Table: Object 39069 - distance - Window 72 hours - Measured 733.1385927312612km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   733.14 |  733.14 | -0.00 |
# | median        |   733.14 |  733.14 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 39069 - humiditiesDewpoint - Window 72 hours - Measured 733.1385927312612km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    14.91 |   13.46 | -1.45 |
# | median        |    13.55 |   12.20 | -1.35 |
# | std_dev       |     4.25 |    3.17 | -1.08 |
# | IQR           |     8.60 |    6.70 | -1.90 |
# | range         |    11.80 |    8.50 | -3.30 |
#
#
# ### Comparison Table: Object 39069 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 733.1385927312612km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    72.11 |   78.44 | 6.33 |
# | median        |    73.00 |   79.00 | 6.00 |
# | std_dev       |    15.13 |   17.01 | 1.87 |
# | IQR           |    27.20 |   32.00 | 4.80 |
# | range         |    50.00 |   53.00 | 3.00 |
#
#
# ### Comparison Table: Object 39083 - airtempsCurrentTemp - Window 72 hours - Measured 396.53311346178003km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    -2.06 |    0.51 |  2.57 |
# | median        |    -0.97 |    0.60 |  1.57 |
# | std_dev       |     2.46 |    1.05 | -1.41 |
# | IQR           |     3.42 |    1.10 | -2.32 |
# | range         |     9.35 |    6.04 | -3.32 |
#
#
# ### Comparison Table: Object 39083 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 396.53311346178003km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |     9.44 |   11.44 | 2.01 |
# | median        |    10.00 |   10.65 | 0.65 |
# | std_dev       |     1.56 |    2.12 | 0.56 |
# | IQR           |     2.15 |    3.62 | 1.47 |
# | range         |     4.50 |    4.50 | 0.00 |
#
#
# ### Comparison Table: Object 39083 - distance - Window 72 hours - Measured 396.53311346178003km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   382.54 |  384.71 |   2.17 |
# | median        |   435.12 |  435.12 |   0.00 |
# | std_dev       |    76.50 |   74.97 |  -1.52 |
# | IQR           |   162.03 |  162.03 |   0.00 |
# | range         |   185.06 |  170.88 | -14.18 |
#
#
# ### Comparison Table: Object 39083 - humiditiesDewpoint - Window 72 hours - Measured 396.53311346178003km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    -3.38 |   -0.13 |  3.25 |
# | median        |    -3.34 |    0.31 |  3.65 |
# | std_dev       |     3.07 |    1.39 | -1.68 |
# | IQR           |     5.40 |    1.61 | -3.78 |
# | range         |    10.40 |    5.52 | -4.88 |
#
#
# ### Comparison Table: Object 39083 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 396.53311346178003km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    91.16 |   95.84 |   4.68 |
# | median        |    92.22 |  100.00 |   7.78 |
# | std_dev       |     8.01 |    5.51 |  -2.50 |
# | IQR           |    10.67 |    8.02 |  -2.65 |
# | range         |    36.00 |   18.16 | -17.84 |
#
#
# ### Comparison Table: Object 39259 - airtempsCurrentTemp - Window 72 hours - Measured 845.4616233297332km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    29.01 |   26.47 | -2.55 |
# | median        |    28.10 |   27.00 | -1.10 |
# | std_dev       |     1.45 |    2.64 |  1.19 |
# | IQR           |     2.15 |    4.25 |  2.10 |
# | range         |     3.30 |    6.20 |  2.90 |
#
#
# ### Comparison Table: Object 39259 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 845.4616233297332km Away
# | Measurement   |   Before |   After |   Δ |
# |---------------|----------|---------|-----|
# | mean          |      nan |     nan | nan |
# | median        |      nan |     nan | nan |
# | std_dev       |      nan |     nan | nan |
# | IQR           |      nan |     nan | nan |
# | range         |      nan |     nan | nan |
#
#
# ### Comparison Table: Object 39259 - distance - Window 72 hours - Measured 845.4616233297332km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   835.91 |  855.34 |  19.43 |
# | median        |   829.28 |  829.28 |   0.00 |
# | std_dev       |    39.83 |   40.28 |   0.46 |
# | IQR           |    20.23 |   48.85 |  28.62 |
# | range         |   124.66 |   89.70 | -34.96 |
#
#
# ### Comparison Table: Object 39259 - humiditiesDewpoint - Window 72 hours - Measured 845.4616233297332km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    21.96 |   21.52 | -0.45 |
# | median        |    22.05 |   22.15 |  0.10 |
# | std_dev       |     1.43 |    2.04 |  0.60 |
# | IQR           |     2.38 |    3.27 |  0.90 |
# | range         |     3.50 |    4.60 |  1.10 |
#
#
# ### Comparison Table: Object 39259 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 845.4616233297332km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    69.14 |   74.40 |  5.26 |
# | median        |    71.05 |   74.20 |  3.15 |
# | std_dev       |     7.52 |   11.81 |  4.30 |
# | IQR           |    10.50 |   15.85 |  5.35 |
# | range         |    21.00 |   31.00 | 10.00 |
#
#
# ### Comparison Table: Object 39482 - airtempsCurrentTemp - Window 72 hours - Measured 812.0746246876183km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    29.68 |   30.00 | 0.32 |
# | median        |    29.48 |   29.70 | 0.22 |
# | std_dev       |     1.39 |    1.70 | 0.31 |
# | IQR           |     2.30 |    2.76 | 0.46 |
# | range         |     5.48 |    6.59 | 1.12 |
#
#
# ### Comparison Table: Object 39482 - distance - Window 72 hours - Measured 812.0746246876183km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   815.26 |  825.42 | 10.16 |
# | median        |   813.61 |  813.61 |  0.00 |
# | std_dev       |    15.96 |   36.92 | 20.96 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |    80.95 |  155.14 | 74.19 |
#
#
# ### Comparison Table: Object 39482 - humiditiesDewpoint - Window 72 hours - Measured 812.0746246876183km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    25.69 |   25.49 | -0.20 |
# | median        |    25.81 |   25.68 | -0.14 |
# | std_dev       |     0.51 |    0.99 |  0.48 |
# | IQR           |     0.80 |    1.09 |  0.29 |
# | range         |     2.18 |    5.15 |  2.98 |
#
#
# ### Comparison Table: Object 39482 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 812.0746246876183km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    79.47 |   77.38 | -2.09 |
# | median        |    80.00 |   79.25 | -0.75 |
# | std_dev       |     5.47 |    7.95 |  2.48 |
# | IQR           |     7.19 |   12.25 |  5.06 |
# | range         |    23.00 |   34.83 | 11.83 |
#
#
# ### Comparison Table: Object 39559 - airtempsCurrentTemp - Window 72 hours - Measured 791.1954375463624km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    45.00 |   40.00 |  -5.00 |
# | median        |    45.00 |   40.00 |  -5.00 |
# | std_dev       |     0.00 |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
# ...
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    26.00 |   17.80 |  -8.20 |
# | median        |    30.00 |   17.80 | -12.20 |
# | std_dev       |     5.48 |    0.00 |  -5.48 |
# | IQR           |    10.00 |    0.00 | -10.00 |
# | range         |    10.00 |    0.00 | -10.00 |
#
#
# ### Comparison Table: Object 56198 - distance - Window 72 hours - Measured 614.6463683621447km Away
# | Measurement   |   Before |   After |       Δ |
# |---------------|----------|---------|---------|
# | mean          |   503.46 |  341.88 | -161.58 |
# | median        |   611.18 |  341.88 | -269.30 |
# | std_dev       |   147.50 |    0.00 | -147.50 |
# | IQR           |   269.30 |    0.00 | -269.30 |
# | range         |   269.30 |    0.00 | -269.30 |
#
#
# ### Comparison Table: Object 56829 - airtempsCurrentTemp - Window 72 hours - Measured 396.85101644413004km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    27.53 |   28.87 |  1.35 |
# | median        |    28.35 |   30.20 |  1.85 |
# | std_dev       |     2.95 |    3.35 |  0.40 |
# | IQR           |     4.70 |    4.50 | -0.20 |
# | range         |    11.51 |   12.82 |  1.31 |
#
#
# ### Comparison Table: Object 56829 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 396.85101644413004km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.00 |    8.74 |  0.74 |
# | median        |     8.00 |    8.80 |  0.80 |
# | std_dev       |     1.63 |    1.41 | -0.22 |
# | IQR           |     3.00 |    2.15 | -0.85 |
# | range         |     4.00 |    3.30 | -0.70 |
#
#
# ### Comparison Table: Object 56829 - distance - Window 72 hours - Measured 396.85101644413004km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   385.20 |  385.36 | 0.16 |
# | median        |   360.94 |  360.94 | 0.00 |
# | std_dev       |    79.99 |   80.79 | 0.79 |
# | IQR           |    22.67 |   22.67 | 0.00 |
# | range         |   269.66 |  269.66 | 0.00 |
#
#
# ### Comparison Table: Object 56829 - humiditiesDewpoint - Window 72 hours - Measured 396.85101644413004km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    19.91 |   16.71 | -3.20 |
# | median        |    20.30 |   16.48 | -3.82 |
# | std_dev       |     1.67 |    2.47 |  0.79 |
# | IQR           |     1.60 |    4.31 |  2.71 |
# | range         |     6.80 |    8.92 |  2.12 |
#
#
# ### Comparison Table: Object 56829 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 396.85101644413004km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    63.73 |   49.44 | -14.29 |
# | median        |    60.00 |   45.50 | -14.50 |
# | std_dev       |    10.62 |   14.29 |   3.67 |
# | IQR           |    15.00 |   20.00 |   5.00 |
# | range         |    36.00 |   48.00 |  12.00 |
#
#
# ### Comparison Table: Object 56831 - airtempsCurrentTemp - Window 72 hours - Measured 309.71862105918444km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    28.16 |   27.71 | -0.45 |
# | median        |    27.63 |   27.23 | -0.40 |
# | std_dev       |     1.51 |    1.53 |  0.02 |
# | IQR           |     2.26 |    2.70 |  0.44 |
# | range         |     5.63 |    5.63 |  0.00 |
#
#
# ### Comparison Table: Object 56831 - distance - Window 72 hours - Measured 309.71862105918444km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   313.61 |  312.91 | -0.70 |
# | median        |   313.61 |  313.61 |  0.00 |
# | std_dev       |     0.00 |    4.35 |  4.35 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |   35.80 | 35.80 |
#
#
# ### Comparison Table: Object 56831 - humiditiesDewpoint - Window 72 hours - Measured 309.71862105918444km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     6.18 |    9.88 |  3.70 |
# | median        |     5.57 |    5.53 | -0.03 |
# | std_dev       |     2.23 |    6.90 |  4.67 |
# | IQR           |     1.02 |   12.03 | 11.02 |
# | range         |    11.90 |   20.23 |  8.33 |
#
#
# ### Comparison Table: Object 56831 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 309.71862105918444km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    55.78 |   59.06 |  3.28 |
# | median        |    56.33 |   59.33 |  3.00 |
# | std_dev       |     3.69 |    4.06 |  0.37 |
# | IQR           |     6.33 |    3.67 | -2.67 |
# | range         |    12.67 |   18.67 |  6.00 |
#
#
# ### Comparison Table: Object 57631 - airtempsCurrentTemp - Window 72 hours - Measured 286.5901343056066km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    28.14 |   28.78 |  0.64 |
# | median        |    29.35 |   29.75 |  0.40 |
# | std_dev       |     3.22 |    2.83 | -0.39 |
# | IQR           |     4.30 |    3.70 | -0.60 |
# | range         |    12.11 |   10.77 | -1.34 |
#
#
# ### Comparison Table: Object 57631 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 286.5901343056066km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |     8.15 |    8.45 | 0.30 |
# | median        |     8.40 |    8.90 | 0.50 |
# | std_dev       |     0.94 |    1.20 | 0.25 |
# | IQR           |     0.55 |    1.15 | 0.60 |
# | range         |     2.20 |    3.80 | 1.60 |
#
#
# ### Comparison Table: Object 57631 - dissolvedoxygensSalinityViaDokitPpt - Window 72 hours - Measured 286.5901343056066km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    35.90 |   34.67 |  -1.23 |
# | median        |    35.90 |   34.67 |  -1.23 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 57631 - distance - Window 72 hours - Measured 286.5901343056066km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   272.14 |  271.96 | -0.18 |
# | median        |   201.32 |  201.32 |  0.00 |
# | std_dev       |   103.20 |  103.51 |  0.31 |
# | IQR           |    86.14 |   86.14 |  0.00 |
# | range         |   332.61 |  332.61 |  0.00 |
#
#
# ### Comparison Table: Object 57631 - humiditiesDewpoint - Window 72 hours - Measured 286.5901343056066km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    16.53 |   20.11 |  3.58 |
# | median        |    16.70 |   20.33 |  3.63 |
# | std_dev       |     2.23 |    1.58 | -0.65 |
# | IQR           |     3.01 |    2.60 | -0.41 |
# | range         |     9.70 |    5.50 | -4.20 |
#
#
# ### Comparison Table: Object 57631 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 286.5901343056066km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    51.92 |   60.56 |   8.65 |
# | median        |    46.50 |   60.00 |  13.50 |
# | std_dev       |    15.98 |   10.30 |  -5.68 |
# | IQR           |    24.99 |   14.00 | -10.99 |
# | range         |    53.00 |   43.44 |  -9.56 |
#
#
# ### Comparison Table: Object 57989 - airtempsCurrentTemp - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    22.00 |   32.00 |  10.00 |
# | median        |    22.00 |   32.00 |  10.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 57989 - distance - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   550.58 |  849.94 | 299.36 |
# | median        |   550.69 |  849.94 | 299.26 |
# | std_dev       |     1.12 |    0.00 |  -1.12 |
# | IQR           |     1.12 |    0.00 |  -1.12 |
# | range         |     2.24 |    0.00 |  -2.24 |
#
#
# ### Comparison Table: Object 57989 - humiditiesDewpoint - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    21.30 |   25.30 |   4.00 |
# | median        |    21.30 |   25.30 |   4.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 57989 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    96.00 |   70.00 | -26.00 |
# | median        |    96.00 |   70.00 | -26.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 58904 - airtempsCurrentTemp - Window 72 hours - Measured 638.4413549968441km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    14.86 |   16.47 | 1.61 |
# | median        |    14.03 |   15.93 | 1.90 |
# | std_dev       |     2.17 |    2.54 | 0.37 |
# | IQR           |     3.33 |    4.26 | 0.93 |
# | range         |     7.73 |    8.73 | 1.00 |
#
#
# ### Comparison Table: Object 58904 - distance - Window 72 hours - Measured 638.4413549968441km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   595.64 |  595.64 |  0.00 |
# | median        |   595.64 |  595.64 |  0.00 |
# | std_dev       |     0.00 |    0.00 |  0.00 |
# | IQR           |     0.00 |    0.00 | -0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 58904 - humiditiesDewpoint - Window 72 hours - Measured 638.4413549968441km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    11.81 |    9.90 | -1.91 |
# | median        |    11.60 |    9.63 | -1.97 |
# | std_dev       |     1.53 |    1.32 | -0.21 |
# | IQR           |     1.88 |    2.38 |  0.50 |
# | range         |     6.03 |    4.63 | -1.40 |
#
#
# ### Comparison Table: Object 58904 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 638.4413549968441km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    82.40 |   66.42 | -15.98 |
# | median        |    83.33 |   68.00 | -15.33 |
# | std_dev       |     4.57 |    9.32 |   4.75 |
# | IQR           |     7.75 |   11.50 |   3.75 |
# | range         |    18.00 |   37.33 |  19.33 |
#
#
# ### Comparison Table: Object 59592 - airtempsCurrentTemp - Window 72 hours - Measured 546.3163716490276km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    20.61 |   21.96 |  1.35 |
# | median        |    21.40 |   22.90 |  1.50 |
# | std_dev       |     2.51 |    2.75 |  0.24 |
# | IQR           |     2.98 |    2.85 | -0.13 |
# | range         |    10.94 |   11.82 |  0.88 |
#
#
# ### Comparison Table: Object 59592 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 546.3163716490276km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.55 |    8.25 | -0.30 |
# | median        |     8.55 |    7.00 | -1.55 |
# | std_dev       |     0.78 |    2.61 |  1.83 |
# | IQR           |     0.55 |    4.25 |  3.70 |
# | range         |     1.10 |    6.50 |  5.40 |
#
#
# ### Comparison Table: Object 59592 - distance - Window 72 hours - Measured 546.3163716490276km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   538.01 |  537.38 | -0.63 |
# | median        |   506.03 |  506.03 |  0.00 |
# | std_dev       |    62.60 |   62.09 | -0.51 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |   171.12 |  164.60 | -6.52 |
#
#
# ### Comparison Table: Object 59592 - humiditiesDewpoint - Window 72 hours - Measured 546.3163716490276km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    12.13 |   12.90 |  0.76 |
# | median        |    12.20 |   12.50 |  0.30 |
# | std_dev       |     1.45 |    1.55 |  0.10 |
# | IQR           |     2.50 |    2.05 | -0.45 |
# | range         |     5.01 |    5.56 |  0.55 |
#
#
# ### Comparison Table: Object 59592 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 546.3163716490276km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    58.96 |   56.89 | -2.07 |
# | median        |    57.00 |   57.00 |  0.00 |
# | std_dev       |     8.70 |   10.17 |  1.47 |
# | IQR           |     9.62 |    9.00 | -0.62 |
# | range         |    40.79 |   44.51 |  3.72 |
#
#
# ### Comparison Table: Object 59665 - airtempsCurrentTemp - Window 72 hours - Measured 563.6647406375927km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.69 |   28.25 | -2.44 |
# | median        |    30.35 |   27.90 | -2.45 |
# | std_dev       |     1.45 |    1.54 |  0.09 |
# | IQR           |     2.48 |    1.88 | -0.60 |
# | range         |     5.70 |    5.95 |  0.25 |
#
#
# ### Comparison Table: Object 59665 - distance - Window 72 hours - Measured 563.6647406375927km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   528.42 |  528.42 |  0.00 |
# | median        |   528.42 |  528.42 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 59665 - humiditiesDewpoint - Window 72 hours - Measured 563.6647406375927km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    26.48 |   26.35 | -0.13 |
# | median        |    26.40 |   26.45 |  0.05 |
# | std_dev       |     0.51 |    0.57 |  0.06 |
# | IQR           |     0.82 |    0.73 | -0.10 |
# | range         |     1.90 |    2.25 |  0.35 |
#
#
# ### Comparison Table: Object 59665 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 563.6647406375927km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    78.71 |   89.87 | 11.17 |
# | median        |    78.50 |   91.50 | 13.00 |
# | std_dev       |     6.29 |    5.39 | -0.90 |
# | IQR           |     9.00 |    6.50 | -2.50 |
# | range         |    22.50 |   20.00 | -2.50 |
#
#
# ### Comparison Table: Object 60337 - airtempsCurrentTemp - Window 72 hours - Measured 422.00784025949895km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    14.90 |   15.60 |   0.70 |
# | median        |    14.90 |   15.60 |   0.70 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 60337 - distance - Window 72 hours - Measured 422.00784025949895km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   422.01 |  422.01 | 0.00 |
# | median        |   422.01 |  422.01 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |

# %%
# Initialize a structure to hold the changes
aggregated_changes = {}

for win in time_windows:
    for obj_id in matching_objects:
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()

        if not before_data.empty and not after_data.empty:
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns

            for column in numeric_cols:
                # Drop NaN values explicitly before statistic calculations
                before_series = before_data[column].dropna()
                after_series = after_data[column].dropna()

                # Ensure we have enough data after dropping NaNs for meaningful calculations
                if len(before_series) > 1 and len(after_series) > 1:
                    before_stats = calculate_stats_series(before_series)
                    after_stats = calculate_stats_series(after_series)

                    # Handle potential NaNs in specific statistics
                    if 'std_dev' in before_stats and 'std_dev' in after_stats:
                        if np.isnan(before_stats['std_dev']) or np.isnan(after_stats['std_dev']):
                            continue  # Skip further processing for cases with NaN std_dev
                        
                    stats_difference = {key: after_stats[key] - before_stats[key] for key in before_stats}
                    
                    if column not in aggregated_changes:
                        aggregated_changes[column] = {key: [] for key in stats_difference}
                        
                    for key in stats_difference:
                        aggregated_changes[column][key].append(stats_difference[key])
# Compute aggregate statistics, e.g., mean and standard deviation of changes
for column, changes in aggregated_changes.items():
    for stat, values in changes.items():
        values_np = np.array(values)
        aggregated_changes[column][stat] = {
            "mean_change": np.mean(values_np),
            "stddev_change": np.std(values_np)
        }

# Display the aggregated changes
for column, stats in aggregated_changes.items():
    print(f"### Aggregated Changes for Measurement: {column}")
    for stat, data in stats.items():
        mean_change = data['mean_change']
        stddev_change = data['stddev_change']

        print(f"{stat}: Mean Change = {mean_change:.2f}, Std Dev of Change = {stddev_change:.2f}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_344056/3965510530.py in ?()
#      10             numeric_cols = before_data.select_dtypes(include=[np.number]).columns
#      11
#      12             for column in numeric_cols:
#      13                 # Drop NaN values explicitly before statistic calculations
# ---> 14                 before_series = before_data[column].dropna()
#      15                 after_series = after_data[column].dropna()
#      16
#      17                 # Ensure we have enough data after dropping NaNs for meaningful calculations
#
# ~/code/GLOBE-research/.venv/lib/python3.12/site-packages/pandas/core/series.py in ?(self, axis, inplace, how, ignore_index)
#    5896         # Validate the axis parameter
#    5897         self._get_axis_number(axis or 0)
#    5898
#    5899         if self._can_hold_na:
# -> 5900             result = remove_na_arraylike(self)
#    5901         else:
#    5902             if not inplace:
#    5903                 result = self.copy(deep=None)
#
# ~/code/GLOBE-research/.venv/lib/python3.12/site-packages/pandas/core/dtypes/missing.py in ?(arr)
#     721     """
#     722     if isinstance(arr.dtype, ExtensionDtype):
#     723         return arr[notna(arr)]
#     724     else:
# --> 725         return arr[notna(np.asarray(arr))]
#
# ~/code/GLOBE-research/.venv/lib/python3.12/site-packages/pandas/core/series.py in ?(self, key)
#    1147
#    1148         if com.is_bool_indexer(key):
#    1149             key = check_bool_indexer(self.index, key)
#    1150             key = np.asarray(key, dtype=bool)
# -> 1151             return self._get_rows_with_mask(key)
#    1152
#    1153         return self._get_with(key)
#
# ~/code/GLOBE-research/.venv/lib/python3.12/site-packages/pandas/core/series.py in ?(self, indexer)
#    1216     def _get_rows_with_mask(self, indexer: npt.NDArray[np.bool_]) -> Series:
#    1217         new_mgr = self._mgr.get_rows_with_mask(indexer)
# -> 1218         return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(self)
#
# ~/code/GLOBE-research/.venv/lib/python3.12/site-packages/pandas/core/series.py in ?(self, mgr, axes)
#     664     def _constructor_from_mgr(self, mgr, axes):
#     665         ser = Series._from_mgr(mgr, axes=axes)
# --> 666         ser._name = None  # caller is responsible for setting real name
#     667
#     668         if type(self) is Series:
#     669             # This would also work `if self._constructor is Series`, but
#
# ~/code/GLOBE-research/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name, value)
#    6316
#    6317         # if this fails, go on to more involved attribute setting
#    6318         # (note that this matches __getattr__, above).
#    6319         if name in self._internal_names_set:
# -> 6320             object.__setattr__(self, name, value)
#    6321         elif name in self._metadata:
#    6322             object.__setattr__(self, name, value)
#    6323         else:
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.colors as mcolors
import matplotlib.cm as cm

# Data storage
hist_data = {}

for win in time_windows:
    for obj_id in matching_objects:
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()
        
        if not before_data.empty and not after_data.empty:
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns

            for column in numeric_cols:
                before_stats = calculate_stats_series(before_data[column].dropna())
                after_stats = calculate_stats_series(after_data[column].dropna())

                stats_difference = {key: after_stats[key] - before_stats[key] for key in before_stats}
                stats_difference["distance"] = distance  # Store distance
                
                if column in hist_data:
                    hist_data[column].append(stats_difference)
                else:
                    hist_data[column] = [stats_difference]

# Function to plot histograms with bin colors based on distance

def plot_histograms(data, value, pdf=None):
    for key, values in data.items():
        means = [entry[value] for entry in values if not np.isnan(entry[value])]
        distances = [entry["distance"] for entry in values if not np.isnan(entry[value])]

        if len(means) < 16:
            continue

        if means:
            fig, ax = plt.subplots(figsize=(8, 6))
            counts, bins, patches = ax.hist(means, bins=10, edgecolor='black')

            norm = mcolors.Normalize(vmin=min(distances), vmax=max(distances))
            colormap = cm.viridis
            
            for bin_patch, dist in zip(patches, distances):
                bin_patch.set_facecolor(colormap(norm(dist)))

            sm = cm.ScalarMappable(cmap=colormap, norm=norm)
            sm.set_array([])
            cbar = fig.colorbar(sm, ax=ax, label="Distance")
            
            ax.set_title(f"{value} Difference of {key}")
            ax.set_xlabel("Delta")
            ax.set_ylabel("Frequency")
            
            if pdf:
                pdf.savefig(fig)
                plt.close(fig)
            else:
                plt.show()

with PdfPages("outputs/histograms.pdf") as pdf:
    plot_histograms(hist_data, "mean", pdf)
    plot_histograms(hist_data, "std_dev", pdf)
    plot_histograms(hist_data, "range", pdf)
