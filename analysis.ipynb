# %% [markdown]
# # Data analysis
#
# We would like to find statistically significant changes in the data after debris reentry. To do this we will first do the following analysis:
#
# 1. Statistical Differences (before & after reentry)
#     - Mean
#     - Median
#     - Standard Deviation
# 2. Anomaly Detection
# 3. Range of change
# 4. Cumulative Unsigned Rate of Change
#
# Finally, we will train an AI model on the data or some selected metrics and we will see how well it performs in predicting reentry events.

# %%
import pandas as pd

# Load the CSV file
file_path = "outputs/output.csv"
df = pd.read_csv(file_path)

# Display headers and first few rows
df_head = df.head()

# Display last few rows to get an overall sense of the data
df_tail = df.tail()

df_head, df_tail
# Out:
# (                  date      object    distance  distance.1  \
#  0  2020-03-10T02:30:00  NORAD 6792  998.651955  998.651955
#  1  2020-03-10T05:00:00  NORAD 6792  998.651955  998.651955
#  2  2020-03-10T05:30:00  NORAD 6792  998.651955  998.651955
#  3  2020-03-10T08:30:00  NORAD 6792  998.651955  998.651955
#  4  2020-03-10T09:00:00  NORAD 6792  998.651955  998.651955
#
#     airtempsCurrentTemp  dissolvedoxygensDissolvedOxygenViaKitMgl  \
#  0                 31.7                                       NaN
#  1                 29.2                                       NaN
#  2                 28.4                                       NaN
#  3                 25.4                                       NaN
#  4                 23.4                                       NaN
#
#     dissolvedoxygensDissolvedOxygenViaProbeMgl  \
#  0                                         NaN
#  1                                         NaN
#  2                                         NaN
#  3                                         NaN
#  4                                         NaN
#
#     dissolvedoxygensSalinityViaDokitPpt  humiditiesDewpoint  \
#  0                                  NaN                25.5
#  1                                  NaN                25.1
#  2                                  NaN                24.7
#  3                                  NaN                23.1
#  4                                  NaN                22.4
#
#     humiditiesRelativeHumidityPercent
#  0                               69.0
#  1                               78.0
#  2                               80.0
#  3                               87.0
#  4                               94.0  ,
#                          date       object   distance  distance.1  \
#  1338652  2024-09-15T00:21:00  NORAD 60337  422.00784   422.00784
#  1338653  2024-09-14T00:21:00  NORAD 60337  422.00784   422.00784
#  1338654  2024-09-13T00:21:00  NORAD 60337  422.00784   422.00784
#  1338655  2024-09-12T00:21:00  NORAD 60337  422.00784   422.00784
#  1338656  2024-09-11T00:21:00  NORAD 60337  422.00784   422.00784
#
#           airtempsCurrentTemp  dissolvedoxygensDissolvedOxygenViaKitMgl  \
#  1338652                 14.0                                       NaN
#  1338653                 12.1                                       NaN
#  1338654                 13.0                                       NaN
#  1338655                 14.3                                       NaN
#  1338656                 15.3                                       NaN
#
#           dissolvedoxygensDissolvedOxygenViaProbeMgl  \
#  1338652                                         NaN
#  1338653                                         NaN
#  1338654                                         NaN
#  1338655                                         NaN
#  1338656                                         NaN
#
#           dissolvedoxygensSalinityViaDokitPpt  humiditiesDewpoint  \
#  1338652                                  NaN                 NaN
#  1338653                                  NaN                 NaN
#  1338654                                  NaN                 NaN
#  1338655                                  NaN                 NaN
#  1338656                                  NaN                 NaN
#
#           humiditiesRelativeHumidityPercent
#  1338652                                NaN
#  1338653                                NaN
#  1338654                                NaN
#  1338655                                NaN
#  1338656                                NaN  )

# %%
# Extract the object numbers from the re-entry log
reentry_objects = set()  # Using a set for quick lookup

with open("outputs/near-reentry-log.txt", "r") as file:
    for line in file:
        parts = line.split()
        if len(parts) > 1 and parts[1].isdigit():
            reentry_objects.add(parts[1])  # Extract the object number

# Extract object numbers from the dataset
df["object_id"] = df["object"].str.extract(r'(\d+)')  # Extract numeric part of "object"
df["object_id"] = df["object_id"].astype(str)

# Find matching objects in the dataset
matching_objects = df[df["object_id"].isin(reentry_objects)]["object_id"].unique()

# Count how many re-entry objects have matching data
num_matches = len(matching_objects)
num_total = len(reentry_objects)

num_matches, num_total, matching_objects
# Out:
# (108,
#  241,
#  array(['6792', '9911', '25274', '25469', '26476', '26640', '26692',
#         '27613', '28130', '28418', '28641', '28921', '29247', '29386',
#         '29482', '29512', '29664', '32751', '32765', '34603', '36749',
#         '38037', '38047', '38048', '38872', '38994', '39069', '39083',
#         '39259', '39482', '39559', '39566', '39572', '39649', '40313',
#         '40422', '40729', '40913', '40963', '41107', '41574', '41575',
#         '41576', '41640', '41777', '41839', '41865', '42704', '42903',
#         '42972', '43101', '43624', '43673', '43684', '44251', '44385',
#         '44820', '44924', '44939', '45076', '45091', '45103', '45203',
#         '45392', '45612', '45704', '45736', '46365', '46368', '46536',
#         '46673', '46769', '47168', '47396', '47569', '47570', '47605',
#         '47741', '47801', '47999', '48409', '48579', '48665', '48809',
#         '49223', '49339', '49386', '49524', '49923', '50164', '51967',
#         '52279', '52512', '52691', '53270', '53759', '53808', '55606',
#         '56198', '56829', '56831', '57631', '57989', '58904', '59589',
#         '59592', '59665', '60337'], dtype=object))

# %% [markdown]
# Now that we have the data for reentry time matched to our extracted GLOBE measurements, we can proceed with further analysis.

# %%
from datetime import datetime, timedelta

# Convert date columns to datetime
df["date"] = pd.to_datetime(df["date"])

reentry_times = {}

with open("outputs/near-reentry-log.txt", "r") as file:
    for line in file:
        parts = line.strip().rstrip(".").split()  # Remove trailing period and split
        if len(parts) > 1 and parts[1].isdigit():
            object_id = parts[1]
            timestamp_str = f"{parts[-2]} {parts[-1]}"  # Extract date and time
            try:
                reentry_times[object_id] = datetime.strptime(timestamp_str, "%Y-%m-%d %H:%M:%S")
            except ValueError as e:
                print(f"Error parsing timestamp for object {object_id}: {timestamp_str} -> {e}")

# Check if parsing succeeded
len(reentry_times)
# Out:
# 241

# %%
# Define time windows before and after reentry (24 and 48 hours)
time_windows = [72]

# Create dictionaries to store time series data
time_series_data = {win: {"before": [], "after": [], "distance": []} for win in time_windows}

# Extract data within the time windows
for obj_id in matching_objects:
    if obj_id in reentry_times:
        reentry_time = reentry_times[obj_id]

        for win in time_windows:
            time_before = reentry_time - timedelta(hours=win)
            time_after = reentry_time + timedelta(hours=win)

            # Select data within the time window
            before_reentry = df[(df["object_id"] == obj_id) & (df["date"] >= time_before) & (df["date"] < reentry_time)]
            after_reentry = df[(df["object_id"] == obj_id) & (df["date"] > reentry_time) & (df["date"] <= time_after)]

            time_series_data[win]["before"].append(before_reentry)
            time_series_data[win]["after"].append(after_reentry)
            time_series_data[win]["distance"].append(df[["distance", "object_id"]][df["object_id"] == obj_id])


# Concatenate results into DataFrames
for win in time_windows:
    time_series_data[win]["before"] = pd.concat(time_series_data[win]["before"])
    time_series_data[win]["after"] = pd.concat(time_series_data[win]["after"])
    time_series_data[win]["distance"] = pd.concat(time_series_data[win]["distance"])

# Display a summary of extracted data
{win: {"before_count": len(time_series_data[win]["before"]), "after_count": len(time_series_data[win]["after"]), "distance_count": len(time_series_data[win]["distance"])} for win in time_windows}
# Out:
# {72: {'before_count': 138388,
#   'after_count': 139326,
#   'distance_count': 1338657}}

# %%
import random

# Randomly select 5 objects from the matching ones
random_objects = random.sample(list(matching_objects), 5)

random_objects
# Out:
# ['45612', '40963', '39649', '29386', '38037']

# %%
import numpy as np

# Function to compute baseline statistics for numeric columns
def compute_stats(df):
    # Select only numeric columns
    df_numeric = df.select_dtypes(include=[np.number])
    df_numeric.dropna(inplace=True, axis=1, how="all")
    
    stats = {
        "mean": df_numeric.mean(),
        "median": df_numeric.median(),
        "std_dev": df_numeric.std(),
        "IQR": df_numeric.quantile(0.75) - df_numeric.quantile(0.25),
        "range": df_numeric.max() - df_numeric.min()
    }
    return stats

# Prepare a dictionary to store the results by object
baseline_stats_by_object = {}

for win in time_windows:
    for obj_id in matching_objects:
        # Get the data for the current object
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()
        
        if obj_id not in baseline_stats_by_object:
            baseline_stats_by_object[obj_id] = {}
        
        baseline_stats_by_object[obj_id][win] = {
            "before": compute_stats(before_data),
            "after": compute_stats(after_data),
            "distance": distance
        }

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate  # used to output markdown tables

def calculate_stats_series(series, trim_percentile=5):
    """Calculate statistics for a pandas Series after removing outliers based on a given percentile and return a dictionary."""
    
    # Sort the series to find the cut-off points for trimming
    series_sorted = series.sort_values()
    
    # Calculate the trim cut-off points based on the given percentile
    lower_trim = series_sorted.quantile(trim_percentile / 100)
    upper_trim = series_sorted.quantile(1 - trim_percentile / 100)
    
    # Remove outliers based on the trim values (both lower and upper)
    trimmed_series = series_sorted[
        (series_sorted >= lower_trim) & (series_sorted <= upper_trim)
    ]
    
    # Calculate statistics on the trimmed data
    stats = {
        "mean": trimmed_series.mean(),
        "median": trimmed_series.median(),
        "std_dev": trimmed_series.std(),
        "IQR": trimmed_series.quantile(0.75) - trimmed_series.quantile(0.25),
        "range": trimmed_series.max() - trimmed_series.min(),
    }
    
    return stats


# Dictionary to store the comparison tables
comparison_tables = {}

# Iterate over time windows and objects
for win in time_windows:
    for obj_id in matching_objects:
        # Filter before and after data for this object
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data  = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()
        
        # Proceed only if there is data in both periods
        if not before_data.empty and not after_data.empty:
            # Determine which numeric measurements are available
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns
            for column in numeric_cols:
                # Get the measurement series for before and after (dropping NaN)
                before_series = before_data[column].dropna()
                after_series  = after_data[column].dropna()
                
                if not before_series.empty and not after_series.empty:
                    # Compute statistics for each measurement
                    before_stats = calculate_stats_series(before_series)
                    after_stats  = calculate_stats_series(after_series)
                    
                    # Build a DataFrame for this measurement's comparison
                    comp_df = pd.DataFrame({
                        "Before": pd.Series(before_stats),
                        "After": pd.Series(after_stats)
                    })
                    comp_df.index.name = "Measurement"

                    # Add a Δ column
                    comp_df["Δ"] = comp_df["After"] - comp_df["Before"]
                    
                    # Build a table name that includes the object and measurement name
                    table_name = f"Object {obj_id} - {column} - Window {win} hours - Measured {distance}km Away"
                    comparison_tables[table_name] = comp_df

# %%
# Output each table in Markdown format
for table_name, df in comparison_tables.items():
    print(f"### Comparison Table: {table_name}")
    print(df.to_markdown(tablefmt="github", floatfmt=".2f"))
    print("\n")
# Out:
# ### Comparison Table: Object 6792 - distance - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   998.65 |  998.65 |  0.00 |
# | median        |   998.65 |  998.65 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 6792 - distance.1 - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   998.65 |  998.65 |  0.00 |
# | median        |   998.65 |  998.65 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 6792 - airtempsCurrentTemp - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    29.91 |   26.37 | -3.54 |
# | median        |    27.90 |   25.50 | -2.40 |
# | std_dev       |     4.29 |    3.32 | -0.97 |
# | IQR           |     8.15 |    5.15 | -3.00 |
# | range         |    12.40 |   12.60 |  0.20 |
#
#
# ### Comparison Table: Object 6792 - humiditiesDewpoint - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    22.04 |   22.82 |  0.78 |
# | median        |    23.40 |   22.50 | -0.90 |
# | std_dev       |     2.66 |    1.19 | -1.47 |
# | IQR           |     3.30 |    2.10 | -1.20 |
# | range         |     8.60 |    3.90 | -4.70 |
#
#
# ### Comparison Table: Object 6792 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 998.3148785401547km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    67.23 |   82.50 |  15.27 |
# | median        |    76.00 |   85.50 |   9.50 |
# | std_dev       |    22.10 |   11.34 | -10.77 |
# | IQR           |    41.00 |   16.00 | -25.00 |
# | range         |    64.00 |   46.00 | -18.00 |
#
#
# ### Comparison Table: Object 9911 - distance - Window 72 hours - Measured 926.0789325270598km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   902.76 |  905.35 |  2.59 |
# | median        |   884.94 |  884.94 |  0.00 |
# | std_dev       |    38.75 |   42.19 |  3.44 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |   137.25 |  162.59 | 25.34 |
#
#
# ### Comparison Table: Object 9911 - distance.1 - Window 72 hours - Measured 926.0789325270598km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   902.76 |  905.35 |  2.59 |
# | median        |   884.94 |  884.94 |  0.00 |
# | std_dev       |    38.75 |   42.19 |  3.44 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |   137.25 |  162.59 | 25.34 |
#
#
# ### Comparison Table: Object 9911 - airtempsCurrentTemp - Window 72 hours - Measured 926.0789325270598km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.80 |   24.18 | -0.62 |
# | median        |    25.00 |   24.00 | -1.00 |
# | std_dev       |     2.36 |    1.96 | -0.40 |
# | IQR           |     4.00 |    3.20 | -0.80 |
# | range         |     8.50 |    8.70 |  0.20 |
#
#
# ### Comparison Table: Object 9911 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 926.0789325270598km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |     3.00 |    8.78 |   5.78 |
# | median        |     3.00 |    9.00 |   6.00 |
# | std_dev       |   nan    |    1.25 | nan    |
# | IQR           |     0.00 |    1.60 |   1.60 |
# | range         |     0.00 |    3.50 |   3.50 |
#
#
# ### Comparison Table: Object 9911 - humiditiesDewpoint - Window 72 hours - Measured 926.0789325270598km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    18.75 |   17.41 | -1.34 |
# | median        |    19.00 |   16.60 | -2.40 |
# | std_dev       |     1.30 |    2.16 |  0.86 |
# | IQR           |     1.60 |    4.50 |  2.90 |
# | range         |     7.40 |    7.40 |  0.00 |
#
#
# ### Comparison Table: Object 9911 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 926.0789325270598km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    71.54 |   67.29 | -4.25 |
# | median        |    74.00 |   67.00 | -7.00 |
# | std_dev       |    10.49 |   11.56 |  1.06 |
# | IQR           |    18.00 |   14.00 | -4.00 |
# | range         |    38.00 |   42.00 |  4.00 |
#
#
# ### Comparison Table: Object 25469 - distance - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   993.80 |  993.80 |  0.00 |
# | median        |   993.80 |  993.80 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 25469 - distance.1 - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   993.80 |  993.80 |  0.00 |
# | median        |   993.80 |  993.80 |  0.00 |
# | std_dev       |     0.00 |    0.00 | -0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 25469 - airtempsCurrentTemp - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.81 |   23.40 | -1.41 |
# | median        |    24.05 |   22.90 | -1.15 |
# | std_dev       |     2.39 |    1.75 | -0.64 |
# | IQR           |     4.33 |    2.60 | -1.73 |
# | range         |     7.40 |    6.10 | -1.30 |
#
#
# ### Comparison Table: Object 25469 - humiditiesDewpoint - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    21.44 |   21.18 | -0.26 |
# | median        |    21.50 |   21.20 | -0.30 |
# | std_dev       |     0.68 |    0.79 |  0.11 |
# | IQR           |     1.30 |    1.30 |  0.00 |
# | range         |     2.30 |    3.10 |  0.80 |
#
#
# ### Comparison Table: Object 25469 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 993.8012023101774km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    81.98 |   87.89 |  5.91 |
# | median        |    85.50 |   89.00 |  3.50 |
# | std_dev       |     8.40 |    5.50 | -2.90 |
# | IQR           |    14.25 |    9.00 | -5.25 |
# | range         |    25.00 |   18.00 | -7.00 |
#
#
# ### Comparison Table: Object 26476 - distance - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   966.47 |  966.47 | 0.00 |
# | median        |   966.47 |  966.47 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 26476 - distance.1 - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   966.47 |  966.47 | 0.00 |
# | median        |   966.47 |  966.47 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 26476 - airtempsCurrentTemp - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    25.91 |   23.08 | -2.83 |
# | median        |    24.40 |   21.70 | -2.70 |
# | std_dev       |     4.49 |    5.00 |  0.51 |
# | IQR           |     8.55 |    8.75 |  0.20 |
# | range         |    14.10 |   17.10 |  3.00 |
#
#
# ### Comparison Table: Object 26476 - humiditiesDewpoint - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    19.97 |   11.21 | -8.76 |
# | median        |    19.80 |   11.85 | -7.95 |
# | std_dev       |     1.91 |    3.88 |  1.97 |
# | IQR           |     3.30 |    6.83 |  3.52 |
# | range         |     6.60 |   13.50 |  6.90 |
#
#
# ### Comparison Table: Object 26476 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 966.6090433319285km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    73.27 |   52.65 | -20.61 |
# | median        |    78.00 |   46.00 | -32.00 |
# | std_dev       |    15.13 |   22.84 |   7.71 |
# | IQR           |    26.00 |   47.50 |  21.50 |
# | range         |    52.00 |   65.00 |  13.00 |
#
#
# ### Comparison Table: Object 26640 - distance - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   449.57 |  449.57 | 0.00 |
# | median        |   478.34 |  478.34 | 0.00 |
# | std_dev       |    39.39 |   39.39 | 0.00 |
# | IQR           |    71.92 |   71.92 | 0.00 |
# | range         |    71.92 |   71.92 | 0.00 |
#
#
# ### Comparison Table: Object 26640 - distance.1 - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   449.57 |  449.57 | 0.00 |
# | median        |   478.34 |  478.34 | 0.00 |
# | std_dev       |    39.39 |   39.39 | 0.00 |
# | IQR           |    71.92 |   71.92 | 0.00 |
# | range         |    71.92 |   71.92 | 0.00 |
#
#
# ### Comparison Table: Object 26640 - airtempsCurrentTemp - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.40 |   29.48 | -0.93 |
# | median        |    32.00 |   30.00 | -2.00 |
# | std_dev       |     3.67 |    1.96 | -1.71 |
# | IQR           |     3.40 |    2.52 | -0.88 |
# | range         |     6.80 |    4.10 | -2.70 |
#
#
# ### Comparison Table: Object 26640 - humiditiesDewpoint - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    19.10 |   16.20 | -2.90 |
# | median        |    19.10 |   16.20 | -2.90 |
# | std_dev       |     0.00 |    0.00 |  0.00 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |     0.00 |    0.00 |  0.00 |
#
#
# ### Comparison Table: Object 26640 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 459.89652696332854km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    51.50 |   35.80 | -15.70 |
# | median        |    51.50 |   35.80 | -15.70 |
# | std_dev       |     0.00 |    0.00 |   0.00 |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 26692 - distance - Window 72 hours - Measured 883.5999578504238km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   866.89 |  895.97 |  29.08 |
# | median        |   866.89 |  895.97 |  29.08 |
# | std_dev       |    31.85 |    0.00 | -31.85 |
# | IQR           |    58.16 |    0.00 | -58.16 |
# | range         |    58.16 |    0.00 | -58.16 |
#
#
# ### Comparison Table: Object 26692 - distance.1 - Window 72 hours - Measured 883.5999578504238km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   866.89 |  895.97 |  29.08 |
# | median        |   866.89 |  895.97 |  29.08 |
# | std_dev       |    31.85 |    0.00 | -31.85 |
# | IQR           |    58.16 |    0.00 | -58.16 |
# | range         |    58.16 |    0.00 | -58.16 |
#
#
# ### Comparison Table: Object 26692 - airtempsCurrentTemp - Window 72 hours - Measured 883.5999578504238km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    26.84 |   30.10 |  3.26 |
# | median        |    28.00 |   30.10 |  2.10 |
# | std_dev       |     1.68 |    0.14 | -1.54 |
# | IQR           |     3.00 |    0.10 | -2.90 |
# | range         |     3.20 |    0.20 | -3.00 |
#
#
# ### Comparison Table: Object 27613 - distance - Window 72 hours - Measured 386.9994860250063km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   387.00 |  387.00 | 0.00 |
# | median        |   387.00 |  387.00 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 27613 - distance.1 - Window 72 hours - Measured 386.9994860250063km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   387.00 |  387.00 | 0.00 |
# | median        |   387.00 |  387.00 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 27613 - airtempsCurrentTemp - Window 72 hours - Measured 386.9994860250063km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    20.20 |   19.80 |  -0.40 |
# | median        |    20.20 |   19.80 |  -0.40 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 28130 - distance - Window 72 hours - Measured 764.4664886225555km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   789.19 |  805.83 |  16.64 |
# | median        |   881.92 |  882.93 |   1.01 |
# | std_dev       |   127.45 |  114.26 | -13.19 |
# | IQR           |   214.53 |  206.03 |  -8.50 |
# | range         |   397.86 |  299.44 | -98.42 |
#
#
# ### Comparison Table: Object 28130 - distance.1 - Window 72 hours - Measured 764.4664886225555km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   789.19 |  805.83 |  16.64 |
# | median        |   881.92 |  882.93 |   1.01 |
# | std_dev       |   127.45 |  114.26 | -13.19 |
# | IQR           |   214.53 |  206.03 |  -8.50 |
# | range         |   397.86 |  299.44 | -98.42 |
#
#
# ### Comparison Table: Object 28130 - airtempsCurrentTemp - Window 72 hours - Measured 764.4664886225555km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.57 |   31.01 |  0.44 |
# | median        |    31.00 |   31.00 |  0.00 |
# | std_dev       |     2.18 |    1.79 | -0.38 |
# | IQR           |     2.40 |    2.00 | -0.40 |
# | range         |     8.00 |    7.00 | -1.00 |
#
#
# ### Comparison Table: Object 28130 - humiditiesDewpoint - Window 72 hours - Measured 764.4664886225555km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    24.56 |   24.32 | -0.25 |
# | median        |    24.40 |   24.05 | -0.35 |
# | std_dev       |     2.14 |    2.25 |  0.11 |
# | IQR           |     2.50 |    2.98 |  0.48 |
# | range         |     8.00 |   10.30 |  2.30 |
#
#
# ### Comparison Table: Object 28130 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 764.4664886225555km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    73.56 |   72.04 | -1.52 |
# | median        |    72.90 |   71.80 | -1.10 |
# | std_dev       |    10.33 |   11.19 |  0.86 |
# | IQR           |    14.55 |   15.58 |  1.03 |
# | range         |    39.80 |   38.30 | -1.50 |
#
#
# ### Comparison Table: Object 28418 - distance - Window 72 hours - Measured 323.9355614993551km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   314.61 |  271.64 | -42.97 |
# | median        |   180.43 |  180.43 |   0.00 |
# | std_dev       |   257.21 |  203.36 | -53.85 |
# | IQR           |   136.10 |   79.36 | -56.74 |
# | range         |   774.23 |  701.40 | -72.84 |
#
#
# ### Comparison Table: Object 28418 - distance.1 - Window 72 hours - Measured 323.9355614993551km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   314.61 |  271.64 | -42.97 |
# | median        |   180.43 |  180.43 |   0.00 |
# | std_dev       |   257.21 |  203.36 | -53.85 |
# | IQR           |   136.10 |   79.36 | -56.74 |
# | range         |   774.23 |  701.40 | -72.84 |
#
#
# ### Comparison Table: Object 28418 - airtempsCurrentTemp - Window 72 hours - Measured 323.9355614993551km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    31.76 |   32.02 |  0.26 |
# | median        |    32.00 |   32.00 |  0.00 |
# | std_dev       |     1.64 |    1.40 | -0.23 |
# | IQR           |     3.00 |    2.00 | -1.00 |
# | range         |     7.00 |    5.00 | -2.00 |
#
#
# ### Comparison Table: Object 28418 - humiditiesDewpoint - Window 72 hours - Measured 323.9355614993551km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    17.37 |   16.80 |  -0.57 |
# | median        |    17.20 |   16.80 |  -0.40 |
# | std_dev       |     0.67 |  nan    | nan    |
# | IQR           |     0.65 |    0.00 |  -0.65 |
# | range         |     1.30 |    0.00 |  -1.30 |
#
#
# ### Comparison Table: Object 28418 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 323.9355614993551km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    56.40 |   42.60 | -13.80 |
# | median        |    54.40 |   42.60 | -11.80 |
# | std_dev       |     7.79 |  nan    | nan    |
# | IQR           |     7.60 |    0.00 |  -7.60 |
# | range         |    15.20 |    0.00 | -15.20 |
#
#
# ### Comparison Table: Object 28641 - distance - Window 72 hours - Measured 669.3637786271279km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   675.32 |  675.32 | 0.00 |
# | median        |   675.32 |  675.32 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 28641 - distance.1 - Window 72 hours - Measured 669.3637786271279km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   675.32 |  675.32 | 0.00 |
# | median        |   675.32 |  675.32 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 28641 - airtempsCurrentTemp - Window 72 hours - Measured 669.3637786271279km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    37.67 |   39.67 |  2.00 |
# | median        |    37.00 |   40.00 |  3.00 |
# | std_dev       |     1.15 |    0.58 | -0.58 |
# | IQR           |     1.00 |    0.50 | -0.50 |
# | range         |     2.00 |    1.00 | -1.00 |
#
#
# ### Comparison Table: Object 28921 - distance - Window 72 hours - Measured 490.54681130033947km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   464.62 |  471.46 |   6.84 |
# | median        |   418.98 |  424.00 |   5.02 |
# | std_dev       |   138.71 |  138.10 |  -0.61 |
# | IQR           |   260.88 |  258.84 |  -2.04 |
# | range         |   411.54 |  398.81 | -12.72 |
#
#
# ### Comparison Table: Object 28921 - distance.1 - Window 72 hours - Measured 490.54681130033947km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   464.62 |  471.46 |   6.84 |
# | median        |   418.98 |  424.00 |   5.02 |
# | std_dev       |   138.71 |  138.10 |  -0.61 |
# | IQR           |   260.88 |  258.84 |  -2.04 |
# | range         |   411.54 |  398.81 | -12.72 |
#
#
# ### Comparison Table: Object 28921 - airtempsCurrentTemp - Window 72 hours - Measured 490.54681130033947km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.64 |   30.25 | -0.39 |
# | median        |    30.00 |   30.00 |  0.00 |
# | std_dev       |     2.01 |    2.68 |  0.67 |
# | IQR           |     2.95 |    3.00 |  0.05 |
# | range         |     8.00 |   10.00 |  2.00 |
#
#
# ### Comparison Table: Object 28921 - humiditiesDewpoint - Window 72 hours - Measured 490.54681130033947km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    12.43 |   11.97 | -0.46 |
# | median        |    11.50 |   11.45 | -0.05 |
# | std_dev       |     6.62 |    6.65 |  0.03 |
# | IQR           |     8.70 |    8.73 |  0.03 |
# | range         |    16.60 |   19.60 |  3.00 |
#
#
# ### Comparison Table: Object 28921 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 490.54681130033947km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    40.46 |   39.76 | -0.70 |
# | median        |    30.20 |   34.55 |  4.35 |
# | std_dev       |    21.37 |   18.32 | -3.05 |
# | IQR           |    24.00 |   21.80 | -2.20 |
# | range         |    53.50 |   54.50 |  1.00 |
#
#
# ### Comparison Table: Object 29247 - distance - Window 72 hours - Measured 413.4173284101769km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   388.69 |  410.58 |  21.90 |
# | median        |   416.67 |  424.52 |   7.85 |
# | std_dev       |   133.52 |  173.13 |  39.61 |
# | IQR           |   211.32 |  318.34 | 107.02 |
# | range         |   328.79 |  328.79 |   0.00 |
#
#
# ### Comparison Table: Object 29247 - distance.1 - Window 72 hours - Measured 413.4173284101769km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   388.69 |  410.58 |  21.90 |
# | median        |   416.67 |  424.52 |   7.85 |
# | std_dev       |   133.52 |  173.13 |  39.61 |
# | IQR           |   211.32 |  318.34 | 107.02 |
# | range         |   328.79 |  328.79 |   0.00 |
#
#
# ### Comparison Table: Object 29247 - airtempsCurrentTemp - Window 72 hours - Measured 413.4173284101769km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    15.03 |   13.18 | -1.85 |
# | median        |    15.00 |   13.80 | -1.20 |
# | std_dev       |     0.89 |    1.08 |  0.19 |
# | IQR           |     0.90 |    2.00 |  1.10 |
# | range         |     2.60 |    2.10 | -0.50 |
#
#
# ### Comparison Table: Object 29386 - distance - Window 72 hours - Measured 1130.5694322701568km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |  1131.04 | 1130.54 | -0.50 |
# | median        |  1127.69 | 1127.69 |  0.00 |
# | std_dev       |    19.59 |   19.09 | -0.50 |
# | IQR           |    23.76 |   21.87 | -1.89 |
# | range         |    51.14 |   51.14 |  0.00 |
#
#
# ### Comparison Table: Object 29386 - distance.1 - Window 72 hours - Measured 1130.5694322701568km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |  1131.04 | 1130.54 | -0.50 |
# | median        |  1127.69 | 1127.69 |  0.00 |
# | std_dev       |    19.59 |   19.09 | -0.50 |
# | IQR           |    23.76 |   21.87 | -1.89 |
# | range         |    51.14 |   51.14 |  0.00 |
#
#
# ### Comparison Table: Object 29386 - airtempsCurrentTemp - Window 72 hours - Measured 1130.5694322701568km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    40.21 |   38.06 | -2.15 |
# | median        |    40.80 |   37.80 | -3.00 |
# | std_dev       |     3.55 |    3.70 |  0.15 |
# | IQR           |     3.20 |    3.50 |  0.30 |
# | range         |    10.70 |   12.70 |  2.00 |
#
#
# ### Comparison Table: Object 29386 - humiditiesDewpoint - Window 72 hours - Measured 1130.5694322701568km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    32.55 |   33.58 |  1.03 |
# | median        |    32.90 |   33.85 |  0.95 |
# | std_dev       |     2.99 |    2.62 | -0.36 |
# | IQR           |     3.90 |    4.07 |  0.18 |
# | range         |     6.60 |    5.20 | -1.40 |
#
#
# ### Comparison Table: Object 29386 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 1130.5694322701568km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    63.75 |   71.00 | 7.25 |
# | median        |    62.50 |   70.00 | 7.50 |
# | std_dev       |    13.77 |   16.15 | 2.38 |
# | IQR           |    18.75 |   23.50 | 4.75 |
# | range         |    30.00 |   34.00 | 4.00 |
#
#
# ### Comparison Table: Object 29482 - distance - Window 72 hours - Measured 978.6503854404525km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |  1009.23 | 1006.71 | -2.52 |
# | median        |  1014.81 | 1014.81 |  0.00 |
# | std_dev       |    28.46 |   35.79 |  7.33 |
# | IQR           |     5.41 |    5.41 |  0.00 |
# | range         |   257.42 |  294.06 | 36.64 |
#
#
# ### Comparison Table: Object 29482 - distance.1 - Window 72 hours - Measured 978.6503854404525km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |  1009.23 | 1006.71 | -2.52 |
# | median        |  1014.81 | 1014.81 |  0.00 |
# | std_dev       |    28.46 |   35.79 |  7.33 |
# | IQR           |     5.41 |    5.41 |  0.00 |
# | range         |   257.42 |  294.06 | 36.64 |
#
#
# ### Comparison Table: Object 29482 - airtempsCurrentTemp - Window 72 hours - Measured 978.6503854404525km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    16.79 |   14.12 | -2.67 |
# | median        |    16.20 |   14.00 | -2.20 |
# | std_dev       |     4.04 |    2.90 | -1.15 |
# | IQR           |     6.50 |    3.70 | -2.80 |
# | range         |    15.30 |   12.50 | -2.80 |
#
#
# ### Comparison Table: Object 29482 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 978.6503854404525km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.16 |    9.17 |  1.01 |
# | median        |     8.00 |    9.25 |  1.25 |
# | std_dev       |     2.40 |    1.70 | -0.71 |
# | IQR           |     2.35 |    1.70 | -0.65 |
# | range         |     7.60 |    6.50 | -1.10 |
#
#
# ### Comparison Table: Object 29482 - humiditiesDewpoint - Window 72 hours - Measured 978.6503854404525km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    10.48 |   12.71 |  2.23 |
# | median        |    10.60 |   13.10 |  2.50 |
# | std_dev       |     2.13 |    1.97 | -0.15 |
# | IQR           |     3.80 |    2.90 | -0.90 |
# | range         |     7.80 |    7.60 | -0.20 |
#
#
# ### Comparison Table: Object 29482 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 978.6503854404525km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    72.56 |   95.18 |  22.62 |
# | median        |    71.80 |   98.30 |  26.50 |
# | std_dev       |    18.39 |    7.35 | -11.03 |
# | IQR           |    30.70 |    3.60 | -27.10 |
# | range         |    62.00 |   34.60 | -27.40 |
#
#
# ### Comparison Table: Object 29664 - distance - Window 72 hours - Measured 1005.276677744487km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |  1005.28 | 1005.28 | 0.00 |
# | median        |  1005.28 | 1005.28 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 29664 - distance.1 - Window 72 hours - Measured 1005.276677744487km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |  1005.28 | 1005.28 | 0.00 |
# | median        |  1005.28 | 1005.28 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 29664 - airtempsCurrentTemp - Window 72 hours - Measured 1005.276677744487km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   -17.00 |   -9.00 |   8.00 |
# | median        |   -17.00 |   -9.00 |   8.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 32751 - distance - Window 72 hours - Measured 932.0357014945399km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   918.76 |  953.77 |  35.01 |
# | median        |  1043.05 | 1131.98 |  88.92 |
# | std_dev       |   278.34 |  264.25 | -14.09 |
# | IQR           |   431.89 |  447.16 |  15.27 |
# | range         |   904.24 |  918.74 |  14.50 |
#
#
# ### Comparison Table: Object 32751 - distance.1 - Window 72 hours - Measured 932.0357014945399km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   918.76 |  953.77 |  35.01 |
# | median        |  1043.05 | 1131.98 |  88.92 |
# | std_dev       |   278.34 |  264.25 | -14.09 |
# | IQR           |   431.89 |  447.16 |  15.27 |
# | range         |   904.24 |  918.74 |  14.50 |
#
#
# ### Comparison Table: Object 32751 - airtempsCurrentTemp - Window 72 hours - Measured 932.0357014945399km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    23.94 |   21.34 | -2.60 |
# | median        |    22.70 |   20.50 | -2.20 |
# | std_dev       |     4.98 |    5.29 |  0.31 |
# | IQR           |     6.42 |    8.00 |  1.58 |
# | range         |    18.70 |   22.60 |  3.90 |
#
#
# ### Comparison Table: Object 32751 - humiditiesDewpoint - Window 72 hours - Measured 932.0357014945399km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    11.42 |   11.93 |  0.51 |
# | median        |    10.30 |   11.80 |  1.50 |
# | std_dev       |     5.35 |    4.64 | -0.71 |
# | IQR           |     4.70 |    4.15 | -0.55 |
# | range         |    23.60 |   22.30 | -1.30 |
#
#
# ### Comparison Table: Object 32751 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 932.0357014945399km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    46.39 |   56.38 |  9.99 |
# | median        |    45.00 |   59.00 | 14.00 |
# | std_dev       |    12.15 |   13.63 |  1.48 |
# | IQR           |    15.00 |   18.25 |  3.25 |
# | range         |    47.00 |   53.00 |  6.00 |
#
#
# ### Comparison Table: Object 32765 - distance - Window 72 hours - Measured 805.2960520534998km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   788.02 |  807.80 |  19.78 |
# | median        |   841.16 |  904.68 |  63.52 |
# | std_dev       |   178.12 |  169.45 |  -8.68 |
# | IQR           |   356.36 |  335.78 | -20.58 |
# | range         |   472.67 |  440.84 | -31.83 |
#
#
# ### Comparison Table: Object 32765 - distance.1 - Window 72 hours - Measured 805.2960520534998km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   788.02 |  807.80 |  19.78 |
# | median        |   841.16 |  904.68 |  63.52 |
# | std_dev       |   178.12 |  169.45 |  -8.68 |
# | IQR           |   356.36 |  335.78 | -20.58 |
# | range         |   472.67 |  440.84 | -31.83 |
#
#
# ### Comparison Table: Object 32765 - airtempsCurrentTemp - Window 72 hours - Measured 805.2960520534998km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.40 |   31.14 |  0.75 |
# | median        |    30.30 |   30.40 |  0.10 |
# | std_dev       |     4.61 |    4.79 |  0.18 |
# | IQR           |     6.75 |    6.45 | -0.30 |
# | range         |    19.00 |   16.90 | -2.10 |
#
#
# ### Comparison Table: Object 32765 - humiditiesDewpoint - Window 72 hours - Measured 805.2960520534998km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    16.95 |   16.51 | -0.44 |
# | median        |    16.40 |   16.95 |  0.55 |
# | std_dev       |     7.08 |    8.27 |  1.19 |
# | IQR           |    10.10 |   11.95 |  1.85 |
# | range         |    25.70 |   28.20 |  2.50 |
#
#
# ### Comparison Table: Object 32765 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 805.2960520534998km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    43.83 |   43.61 | -0.21 |
# | median        |    40.00 |   44.00 |  4.00 |
# | std_dev       |    12.62 |   14.34 |  1.72 |
# | IQR           |    19.00 |   23.00 |  4.00 |
# | range         |    45.00 |   56.00 | 11.00 |
#
#
# ### Comparison Table: Object 34603 - distance - Window 72 hours - Measured 891.9137366220565km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   897.50 |  903.89 |   6.39 |
# | median        |   931.84 |  931.84 |   0.00 |
# | std_dev       |    78.78 |   70.17 |  -8.61 |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |   351.90 |  280.92 | -70.97 |
#
#
# ### Comparison Table: Object 34603 - distance.1 - Window 72 hours - Measured 891.9137366220565km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   897.50 |  903.89 |   6.39 |
# | median        |   931.84 |  931.84 |   0.00 |
# | std_dev       |    78.78 |   70.17 |  -8.61 |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |   351.90 |  280.92 | -70.97 |
#
#
# ### Comparison Table: Object 34603 - airtempsCurrentTemp - Window 72 hours - Measured 891.9137366220565km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    17.99 |   15.26 | -2.73 |
# | median        |    18.90 |   16.20 | -2.70 |
# | std_dev       |     4.17 |    4.77 |  0.59 |
# | IQR           |     7.80 |    8.13 |  0.33 |
# | range         |    14.30 |   16.80 |  2.50 |
#
#
# ### Comparison Table: Object 34603 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 891.9137366220565km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.20 |    5.32 | -2.88 |
# | median        |     8.00 |    5.45 | -2.55 |
# | std_dev       |     1.37 |    3.93 |  2.56 |
# | IQR           |     1.60 |    7.08 |  5.48 |
# | range         |     4.00 |    8.60 |  4.60 |
#
#
# ### Comparison Table: Object 34603 - humiditiesDewpoint - Window 72 hours - Measured 891.9137366220565km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     1.55 |    0.62 | -0.93 |
# | median        |     0.90 |    0.50 | -0.40 |
# | std_dev       |     3.19 |    3.15 | -0.04 |
# | IQR           |     5.60 |    3.90 | -1.70 |
# | range         |    12.60 |   14.60 |  2.00 |
#
#
# ### Comparison Table: Object 34603 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 891.9137366220565km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    37.25 |   41.51 |  4.27 |
# | median        |    35.00 |   43.00 |  8.00 |
# | std_dev       |    14.39 |   14.69 |  0.30 |
# | IQR           |    22.00 |   25.00 |  3.00 |
# | range         |    53.00 |   50.00 | -3.00 |
#
#
# ### Comparison Table: Object 36749 - distance - Window 72 hours - Measured 597.7783200039827km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   585.75 |  584.14 | -1.60 |
# | median        |   763.29 |  763.29 |  0.00 |
# | std_dev       |   273.87 |  274.10 |  0.23 |
# | IQR           |   587.90 |  587.90 |  0.00 |
# | range         |   623.23 |  623.23 |  0.00 |
#
#
# ### Comparison Table: Object 36749 - distance.1 - Window 72 hours - Measured 597.7783200039827km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   585.75 |  584.14 | -1.60 |
# | median        |   763.29 |  763.29 |  0.00 |
# | std_dev       |   273.87 |  274.10 |  0.23 |
# | IQR           |   587.90 |  587.90 |  0.00 |
# | range         |   623.23 |  623.23 |  0.00 |
#
#
# ### Comparison Table: Object 36749 - airtempsCurrentTemp - Window 72 hours - Measured 597.7783200039827km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    23.64 |   21.34 | -2.30 |
# | median        |    23.90 |   21.20 | -2.70 |
# | std_dev       |     4.93 |    4.23 | -0.71 |
# | IQR           |     8.70 |    7.40 | -1.30 |
# | range         |    16.80 |   15.40 | -1.40 |
#
#
# ### Comparison Table: Object 36749 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 597.7783200039827km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.81 |    8.68 | -0.14 |
# | median        |     9.00 |    8.80 | -0.20 |
# | std_dev       |     0.57 |    2.40 |  1.83 |
# | IQR           |     0.35 |    2.20 |  1.85 |
# | range         |     1.80 |    7.00 |  5.20 |
#
#
# ### Comparison Table: Object 36749 - humiditiesDewpoint - Window 72 hours - Measured 597.7783200039827km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    15.38 |   16.27 | 0.90 |
# | median        |    15.30 |   16.50 | 1.20 |
# | std_dev       |     1.59 |    2.22 | 0.63 |
# | IQR           |     2.50 |    3.40 | 0.90 |
# | range         |     6.80 |    8.70 | 1.90 |
#
#
# ### Comparison Table: Object 36749 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 597.7783200039827km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    63.49 |   75.94 | 12.45 |
# | median        |    61.60 |   76.10 | 14.50 |
# | std_dev       |    18.20 |   16.15 | -2.05 |
# | IQR           |    33.60 |   29.00 | -4.60 |
# | range         |    57.00 |   55.20 | -1.80 |
#
#
# ### Comparison Table: Object 38037 - distance - Window 72 hours - Measured 675.1092856085514km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   697.44 |  679.55 | -17.89 |
# | median        |   841.79 |  754.12 | -87.67 |
# | std_dev       |   187.44 |  191.33 |   3.90 |
# | IQR           |   420.75 |  424.12 |   3.38 |
# | range         |   442.36 |  442.36 |   0.00 |
#
#
# ### Comparison Table: Object 38037 - distance.1 - Window 72 hours - Measured 675.1092856085514km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   697.44 |  679.55 | -17.89 |
# | median        |   841.79 |  754.12 | -87.67 |
# | std_dev       |   187.44 |  191.33 |   3.90 |
# | IQR           |   420.75 |  424.12 |   3.38 |
# | range         |   442.36 |  442.36 |   0.00 |
#
#
# ### Comparison Table: Object 38037 - airtempsCurrentTemp - Window 72 hours - Measured 675.1092856085514km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     1.47 |    2.81 |  1.35 |
# | median        |     1.20 |    2.85 |  1.65 |
# | std_dev       |     3.03 |    1.84 | -1.19 |
# | IQR           |     3.00 |    2.20 | -0.80 |
# | range         |    17.80 |    8.70 | -9.10 |
#
#
# ### Comparison Table: Object 38037 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 675.1092856085514km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |     9.38 |   10.20 |   0.82 |
# | median        |     9.30 |   10.20 |   0.90 |
# | std_dev       |     0.43 |  nan    | nan    |
# | IQR           |     0.60 |    0.00 |  -0.60 |
# | range         |     1.00 |    0.00 |  -1.00 |
#
#
# ### Comparison Table: Object 38037 - humiditiesDewpoint - Window 72 hours - Measured 675.1092856085514km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    -1.01 |    0.18 |  1.19 |
# | median        |    -1.30 |    0.30 |  1.60 |
# | std_dev       |     3.33 |    2.61 | -0.73 |
# | IQR           |     4.90 |    4.60 | -0.30 |
# | range         |    16.20 |    8.70 | -7.50 |
#
#
# ### Comparison Table: Object 38037 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 675.1092856085514km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    85.13 |   85.28 |  0.14 |
# | median        |    89.00 |   90.00 |  1.00 |
# | std_dev       |    10.93 |   12.05 |  1.12 |
# | IQR           |    18.80 |   18.00 | -0.80 |
# | range         |    38.40 |   40.00 |  1.60 |
#
#
# ### Comparison Table: Object 38047 - distance - Window 72 hours - Measured 993.1989035174919km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   993.61 |  996.55 |  2.93 |
# | median        |   982.07 |  982.07 |  0.00 |
# | std_dev       |    41.58 |   44.09 |  2.51 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |   202.51 |  196.59 | -5.93 |
#
#
# ### Comparison Table: Object 38047 - distance.1 - Window 72 hours - Measured 993.1989035174919km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   993.61 |  996.55 |  2.93 |
# | median        |   982.07 |  982.07 |  0.00 |
# | std_dev       |    41.58 |   44.09 |  2.51 |
# | IQR           |     0.00 |    0.00 |  0.00 |
# | range         |   202.51 |  196.59 | -5.93 |
#
#
# ### Comparison Table: Object 38047 - airtempsCurrentTemp - Window 72 hours - Measured 993.1989035174919km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    18.04 |   15.13 | -2.90 |
# | median        |    18.00 |   14.60 | -3.40 |
# | std_dev       |     1.89 |    2.87 |  0.99 |
# | IQR           |     3.50 |    5.20 |  1.70 |
# | range         |     7.30 |    9.90 |  2.60 |
#
#
# ### Comparison Table: Object 38047 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 993.1989035174919km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     9.70 |    4.59 | -5.11 |
# | median        |     9.70 |    3.00 | -6.70 |
# | std_dev       |     0.14 |    2.42 |  2.28 |
# | IQR           |     0.10 |    2.35 |  2.25 |
# | range         |     0.20 |    6.40 |  6.20 |
#
#
# ### Comparison Table: Object 38047 - humiditiesDewpoint - Window 72 hours - Measured 993.1989035174919km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    14.86 |    3.93 | -10.93 |
# | median        |    15.80 |    3.90 | -11.90 |
# | std_dev       |     2.31 |    2.89 |   0.58 |
# | IQR           |     2.90 |    3.30 |   0.40 |
# | range         |     9.30 |   11.80 |   2.50 |
#
#
# ### Comparison Table: Object 38047 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 993.1989035174919km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    82.15 |   48.48 | -33.67 |
# | median        |    84.00 |   47.00 | -37.00 |
# | std_dev       |     8.39 |   10.50 |   2.11 |
# | IQR           |    14.00 |   17.00 |   3.00 |
# | range         |    32.00 |   39.00 |   7.00 |
#
#
# ### Comparison Table: Object 38872 - distance - Window 72 hours - Measured 572.0280721274904km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   556.96 |  558.78 | 1.81 |
# | median        |   541.65 |  541.65 | 0.00 |
# | std_dev       |    98.42 |  100.54 | 2.13 |
# | IQR           |   100.73 |  100.73 | 0.00 |
# | range         |   384.73 |  384.73 | 0.00 |
#
#
# ### Comparison Table: Object 38872 - distance.1 - Window 72 hours - Measured 572.0280721274904km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   556.96 |  558.78 | 1.81 |
# | median        |   541.65 |  541.65 | 0.00 |
# | std_dev       |    98.42 |  100.54 | 2.13 |
# | IQR           |   100.73 |  100.73 | 0.00 |
# | range         |   384.73 |  384.73 | 0.00 |
#
#
# ### Comparison Table: Object 38872 - airtempsCurrentTemp - Window 72 hours - Measured 572.0280721274904km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.82 |    6.23 | -2.59 |
# | median        |     8.85 |    5.50 | -3.35 |
# | std_dev       |     2.04 |    5.62 |  3.58 |
# | IQR           |     2.80 |    9.20 |  6.40 |
# | range         |    10.50 |   17.70 |  7.20 |
#
#
# ### Comparison Table: Object 38872 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 572.0280721274904km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.71 |    7.77 | -0.93 |
# | median        |     9.00 |    7.00 | -2.00 |
# | std_dev       |     1.82 |    1.28 | -0.54 |
# | IQR           |     3.10 |    1.75 | -1.35 |
# | range         |     5.50 |    3.30 | -2.20 |
#
#
# ### Comparison Table: Object 38872 - humiditiesDewpoint - Window 72 hours - Measured 572.0280721274904km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     7.44 |    4.92 | -2.53 |
# | median        |     7.80 |    4.10 | -3.70 |
# | std_dev       |     2.01 |    5.04 |  3.03 |
# | IQR           |     3.00 |    9.40 |  6.40 |
# | range         |     9.10 |   15.00 |  5.90 |
#
#
# ### Comparison Table: Object 38872 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 572.0280721274904km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    92.67 |   93.42 |  0.75 |
# | median        |    95.00 |   96.30 |  1.30 |
# | std_dev       |     7.50 |    6.90 | -0.60 |
# | IQR           |     8.00 |    8.00 |  0.00 |
# | range         |    31.00 |   25.00 | -6.00 |
#
#
# ### Comparison Table: Object 38994 - distance - Window 72 hours - Measured 713.3645180219295km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   739.11 |  739.11 | 0.00 |
# | median        |   739.11 |  739.11 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 38994 - distance.1 - Window 72 hours - Measured 713.3645180219295km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# ...
#
#
# ### Comparison Table: Object 56831 - distance - Window 72 hours - Measured 311.9033180032155km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   313.43 |  313.00 | -0.43 |
# | median        |   275.90 |  275.90 |  0.00 |
# | std_dev       |    99.28 |   99.03 | -0.25 |
# | IQR           |   234.62 |  234.62 |  0.00 |
# | range         |   234.62 |  234.62 |  0.00 |
#
#
# ### Comparison Table: Object 56831 - distance.1 - Window 72 hours - Measured 311.9033180032155km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   313.43 |  313.00 | -0.43 |
# | median        |   275.90 |  275.90 |  0.00 |
# | std_dev       |    99.28 |   99.03 | -0.25 |
# | IQR           |   234.62 |  234.62 |  0.00 |
# | range         |   234.62 |  234.62 |  0.00 |
#
#
# ### Comparison Table: Object 56831 - airtempsCurrentTemp - Window 72 hours - Measured 311.9033180032155km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    28.08 |   27.66 | -0.42 |
# | median        |    27.80 |   27.10 | -0.70 |
# | std_dev       |     1.96 |    1.74 | -0.22 |
# | IQR           |     2.70 |    2.50 | -0.20 |
# | range         |     7.30 |    6.60 | -0.70 |
#
#
# ### Comparison Table: Object 56831 - humiditiesDewpoint - Window 72 hours - Measured 311.9033180032155km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |     6.64 |   11.36 |   4.72 |
# | median        |    24.90 |   24.00 |  -0.90 |
# | std_dev       |    27.20 |   22.87 |  -4.33 |
# | IQR           |    58.60 |   18.60 | -40.00 |
# | range         |    61.70 |   61.10 |  -0.60 |
#
#
# ### Comparison Table: Object 56831 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 311.9033180032155km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    54.02 |   59.05 |   5.02 |
# | median        |    77.00 |   76.00 |  -1.00 |
# | std_dev       |    38.41 |   36.25 |  -2.16 |
# | IQR           |    84.00 |   70.00 | -14.00 |
# | range         |    91.00 |   94.00 |   3.00 |
#
#
# ### Comparison Table: Object 57631 - distance - Window 72 hours - Measured 420.02126792091366km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   404.86 |  404.55 | -0.32 |
# | median        |   287.45 |  287.45 |  0.00 |
# | std_dev       |   278.29 |  278.33 |  0.04 |
# | IQR           |   249.71 |  249.71 |  0.00 |
# | range         |  1113.35 | 1113.35 |  0.00 |
#
#
# ### Comparison Table: Object 57631 - distance.1 - Window 72 hours - Measured 420.02126792091366km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   404.86 |  404.55 | -0.32 |
# | median        |   287.45 |  287.45 |  0.00 |
# | std_dev       |   278.29 |  278.33 |  0.04 |
# | IQR           |   249.71 |  249.71 |  0.00 |
# | range         |  1113.35 | 1113.35 |  0.00 |
#
#
# ### Comparison Table: Object 57631 - airtempsCurrentTemp - Window 72 hours - Measured 420.02126792091366km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    25.91 |   26.72 |  0.81 |
# | median        |    27.10 |   27.80 |  0.70 |
# | std_dev       |     4.30 |    3.99 | -0.32 |
# | IQR           |     6.80 |    6.20 | -0.60 |
# | range         |    15.60 |   14.10 | -1.50 |
#
#
# ### Comparison Table: Object 57631 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 420.02126792091366km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     7.23 |    8.27 |  1.04 |
# | median        |     6.80 |    8.70 |  1.90 |
# | std_dev       |     1.33 |    1.57 |  0.24 |
# | IQR           |     2.40 |    1.98 | -0.42 |
# | range         |     3.00 |    4.55 |  1.55 |
#
#
# ### Comparison Table: Object 57631 - dissolvedoxygensSalinityViaDokitPpt - Window 72 hours - Measured 420.02126792091366km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    35.90 |   35.00 |  -0.90 |
# | median        |    35.90 |   35.00 |  -0.90 |
# | std_dev       |   nan    |    0.00 | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 57631 - humiditiesDewpoint - Window 72 hours - Measured 420.02126792091366km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    16.98 |   19.62 |  2.64 |
# | median        |    17.00 |   19.70 |  2.70 |
# | std_dev       |     2.09 |    1.69 | -0.40 |
# | IQR           |     3.10 |    2.70 | -0.40 |
# | range         |     8.60 |    6.30 | -2.30 |
#
#
# ### Comparison Table: Object 57631 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 420.02126792091366km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    61.26 |   67.58 |   6.32 |
# | median        |    58.00 |   65.00 |   7.00 |
# | std_dev       |    18.13 |   13.73 |  -4.40 |
# | IQR           |    31.00 |   22.00 |  -9.00 |
# | range         |    60.00 |   50.00 | -10.00 |
#
#
# ### Comparison Table: Object 57989 - distance - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   550.58 |  849.94 | 299.36 |
# | median        |   550.69 |  849.94 | 299.26 |
# | std_dev       |     1.12 |    0.00 |  -1.12 |
# | IQR           |     1.12 |    0.00 |  -1.12 |
# | range         |     2.24 |    0.00 |  -2.24 |
#
#
# ### Comparison Table: Object 57989 - distance.1 - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |   550.58 |  849.94 | 299.36 |
# | median        |   550.69 |  849.94 | 299.26 |
# | std_dev       |     1.12 |    0.00 |  -1.12 |
# | IQR           |     1.12 |    0.00 |  -1.12 |
# | range         |     2.24 |    0.00 |  -2.24 |
#
#
# ### Comparison Table: Object 57989 - airtempsCurrentTemp - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    22.00 |   32.00 |  10.00 |
# | median        |    22.00 |   32.00 |  10.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 57989 - humiditiesDewpoint - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    21.30 |   25.30 |   4.00 |
# | median        |    21.30 |   25.30 |   4.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 57989 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 748.0586729122813km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    96.00 |   70.00 | -26.00 |
# | median        |    96.00 |   70.00 | -26.00 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |
#
#
# ### Comparison Table: Object 58904 - distance - Window 72 hours - Measured 635.7824267136302km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   595.78 |  595.71 | -0.07 |
# | median        |   626.82 |  626.82 |  0.00 |
# | std_dev       |    45.46 |   45.49 |  0.03 |
# | IQR           |    97.48 |   97.48 |  0.00 |
# | range         |    97.48 |   97.48 |  0.00 |
#
#
# ### Comparison Table: Object 58904 - distance.1 - Window 72 hours - Measured 635.7824267136302km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   595.78 |  595.71 | -0.07 |
# | median        |   626.82 |  626.82 |  0.00 |
# | std_dev       |    45.46 |   45.49 |  0.03 |
# | IQR           |    97.48 |   97.48 |  0.00 |
# | range         |    97.48 |   97.48 |  0.00 |
#
#
# ### Comparison Table: Object 58904 - airtempsCurrentTemp - Window 72 hours - Measured 635.7824267136302km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    14.71 |   16.46 |  1.75 |
# | median        |    15.00 |   15.90 |  0.90 |
# | std_dev       |     4.02 |    3.08 | -0.95 |
# | IQR           |     6.43 |    4.70 | -1.72 |
# | range         |    14.20 |   11.40 | -2.80 |
#
#
# ### Comparison Table: Object 58904 - humiditiesDewpoint - Window 72 hours - Measured 635.7824267136302km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    11.82 |   10.10 | -1.72 |
# | median        |    12.40 |   10.80 | -1.60 |
# | std_dev       |     3.21 |    3.01 | -0.20 |
# | IQR           |     5.30 |    4.30 | -1.00 |
# | range         |    11.40 |   11.70 |  0.30 |
#
#
# ### Comparison Table: Object 58904 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 635.7824267136302km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    82.63 |   67.32 | -15.30 |
# | median        |    83.00 |   68.00 | -15.00 |
# | std_dev       |     6.48 |   10.33 |   3.85 |
# | IQR           |     9.00 |   16.00 |   7.00 |
# | range         |    26.00 |   41.00 |  15.00 |
#
#
# ### Comparison Table: Object 59592 - distance - Window 72 hours - Measured 628.8237199581139km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   626.63 |  625.98 | -0.65 |
# | median        |   710.56 |  710.56 |  0.00 |
# | std_dev       |   151.18 |  151.13 | -0.06 |
# | IQR           |   212.61 |  212.61 |  0.00 |
# | range         |   529.62 |  529.62 |  0.00 |
#
#
# ### Comparison Table: Object 59592 - distance.1 - Window 72 hours - Measured 628.8237199581139km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |   626.63 |  625.98 | -0.65 |
# | median        |   710.56 |  710.56 |  0.00 |
# | std_dev       |   151.18 |  151.13 | -0.06 |
# | IQR           |   212.61 |  212.61 |  0.00 |
# | range         |   529.62 |  529.62 |  0.00 |
#
#
# ### Comparison Table: Object 59592 - airtempsCurrentTemp - Window 72 hours - Measured 628.8237199581139km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    17.70 |   18.64 |  0.94 |
# | median        |    18.80 |   18.60 | -0.20 |
# | std_dev       |     4.23 |    3.69 | -0.55 |
# | IQR           |     8.00 |    6.50 | -1.50 |
# | range         |    13.50 |   14.60 |  1.10 |
#
#
# ### Comparison Table: Object 59592 - dissolvedoxygensDissolvedOxygenViaKitMgl - Window 72 hours - Measured 628.8237199581139km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |     8.55 |    8.43 | -0.12 |
# | median        |     8.55 |    8.00 | -0.55 |
# | std_dev       |     0.78 |    2.56 |  1.79 |
# | IQR           |     0.55 |    4.85 |  4.30 |
# | range         |     1.10 |    6.50 |  5.40 |
#
#
# ### Comparison Table: Object 59592 - humiditiesDewpoint - Window 72 hours - Measured 628.8237199581139km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |    11.54 |   12.39 | 0.85 |
# | median        |    11.70 |   12.30 | 0.60 |
# | std_dev       |     1.81 |    2.03 | 0.22 |
# | IQR           |     2.70 |    3.00 | 0.30 |
# | range         |     7.30 |    8.10 | 0.80 |
#
#
# ### Comparison Table: Object 59592 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 628.8237199581139km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    69.26 |   68.99 | -0.27 |
# | median        |    67.00 |   67.00 |  0.00 |
# | std_dev       |    14.29 |   14.56 |  0.28 |
# | IQR           |    26.00 |   25.00 | -1.00 |
# | range         |    47.80 |   53.10 |  5.30 |
#
#
# ### Comparison Table: Object 59665 - distance - Window 72 hours - Measured 567.5387043168354km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   528.42 |  528.42 | 0.00 |
# | median        |   528.42 |  528.42 | 0.00 |
# | std_dev       |   106.97 |  106.97 | 0.00 |
# | IQR           |   213.75 |  213.75 | 0.00 |
# | range         |   213.75 |  213.75 | 0.00 |
#
#
# ### Comparison Table: Object 59665 - distance.1 - Window 72 hours - Measured 567.5387043168354km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   528.42 |  528.42 | 0.00 |
# | median        |   528.42 |  528.42 | 0.00 |
# | std_dev       |   106.97 |  106.97 | 0.00 |
# | IQR           |   213.75 |  213.75 | 0.00 |
# | range         |   213.75 |  213.75 | 0.00 |
#
#
# ### Comparison Table: Object 59665 - airtempsCurrentTemp - Window 72 hours - Measured 567.5387043168354km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    30.69 |   28.22 | -2.47 |
# | median        |    30.30 |   27.90 | -2.40 |
# | std_dev       |     1.48 |    1.66 |  0.18 |
# | IQR           |     2.20 |    2.40 |  0.20 |
# | range         |     5.60 |    6.00 |  0.40 |
#
#
# ### Comparison Table: Object 59665 - humiditiesDewpoint - Window 72 hours - Measured 567.5387043168354km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    26.54 |   26.34 | -0.20 |
# | median        |    26.90 |   26.50 | -0.40 |
# | std_dev       |     0.89 |    0.70 | -0.19 |
# | IQR           |     1.60 |    1.20 | -0.40 |
# | range         |     2.90 |    2.70 | -0.20 |
#
#
# ### Comparison Table: Object 59665 - humiditiesRelativeHumidityPercent - Window 72 hours - Measured 567.5387043168354km Away
# | Measurement   |   Before |   After |     Δ |
# |---------------|----------|---------|-------|
# | mean          |    78.62 |   89.75 | 11.13 |
# | median        |    79.00 |   91.00 | 12.00 |
# | std_dev       |     6.42 |    6.16 | -0.25 |
# | IQR           |    10.00 |   10.00 |  0.00 |
# | range         |    27.00 |   22.00 | -5.00 |
#
#
# ### Comparison Table: Object 60337 - distance - Window 72 hours - Measured 422.00784025949895km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   422.01 |  422.01 | 0.00 |
# | median        |   422.01 |  422.01 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 60337 - distance.1 - Window 72 hours - Measured 422.00784025949895km Away
# | Measurement   |   Before |   After |    Δ |
# |---------------|----------|---------|------|
# | mean          |   422.01 |  422.01 | 0.00 |
# | median        |   422.01 |  422.01 | 0.00 |
# | std_dev       |     0.00 |    0.00 | 0.00 |
# | IQR           |     0.00 |    0.00 | 0.00 |
# | range         |     0.00 |    0.00 | 0.00 |
#
#
# ### Comparison Table: Object 60337 - airtempsCurrentTemp - Window 72 hours - Measured 422.00784025949895km Away
# | Measurement   |   Before |   After |      Δ |
# |---------------|----------|---------|--------|
# | mean          |    14.90 |   15.60 |   0.70 |
# | median        |    14.90 |   15.60 |   0.70 |
# | std_dev       |   nan    |  nan    | nan    |
# | IQR           |     0.00 |    0.00 |   0.00 |
# | range         |     0.00 |    0.00 |   0.00 |

# %%
# Initialize a structure to hold the changes
aggregated_changes = {}

for win in time_windows:
    for obj_id in matching_objects:
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()

        if not before_data.empty and not after_data.empty:
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns

            for column in numeric_cols:
                # Drop NaN values explicitly before statistic calculations
                before_series = before_data[column].dropna()
                after_series = after_data[column].dropna()

                # Ensure we have enough data after dropping NaNs for meaningful calculations
                if len(before_series) > 1 and len(after_series) > 1:
                    before_stats = calculate_stats_series(before_series)
                    after_stats = calculate_stats_series(after_series)

                    # Handle potential NaNs in specific statistics
                    if 'std_dev' in before_stats and 'std_dev' in after_stats:
                        if np.isnan(before_stats['std_dev']) or np.isnan(after_stats['std_dev']):
                            continue  # Skip further processing for cases with NaN std_dev
                        
                    stats_difference = {key: after_stats[key] - before_stats[key] for key in before_stats}
                    
                    if column not in aggregated_changes:
                        aggregated_changes[column] = {key: [] for key in stats_difference}
                        
                    for key in stats_difference:
                        aggregated_changes[column][key].append(stats_difference[key])
# Compute aggregate statistics, e.g., mean and standard deviation of changes
for column, changes in aggregated_changes.items():
    for stat, values in changes.items():
        values_np = np.array(values)
        aggregated_changes[column][stat] = {
            "mean_change": np.mean(values_np),
            "stddev_change": np.std(values_np)
        }

# Display the aggregated changes
for column, stats in aggregated_changes.items():
    print(f"### Aggregated Changes for Measurement: {column}")
    for stat, data in stats.items():
        mean_change = data['mean_change']
        stddev_change = data['stddev_change']

        print(f"{stat}: Mean Change = {mean_change:.2f}, Std Dev of Change = {stddev_change:.2f}")
    print("\n")
# Out:
# ### Aggregated Changes for Measurement: distance
# mean: Mean Change = 3.22, Std Dev of Change = 50.05
# median: Mean Change = 3.49, Std Dev of Change = 88.50
# std_dev: Mean Change = -4.47, Std Dev of Change = 30.59
# IQR: Mean Change = -6.57, Std Dev of Change = 62.97
# range: Mean Change = -4.99, Std Dev of Change = 88.65
#
#
# ### Aggregated Changes for Measurement: distance.1
# mean: Mean Change = 3.22, Std Dev of Change = 50.05
# median: Mean Change = 3.49, Std Dev of Change = 88.50
# std_dev: Mean Change = -4.47, Std Dev of Change = 30.59
# IQR: Mean Change = -6.57, Std Dev of Change = 62.97
# range: Mean Change = -4.99, Std Dev of Change = 88.65
#
#
# ### Aggregated Changes for Measurement: airtempsCurrentTemp
# mean: Mean Change = 0.03, Std Dev of Change = 2.45
# median: Mean Change = -0.16, Std Dev of Change = 2.81
# std_dev: Mean Change = -0.30, Std Dev of Change = 1.17
# IQR: Mean Change = -0.61, Std Dev of Change = 2.20
# range: Mean Change = -0.76, Std Dev of Change = 3.46
#
#
# ### Aggregated Changes for Measurement: humiditiesDewpoint
# mean: Mean Change = 0.26, Std Dev of Change = 3.30
# median: Mean Change = 0.07, Std Dev of Change = 3.22
# std_dev: Mean Change = -0.27, Std Dev of Change = 1.86
# IQR: Mean Change = -0.89, Std Dev of Change = 4.99
# range: Mean Change = -0.12, Std Dev of Change = 3.70
#
#
# ### Aggregated Changes for Measurement: humiditiesRelativeHumidityPercent
# mean: Mean Change = 0.58, Std Dev of Change = 8.82
# median: Mean Change = 0.74, Std Dev of Change = 10.28
# std_dev: Mean Change = -0.10, Std Dev of Change = 3.61
# IQR: Mean Change = -0.87, Std Dev of Change = 9.60
# range: Mean Change = 0.04, Std Dev of Change = 9.11
#
#
# ### Aggregated Changes for Measurement: dissolvedoxygensDissolvedOxygenViaKitMgl
# mean: Mean Change = 0.39, Std Dev of Change = 1.61
# median: Mean Change = 0.23, Std Dev of Change = 1.78
# std_dev: Mean Change = 0.11, Std Dev of Change = 1.09
# IQR: Mean Change = 0.14, Std Dev of Change = 1.83
# range: Mean Change = -0.00, Std Dev of Change = 3.20
#
#
# ### Aggregated Changes for Measurement: dissolvedoxygensSalinityViaDokitPpt
# mean: Mean Change = -0.17, Std Dev of Change = 0.40
# median: Mean Change = -0.01, Std Dev of Change = 0.03
# std_dev: Mean Change = -0.22, Std Dev of Change = 0.54
# IQR: Mean Change = -0.39, Std Dev of Change = 1.08
# range: Mean Change = -0.43, Std Dev of Change = 1.05
#
#
# ### Aggregated Changes for Measurement: dissolvedoxygensDissolvedOxygenViaProbeMgl
# mean: Mean Change = 0.00, Std Dev of Change = 0.00
# median: Mean Change = 0.00, Std Dev of Change = 0.00
# std_dev: Mean Change = 0.00, Std Dev of Change = 0.00
# IQR: Mean Change = 0.00, Std Dev of Change = 0.00
# range: Mean Change = 0.00, Std Dev of Change = 0.00

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.colors as mcolors
import matplotlib.cm as cm

# Data storage
hist_data = {}

for win in time_windows:
    for obj_id in matching_objects:
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()
        
        if not before_data.empty and not after_data.empty:
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns

            for column in numeric_cols:
                before_stats = calculate_stats_series(before_data[column].dropna())
                after_stats = calculate_stats_series(after_data[column].dropna())

                stats_difference = {key: after_stats[key] - before_stats[key] for key in before_stats}
                stats_difference["distance"] = distance  # Store distance
                
                if column in hist_data:
                    hist_data[column].append(stats_difference)
                else:
                    hist_data[column] = [stats_difference]

# Function to plot histograms with bin colors based on distance

def plot_histograms(data, value, pdf=None):
    for key, values in data.items():
        means = [entry[value] for entry in values if not np.isnan(entry[value])]
        distances = [entry["distance"] for entry in values if not np.isnan(entry[value])]

        if len(means) < 16:
            continue

        if means:
            fig, ax = plt.subplots(figsize=(8, 6))
            counts, bins, patches = ax.hist(means, bins=10, edgecolor='black')

            norm = mcolors.Normalize(vmin=min(distances), vmax=max(distances))
            colormap = cm.viridis
            
            for bin_patch, dist in zip(patches, distances):
                bin_patch.set_facecolor(colormap(norm(dist)))

            sm = cm.ScalarMappable(cmap=colormap, norm=norm)
            sm.set_array([])
            cbar = fig.colorbar(sm, ax=ax, label="Distance")
            
            ax.set_title(f"{value} Difference of {key}")
            ax.set_xlabel("Delta")
            ax.set_ylabel("Frequency")
            
            if pdf:
                pdf.savefig(fig)
                plt.close(fig)
            else:
                plt.show()

with PdfPages("outputs/histograms.pdf") as pdf:
    plot_histograms(hist_data, "mean", pdf)
    plot_histograms(hist_data, "std_dev", pdf)
    plot_histograms(hist_data, "range", pdf)
    plot_histograms(hist_data, "IQR", pdf)

# %% [markdown]
# ## Testing hypotheses
#
# Having seen the data, let's test some hypotheses:
#
# Up first: Does the reentry of space debris reduce humidity variability in the local atmosphere?
#
# We will evaluate the following: IQR, Range, and Standard Deviation

# %%
import numpy as np
from scipy import stats

before = {}
after = {}

# Example data: Humidity variability before and after reentry
# Replace these with actual values from your dataset
for win in time_windows:
    for obj_id in matching_objects:
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        distance = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"].mean()
        
        if not before_data.empty and not after_data.empty:
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns

            for column in numeric_cols:
                before_stats = calculate_stats_series(before_data[column].dropna())
                after_stats = calculate_stats_series(after_data[column].dropna())
                if column not in before:
                    before[column] = {}
                    after[column] = {}
 
                for stat in before_stats:
                    if stat not in before[column]:
                        before[column][stat] = []
                        after[column][stat] = []
                    before[column][stat].append(before_stats[stat])
                    after[column][stat].append(after_stats[stat])

for measurement in before:
    print(f"=====================")
    print(f"Testing {measurement}")
    for stat in before[measurement]:
        print(f"Testing {stat}")

        stat_before = np.array(before[measurement][stat])
        stat_after = np.array(after[measurement][stat])
        before_filter = ~np.isnan(stat_before)
        stat_before = stat_before[before_filter]
        stat_after = stat_after[before_filter]
        after_filter = ~np.isnan(stat_after)
        stat_before = stat_before[after_filter]
        stat_after = stat_after[after_filter]

        t_stat, p_value = stats.ttest_rel(stat_before, stat_after)

        # Print results
        print(f"T-statistic: {t_stat:.4f}")
        print(f"P-value: {p_value:.4f}")

        # Interpretation
        alpha = 0.05  # 5% significance level
        if p_value < alpha:
            print(f"FOUND STATISTICAL SIGNIFICANCE: {measurement}: {stat} before-after difference statistically significant: P-value = {p_value}")
        else:
            print(f"{measurement}: {stat} before-after difference not statistically significant: P-value = {p_value}")
# Out:
# =====================
# Testing distance
# Testing mean
# T-statistic: -0.6274
# P-value: 0.5319
# distance: mean before-after difference not statistically significant: P-value = 0.5318968070080936
# Testing median
# T-statistic: -0.3842
# P-value: 0.7017
# distance: median before-after difference not statistically significant: P-value = 0.7017075879669059
# Testing std_dev
# T-statistic: 1.4250
# P-value: 0.1574
# distance: std_dev before-after difference not statistically significant: P-value = 0.1574461813125528
# Testing IQR
# T-statistic: 1.0169
# P-value: 0.3118
# distance: IQR before-after difference not statistically significant: P-value = 0.3117731410375337
# Testing range
# T-statistic: 0.5489
# P-value: 0.5844
# distance: range before-after difference not statistically significant: P-value = 0.5843700927672465
# =====================
# Testing distance.1
# Testing mean
# T-statistic: -0.6274
# P-value: 0.5319
# distance.1: mean before-after difference not statistically significant: P-value = 0.5318968070080936
# Testing median
# T-statistic: -0.3842
# P-value: 0.7017
# distance.1: median before-after difference not statistically significant: P-value = 0.7017075879669059
# Testing std_dev
# T-statistic: 1.4250
# P-value: 0.1574
# distance.1: std_dev before-after difference not statistically significant: P-value = 0.1574461813125528
# Testing IQR
# T-statistic: 1.0169
# P-value: 0.3118
# distance.1: IQR before-after difference not statistically significant: P-value = 0.3117731410375337
# Testing range
# T-statistic: 0.5489
# P-value: 0.5844
# distance.1: range before-after difference not statistically significant: P-value = 0.5843700927672465
# =====================
# Testing airtempsCurrentTemp
# Testing mean
# T-statistic: -0.7357
# P-value: 0.4638
# airtempsCurrentTemp: mean before-after difference not statistically significant: P-value = 0.46377473639913047
# Testing median
# T-statistic: -0.1419
# P-value: 0.8875
# airtempsCurrentTemp: median before-after difference not statistically significant: P-value = 0.8874536084746741
# Testing std_dev
# T-statistic: 2.3287
# P-value: 0.0223
# FOUND STATISTICAL SIGNIFICANCE: airtempsCurrentTemp: std_dev before-after difference statistically significant: P-value = 0.022277599002317964
# Testing IQR
# T-statistic: 2.4103
# P-value: 0.0179
# FOUND STATISTICAL SIGNIFICANCE: airtempsCurrentTemp: IQR before-after difference statistically significant: P-value = 0.017926905584379326
# Testing range
# T-statistic: 1.8871
# P-value: 0.0623
# airtempsCurrentTemp: range before-after difference not statistically significant: P-value = 0.062295336422459144
# =====================
# Testing dissolvedoxygensDissolvedOxygenViaKitMgl
# Testing mean
# T-statistic: -1.9369
# P-value: 0.0602
# dissolvedoxygensDissolvedOxygenViaKitMgl: mean before-after difference not statistically significant: P-value = 0.060216957207302246
# Testing median
# T-statistic: -1.3284
# P-value: 0.1920
# dissolvedoxygensDissolvedOxygenViaKitMgl: median before-after difference not statistically significant: P-value = 0.19198458541599672
# Testing std_dev
# T-statistic: -0.5852
# P-value: 0.5623
# dissolvedoxygensDissolvedOxygenViaKitMgl: std_dev before-after difference not statistically significant: P-value = 0.5622724763197742
# Testing IQR
# T-statistic: -0.5867
# P-value: 0.5608
# dissolvedoxygensDissolvedOxygenViaKitMgl: IQR before-after difference not statistically significant: P-value = 0.5608477753793308
# Testing range
# T-statistic: -0.1764
# P-value: 0.8609
# dissolvedoxygensDissolvedOxygenViaKitMgl: range before-after difference not statistically significant: P-value = 0.8609288095107772
# =====================
# Testing dissolvedoxygensDissolvedOxygenViaProbeMgl
# Testing mean
# T-statistic: -0.9334
# P-value: 0.4195
# dissolvedoxygensDissolvedOxygenViaProbeMgl: mean before-after difference not statistically significant: P-value = 0.41945747414523377
# Testing median
# T-statistic: -0.9334
# P-value: 0.4195
# dissolvedoxygensDissolvedOxygenViaProbeMgl: median before-after difference not statistically significant: P-value = 0.41945747414523377
# Testing std_dev
# T-statistic: nan
# P-value: nan
# dissolvedoxygensDissolvedOxygenViaProbeMgl: std_dev before-after difference not statistically significant: P-value = nan
# Testing IQR
# T-statistic: nan
# P-value: nan
# dissolvedoxygensDissolvedOxygenViaProbeMgl: IQR before-after difference not statistically significant: P-value = nan
# Testing range
# T-statistic: nan
# P-value: nan
# dissolvedoxygensDissolvedOxygenViaProbeMgl: range before-after difference not statistically significant: P-value = nan
# =====================
# Testing dissolvedoxygensSalinityViaDokitPpt
# Testing mean
# T-statistic: 1.0808
# P-value: 0.3113
# dissolvedoxygensSalinityViaDokitPpt: mean before-after difference not statistically significant: P-value = 0.31127292857892686
# Testing median
# T-statistic: 1.0391
# P-value: 0.3291
# dissolvedoxygensSalinityViaDokitPpt: median before-after difference not statistically significant: P-value = 0.3291225981937569
# Testing std_dev
# T-statistic: 1.0168
# P-value: 0.3485
# dissolvedoxygensSalinityViaDokitPpt: std_dev before-after difference not statistically significant: P-value = 0.34846640253673167
# Testing IQR
# T-statistic: 0.8908
# P-value: 0.3991
# dissolvedoxygensSalinityViaDokitPpt: IQR before-after difference not statistically significant: P-value = 0.3990570005821119
# Testing range
# T-statistic: 1.0000
# P-value: 0.3466
# dissolvedoxygensSalinityViaDokitPpt: range before-after difference not statistically significant: P-value = 0.34659350708733416
# =====================
# Testing humiditiesDewpoint
# Testing mean
# T-statistic: -0.8654
# P-value: 0.3893
# humiditiesDewpoint: mean before-after difference not statistically significant: P-value = 0.3893175284773791
# Testing median
# T-statistic: -0.4488
# P-value: 0.6547
# humiditiesDewpoint: median before-after difference not statistically significant: P-value = 0.6547271653557984
# Testing std_dev
# T-statistic: 1.2652
# P-value: 0.2098
# humiditiesDewpoint: std_dev before-after difference not statistically significant: P-value = 0.20975440616785587
# Testing IQR
# T-statistic: 1.4985
# P-value: 0.1378
# humiditiesDewpoint: IQR before-after difference not statistically significant: P-value = 0.13783998047255974
# Testing range
# T-statistic: 0.0902
# P-value: 0.9284
# humiditiesDewpoint: range before-after difference not statistically significant: P-value = 0.9283681772786118
# =====================
# Testing humiditiesRelativeHumidityPercent
# Testing mean
# T-statistic: 0.2523
# P-value: 0.8014
# humiditiesRelativeHumidityPercent: mean before-after difference not statistically significant: P-value = 0.8014395980005089
# Testing median
# T-statistic: 0.0800
# P-value: 0.9364
# humiditiesRelativeHumidityPercent: median before-after difference not statistically significant: P-value = 0.9364380018763994
# Testing std_dev
# T-statistic: 0.2347
# P-value: 0.8151
# humiditiesRelativeHumidityPercent: std_dev before-after difference not statistically significant: P-value = 0.8150941264070958
# Testing IQR
# T-statistic: 0.8135
# P-value: 0.4183
# humiditiesRelativeHumidityPercent: IQR before-after difference not statistically significant: P-value = 0.4183149411358936
# Testing range
# T-statistic: -0.0341
# P-value: 0.9729
# humiditiesRelativeHumidityPercent: range before-after difference not statistically significant: P-value = 0.9728590297389015
# /home/pisanvs/code/GLOBE-research/.venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/pisanvs/code/GLOBE-research/.venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:1214: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero

# %%
import numpy as np
from scipy import stats

# Dictionaries to store statistics and corresponding weights
before = {}
after = {}
weights = {}

epsilon = 1e-6  # small constant to avoid division by zero

# Loop over time windows and matching objects
for win in time_windows:
    for obj_id in matching_objects:
        # Extract data for before and after periods
        before_data = time_series_data[win]["before"][time_series_data[win]["before"]["object_id"] == obj_id]
        after_data = time_series_data[win]["after"][time_series_data[win]["after"]["object_id"] == obj_id]
        
        # Compute the mean distance for this object; then compute its weight
        distance_series = time_series_data[win]["distance"][time_series_data[win]["distance"]["object_id"] == obj_id]["distance"]
        if distance_series.empty:
            continue
        distance = distance_series.mean()
        if np.isnan(distance):
            continue
        # Inverse distance weighting: closer distances yield higher weights
        weight_val = 1 / (distance + epsilon)
        
        # Only process if both before and after data exist
        if not before_data.empty and not after_data.empty:
            numeric_cols = before_data.select_dtypes(include=[np.number]).columns

            for column in numeric_cols:
                # Compute your statistics for the column
                before_stats = calculate_stats_series(before_data[column].dropna())
                after_stats = calculate_stats_series(after_data[column].dropna())
                
                # Initialize dictionaries if not already present
                if column not in before:
                    before[column] = {}
                    after[column] = {}
                    weights[column] = {}
 
                for stat in before_stats:
                    if stat not in before[column]:
                        before[column][stat] = []
                        after[column][stat] = []
                        weights[column][stat] = []  # store corresponding weight for each pair
                    before[column][stat].append(before_stats[stat])
                    after[column][stat].append(after_stats[stat])
                    weights[column][stat].append(weight_val)

# Perform weighted paired t-tests for each measurement/statistic
for measurement in before:
    print("=====================")
    print(f"Testing {measurement}")
    for stat in before[measurement]:
        print(f"Testing {stat}")
        
        # Convert lists to numpy arrays
        stat_before = np.array(before[measurement][stat])
        stat_after = np.array(after[measurement][stat])
        w = np.array(weights[measurement][stat])
        
        # Remove any NaN values in parallel across arrays
        valid = ~np.isnan(stat_before) & ~np.isnan(stat_after) & ~np.isnan(w)
        stat_before = stat_before[valid]
        stat_after = stat_after[valid]
        w = w[valid]
        
        if len(stat_before) == 0:
            print("No valid data for this test.")
            continue
        
        # Compute paired differences
        d = stat_before - stat_after
        
        # Compute total weight and sum of squared weights
        W = np.sum(w)
        w2 = np.sum(w**2)
        if W == 0 or w2 == 0:
            print("Invalid weights, skipping test.")
            continue
        
        # Effective sample size
        n_eff = W**2 / w2
        
        # Weighted mean difference
        d_bar = np.sum(w * d) / W
        
        # Calculate weighted variance of the differences using:
        # weighted_var = sum(w * (d - d_bar)^2) / (W - (sum(w^2)/W))
        denom = W - (w2 / W)
        if denom <= 0:
            print("Non-positive denominator for weighted variance, skipping.")
            continue
        weighted_var = np.sum(w * (d - d_bar)**2) / denom
        
        # Standard error of the weighted mean difference
        se = np.sqrt(weighted_var / n_eff)
        if se == 0:
            print("Standard error zero, cannot compute t-statistic.")
            continue
        
        # Compute t-statistic and two-tailed p-value
        t_stat = d_bar / se
        p_value = 2 * stats.t.sf(np.abs(t_stat), df=n_eff - 1)
        
        # Print results
        print(f"T-statistic: {t_stat:.4f}")
        print(f"P-value: {p_value:.4f}")
        
        alpha = 0.05  # significance level (here 10% as an example)
        if p_value < alpha:
            print(f"FOUND STATISTICAL SIGNIFICANCE: {measurement}: {stat} before-after difference statistically significant (P-value = {p_value})")
        else:
            print(f"{measurement}: {stat} before-after difference not statistically significant (P-value = {p_value})")
# Out:
# =====================
# Testing distance
# Testing mean
# T-statistic: -0.1899
# P-value: 0.8499
# distance: mean before-after difference not statistically significant (P-value = 0.8498978288704224)
# Testing median
# T-statistic: -0.1345
# P-value: 0.8934
# distance: median before-after difference not statistically significant (P-value = 0.8933892928606751)
# Testing std_dev
# T-statistic: 1.2747
# P-value: 0.2065
# distance: std_dev before-after difference not statistically significant (P-value = 0.20651676022975976)
# Testing IQR
# T-statistic: 0.9809
# P-value: 0.3299
# distance: IQR before-after difference not statistically significant (P-value = 0.3299262843377382)
# Testing range
# T-statistic: 0.6472
# P-value: 0.5195
# distance: range before-after difference not statistically significant (P-value = 0.5195269826480489)
# =====================
# Testing distance.1
# Testing mean
# T-statistic: -0.1899
# P-value: 0.8499
# distance.1: mean before-after difference not statistically significant (P-value = 0.8498978288704224)
# Testing median
# T-statistic: -0.1345
# P-value: 0.8934
# distance.1: median before-after difference not statistically significant (P-value = 0.8933892928606751)
# Testing std_dev
# T-statistic: 1.2747
# P-value: 0.2065
# distance.1: std_dev before-after difference not statistically significant (P-value = 0.20651676022975976)
# Testing IQR
# T-statistic: 0.9809
# P-value: 0.3299
# distance.1: IQR before-after difference not statistically significant (P-value = 0.3299262843377382)
# Testing range
# T-statistic: 0.6472
# P-value: 0.5195
# distance.1: range before-after difference not statistically significant (P-value = 0.5195269826480489)
# =====================
# Testing airtempsCurrentTemp
# Testing mean
# T-statistic: -0.9676
# P-value: 0.3366
# airtempsCurrentTemp: mean before-after difference not statistically significant (P-value = 0.3366088523903864)
# Testing median
# T-statistic: -0.4202
# P-value: 0.6757
# airtempsCurrentTemp: median before-after difference not statistically significant (P-value = 0.6756672807863654)
# Testing std_dev
# T-statistic: 1.9481
# P-value: 0.0559
# airtempsCurrentTemp: std_dev before-after difference not statistically significant (P-value = 0.055909960622930105)
# Testing IQR
# T-statistic: 2.0896
# P-value: 0.0403
# FOUND STATISTICAL SIGNIFICANCE: airtempsCurrentTemp: IQR before-after difference statistically significant (P-value = 0.04033122356890495)
# Testing range
# T-statistic: 1.6603
# P-value: 0.1014
# airtempsCurrentTemp: range before-after difference not statistically significant (P-value = 0.10138389523106052)
# =====================
# Testing dissolvedoxygensDissolvedOxygenViaKitMgl
# Testing mean
# T-statistic: -2.3999
# P-value: 0.0221
# FOUND STATISTICAL SIGNIFICANCE: dissolvedoxygensDissolvedOxygenViaKitMgl: mean before-after difference statistically significant (P-value = 0.022055062555825608)
# Testing median
# T-statistic: -1.7212
# P-value: 0.0944
# dissolvedoxygensDissolvedOxygenViaKitMgl: median before-after difference not statistically significant (P-value = 0.09435715211473228)
# Testing std_dev
# T-statistic: -0.6246
# P-value: 0.5369
# dissolvedoxygensDissolvedOxygenViaKitMgl: std_dev before-after difference not statistically significant (P-value = 0.5369340075242492)
# Testing IQR
# T-statistic: -0.5260
# P-value: 0.6023
# dissolvedoxygensDissolvedOxygenViaKitMgl: IQR before-after difference not statistically significant (P-value = 0.6023314227497343)
# Testing range
# T-statistic: -0.1252
# P-value: 0.9011
# dissolvedoxygensDissolvedOxygenViaKitMgl: range before-after difference not statistically significant (P-value = 0.901134589911045)
# =====================
# Testing dissolvedoxygensDissolvedOxygenViaProbeMgl
# Testing mean
# T-statistic: -1.2861
# P-value: 0.3064
# dissolvedoxygensDissolvedOxygenViaProbeMgl: mean before-after difference not statistically significant (P-value = 0.3063813041971351)
# Testing median
# T-statistic: -1.2861
# P-value: 0.3064
# dissolvedoxygensDissolvedOxygenViaProbeMgl: median before-after difference not statistically significant (P-value = 0.3063813041971351)
# Testing std_dev
# Non-positive denominator for weighted variance, skipping.
# Testing IQR
# Standard error zero, cannot compute t-statistic.
# Testing range
# Standard error zero, cannot compute t-statistic.
# =====================
# Testing dissolvedoxygensSalinityViaDokitPpt
# Testing mean
# T-statistic: 0.9787
# P-value: 0.3598
# dissolvedoxygensSalinityViaDokitPpt: mean before-after difference not statistically significant (P-value = 0.35976206134178357)
# Testing median
# T-statistic: 0.9426
# P-value: 0.3767
# dissolvedoxygensSalinityViaDokitPpt: median before-after difference not statistically significant (P-value = 0.37671754930133566)
# Testing std_dev
# T-statistic: 0.9901
# P-value: 0.3610
# dissolvedoxygensSalinityViaDokitPpt: std_dev before-after difference not statistically significant (P-value = 0.3610095672647291)
# Testing IQR
# T-statistic: 0.7296
# P-value: 0.4889
# dissolvedoxygensSalinityViaDokitPpt: IQR before-after difference not statistically significant (P-value = 0.48894314537034345)
# Testing range
# T-statistic: 0.8691
# P-value: 0.4131
# dissolvedoxygensSalinityViaDokitPpt: range before-after difference not statistically significant (P-value = 0.413077875089783)
# =====================
# Testing humiditiesDewpoint
# Testing mean
# T-statistic: -1.1988
# P-value: 0.2346
# humiditiesDewpoint: mean before-after difference not statistically significant (P-value = 0.23462910302823017)
# Testing median
# T-statistic: -0.5119
# P-value: 0.6103
# humiditiesDewpoint: median before-after difference not statistically significant (P-value = 0.6103384499155848)
# Testing std_dev
# T-statistic: 1.5874
# P-value: 0.1173
# humiditiesDewpoint: std_dev before-after difference not statistically significant (P-value = 0.11734759674606197)
# Testing IQR
# T-statistic: 1.7317
# P-value: 0.0877
# humiditiesDewpoint: IQR before-after difference not statistically significant (P-value = 0.0876998993589324)
# Testing range
# T-statistic: 0.4444
# P-value: 0.6581
# humiditiesDewpoint: range before-after difference not statistically significant (P-value = 0.6581002432962981)
# =====================
# Testing humiditiesRelativeHumidityPercent
# Testing mean
# T-statistic: 0.4090
# P-value: 0.6837
# humiditiesRelativeHumidityPercent: mean before-after difference not statistically significant (P-value = 0.6837448729543607)
# Testing median
# T-statistic: 0.2399
# P-value: 0.8111
# humiditiesRelativeHumidityPercent: median before-after difference not statistically significant (P-value = 0.8111021390603649)
# Testing std_dev
# T-statistic: 0.3410
# P-value: 0.7342
# humiditiesRelativeHumidityPercent: std_dev before-after difference not statistically significant (P-value = 0.7342406743258936)
# Testing IQR
# T-statistic: 1.2427
# P-value: 0.2181
# humiditiesRelativeHumidityPercent: IQR before-after difference not statistically significant (P-value = 0.2181055507646612)
# Testing range
# T-statistic: 0.0167
# P-value: 0.9867
# humiditiesRelativeHumidityPercent: range before-after difference not statistically significant (P-value = 0.9866934472763988)
